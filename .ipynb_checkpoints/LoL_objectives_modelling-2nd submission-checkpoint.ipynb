# %% [markdown]
# # Assessing significance of neutral objectives in League of Legends

# %% [markdown]
# ### Table of contents
#
# 1. [Loading and saving libraries/data](#load)
#
# 2. [Querying Riot's API](#query)
#
# 3. [Data Proprocessing and exploration](#explore)
#
# 4. [Revised Machine Learning Model](#model)
#
# 5. [Results Summary and Future Directions](#results)
#
# 6. [Initial Machine Learning Model](#initial)

# %% [markdown]
# ## Background Information
# ### Brief Game Overview
# League of Legends (LOL) is a 5v5 multiplayer strategy game where each team's objective is to destroy the other team's Nexus, a structural objective. Every game takes place on the same map, Summoner's Rift (Fig 1) with the blue team on the bottom left side and the red team on the upper right side, and the same monsters (see Fig 1). Players spwan at the corner of their side of the map, located next to their team's Nexus. Over the course of the game, players must destroy a series of structural objectives - turrets and inhibitors - before getting access to the final objective located at the opposite corner of the map.
#
# ### Neutral objectives Overview
# Outside of the mandatory winning objectives, there are **neutral objectives** that are positioned closely to the diagonal division between the two teams, where the map division is visually indicated by a river. Neutral objectives are strong monsters that spawn in alcoves that both teams can access via openings facing the river. These monsters spawn at specific timepoints of the game as well as periodically spawn once an objective is killed. Killing neutral objectives grants unique buffs (in addition to the usual gold and experience) for the team who deals the final blow, and thus granting advantages which may swing the favor of a game or secure the stronger team's winning advantages.
# Each type of monster grants a unique buff for the team who kills it, as determined by the player who deals the final blow. Neutral objectives include **dragons, rift heralds, and baron nashors**. Dragons are further divided into 4 elemental types (water, fire, air, earth)  and an additional Elder type. Each dragon type is categorized as different features for this project, as each dragon type grants a unique buff.
#
# ### Predicting LOL Game Outcome
# Predicting game outcome based on post-game or real-time stats usually involves as many significantly relevant features as possible. These numbers include: **player kills, structural objectives captured, gold, experience, items, and neutral objectives**. There have been other project looking at the predictive power of very specific features, such as the champions selected by the players, and individual professional e-sports players. I have not found any projects focusing on the importance of objectives nor one that is up-to-date with the latest objective changes for the current season.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Figure 1. Summoner's Rift Map with labelled monster objectives.

# %% [markdown]
# ### Why focus on neutral objectives?
# The relative benefits and importance of these neutral monster objectives are widely debated. The objectives are geographically split on the game map, with rift herald and baron spawning on the top side and dragons spawning on the bottom side of the map. The split locations often force teams to choose between prioritizing the two locations; the enemy team is usually able to "trade" these objectives by taking the other neutral objective located at the opposite side of the map. Even if one team is behind and unable to contest an objective, the weaker team is usually able to either take the neutral objective located at the other side of the map or a structural objective. The objective dilemma becomes more significant in professional e-sports, where skilled players are able to utilize small advantages gained from capturing neutral objectives to swing the game in their favor or to further a lead into victory.
#
# This project aims to provide insight on the relative importance of neutral objectives throughout the course of the game, helping players make optimal decisions regarding objectives. The anaylzed match data was extracted via the [Riot Games API](https://developer.riotgames.com/apis) and contains over 20,000 NA high elo solo/duo ranked matches from masters, Grandmasters, and Challenger tier players in the North American server on patch 10.11.

# %% [markdown]
# # Project Overview
#
# There are two components to this project:
# 1. Train a binary classifier model for predicting the winner of a game at different times of a game
#     - Two different models were trained to predict the winner of each game, red side or blue side. The models both use only features related to neutral objectives for training and prediction. In contrast, predictive LOL models usually would try to include all relevant statistics such as team gold and kills. However, the focus of this project is to evaluate only specifically the predictive power of one type of resource: neutral objectives.
#
# 2. Assess the relative importance of neutral objectives to predicting game outcomes
#     - The number of objectives captured up to different timepoints in a game will be used to predict the winner. This will examine the importance of different objective types in predicting the game winner.
#     - feature importance weights will be extracted from the trained model

# %% [markdown]
# ### Model 1:
# - **Post-game features**: Model 1 used features related to neutral objectives for each team at the end of the game, e.g. number of barons taken by the blue team.
#
#
# ### Model 2:
# - **Time Intervals**: I was interested in the predictive power of neutral objectives at different points of the game, since the value of a dragon varies at different times in the game. At 5 minute intervals for each game, the winner is predicted using neutral objective numbers at that timepoint.
# - **Streamlined features**: I chose to express the features differently, rather than each feature relating to a team (e.g. number of barons captured by the red team), features are expressed as a difference between the two teams, e.g. the difference in number of barons captured between the two teamss. This massively streamlines the number of features and increases interpretability with minimal data loss.
#
#
# ## Evaluation Metrics
#
#
# Predicting wins in sports lends itself to gambling applications, and thus the models will be evaluated as such; of course, the current model has limited practical applications since it only work mid-game or post-game, while e-sports betting usually happens pre-game. Of the metrics in a confusion matrix, precision would be more valuable than recall for this project. Recall refers to the number of blue-win games that were correctly classified as such, while precision refers to the proportion of correct predictions (TP) of all blue-win predictions (TP+FP). Maximizing the chance that a winning prediction is correct is critical for minimizing the financial risks of betting on a single game. Recall is less important since bets are generally based on individual games. F1 score is also used as a metric to balance precision and recall.
#
#
# Fortunately, the outcome dataset is balanced - the blue and red sides are designed such that there is practically no advantage to be on either side.

# %% [markdown]
# ### Results of initial model

# %% [markdown]
# #### Dragon Soul
#
# The data does seem to reflect what people think of the relative power levels of dragon souls - ocean is the most powerful IF you get it early. Cloud soul also contributes towards wins if it's obtained earlier in the game. This makes sense since ocean and cloud drake both grant advantages early and mid-game, but these advantages decrease as the game goes on. Come late game, the players' stats will have scaled enough and the game's pace will change to even out these dragon soul advantages.
#
# Ocean soul grants extra health and mana regeneration out of combat, which will help one team stay healthy throughout midgames during skirmishes, extended seiges and teamfights. Since it boosts regeneration, ocean soul is only useful if at least some players on a team stay alive after combat. Turrets still do significant damage to players midgame, so even if not everyone on a is alive, ocean soul helps the alive players stay healthy to defend with the safety of  structures. As the game goes on, player damage will have also increased to the point that players are more likely to die and the death timers are longer. Additionally, structural defenses, turrets, do less meaningful damage to players while players can destroy them more easily. As deaths become more impactful, any player who remain alive on a team while some of their teammates are dead find that ocean soul becomes less helpful in defense.
#
# Cloud soul increases movement speed and cooldown reduction on spells, granting one team a tempo advantage in moving around the map and having increased access to useful ultimate spells. Player will have more CDR items and have decreased cooldowns with higher level spells, so players will be more likely to have equal access to their ultimate spells later in the game.
#
# Infernal soul, on the other hand, remains powerful regardless of when the team obtains it. The infernal soul grants percent-based permanent damage bonuses to a team, so that advantage remains throughout the course of a game.

# %% [markdown]
# The top 5 most predictive features are:
# 1. team that takes first inhibitor
# 2. number of elemental dragons taken by red team
# 3. number of elemental dragons taken by blue team
# 4. number of baron kills taken by the red team
# 5. team that takes first tower
#
# Which team kills the first inhibitor seems to be the best predictor of who will win the game. This makes sense since killing an inhibitor is the most direct path towards killing the enemy nexus. The first inhibitor kill accounts for 60% of the weights for predicting the game winner.
#
# The total number of elemental drakes taken by a team is the next best predictor, with red team dragon kills being slightly more predictive than blue team's. Without doing further analysis it's hard to say whether this difference is statistically significant. We can speculate that perhaps the red team's larger relative distance from the dragon pit compared to the blue team means that red team naturally has less control over the dragon; therefore, if the red team is successful at capturing dragon objectives, red likely has a strong control over the game carrying over to wins.
#
# The order of importance of neutral objectives to the game result seems to be:
# #### elemental dragons > baron > elder dragon > rift herald
#
# ### Early objectives
#
# Of all the early objectives available (inhibitor, tower, dragon, baron, rift herald), it seems that the non-neutral objectives, inhibitors and towers, are the most predictive, followed by dragon and baron. First rift herald seem to have no predictive weight on the winner at all.
#
# Of course, the associations here must be taken with a grain of salt before tranlating them to causation. Having early game pressure will translate to more objective control. However, it is very telling that first dragon has more weight than first herald, when both of these objectives are usually captured around the same time and are often "traded" for each other (if one team takes one, the other team will take the other).

# %% [markdown]
# # Model 2 Results Summary

# %% [markdown]
# Although this project is unable to establish causal relationships, it identified interesting relationships between different types of neutral objectives, game time, and the winning team:
# - among the "firsts" in objectives, first inhibitor is most predictive of the winner followed by first baron and first tower very closely together.
#
# The top 5 most post-game predictive features are:
# 1. team that takes first inhibitor
# 2. elemental dragons difference
# 3. game duration
# 4. baron kill difference
# 5. team that takes first baron / team that takes first tower
#
#
#
#
#
#
# ### Early objectives
#
# Of all the early objectives available (inhibitor, tower, dragon, baron, rift herald), the order of their importances are.
#
# #### First inhibitor > First baron > First tower > First dragon > First rift herald
#
# Of course, the associations here must be taken with a grain of salt before tranlating them to causation - other than First Inhibitor, the differences in weights between the objectives are not big. Having early game pressure will translate to more objective control. However, it is very telling that first dragon has more weight than first herald, when both of these objectives are usually captured around the same time and are often "traded" for each other (if one team takes one, the other team will take the other).

# %% [markdown]
# Different types of objectives seem to be the most valuable (associated with winning) at different points in the game:
# - 10 mins: **elemental dragon differences**, in order of Ocean > Infernal > Mountain > Cloud.
#     - While this may suggest that the order is related to the degree of advantage the dragon bestows on a team, it's just as possible that the order reflects prioritization of the dragon types. For example, the ocean dragons are regarded as beneficial for early laning phases, so advantaged team may expend more effort securing the dragon than for a cloud dragon.
#     - considering the priority that teams place on dragons right now as a stepping stone to obtaining dragon soul, the weakness of the individual dragons, and the fact that the soul drake element is not reveal until after the 2nd dragon is killed, it seems likely that the weight differences here stem from the degree of advantages conferred by different types of dragons.
# - 15-20 mins: **rift herald difference** - if the rift herald is captured early enough, it will spawn a second time as a stronger buff. The rift herald will despawn at 20 minutes if not killed, so the window of most significance during 15 and 20 minutes reflects this nicely. The 20 minute association is stronger than the 15 minute one in accordance with the rift herald's strength.
# - 25-35 mins: **Baron nashor difference** at 35 mins, soul dragons and elder dragons become more significant, but their effects are still overshadowed by literally every other objective.
#
# ### Elemental Dragons
# It seems that elemental dragon advantages - those found in early game - are much more significantly associated with wins than souls. Certainly part of the reason for the association may be the translation of early game advantages, obtained from outside of neutral objectives (e.g. lane dominance, successful skirmishes), into capturing neutral objectives. There is still the logical possibility of a causal relationship.
#
# Individiual elemental dragons might be weak (and they are far weaker than in previous seasons), but they are far more significantly related to wins than the objectively stronger elder dragons and dragon souls. The small advantages conferred by individual drakes in the early game might help teams dominate over the enemy team and snowball further advantages.
# To better establish a causal relationship, Assessing how teams prioritize between the different objectives would be useful to establish a causal relationship. The relatively small importances that souls have towards wins compared to the initial direct correlation might be that by the time these late-game objectives are available, wins are already decided by early game snowballing.

# %% [markdown]
# # Future work/directions:
# - adding predictions based on different points of time in the game
# - for the time series, change the temporary buff features (e.g. rift herald, Elder dragon, baron) so that each gamestate interval will only reflect the objectives captured in that time interval (vs. having a cumulative count)
# - adding lane positions to assess their impact on objective control
# - try fitting a XGBoost Classifier model, a variation of the Gradient Boosting Classifier used for the project
# - add other relevant match variables: team gold, kills, wards, champion picks, etc.
# - expand number of matches in dataset - due to time practicality limitations, only 20,000 matches were extracted of over 60,000 match IDs obtained
# - expand data to servers in other geographical regions - e.g. EU, China, Korean
# - expand data to lower elos, since masters+ is a very small proportion of the playerbase and may not reflect what the predictors are in lower elo (e.g. Bronze, Silver, Gold)
# - evaluate competitive play, which plays out differently than solo queue, and where objective decisions matter more than anywhere else

# %% [markdown]
# <a id='load'></a>
# ### Loading libraries and data, saving data

# %%
import requests, json
import numpy as np
import importlib
import pandas as pd
import pickle
import os

from riotwatcher import LolWatcher, ApiError
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
import pdb
import warnings
warnings.filterwarnings('ignore')

# %%
from src import data_preprocessing as p
from src import visuals as v

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import make_scorer, fbeta_score, accuracy_score, classification_report

# %% [markdown]
# ### Load saved data

# %%
# %%time
gamestate_by_time_dict = p.load_pkl('data/gamestate_by_time_dict.pkl')
# Out:
# Wall time: 51.9 ms

# %%
# %%time
match_results_dict = p.load_pkl('data/match_results_dict.pkl')
# Out:
# Wall time: 60.8 ms

# %%
# %%time
match_detail_dict = p.load_pkl('data/match_detail_dict.pkl')
# Out:
# Wall time: 4.68 s

# %%
#warning: LARGE file
# %%time
match_timeline_dict = p.load_pkl('data/match_timeline_dict.pkl')

# %%
# %%time
matchlist = p.load_pkl('data/matchlist.pkl')
# Out:
# Wall time: 4.99 ms

# %%
# %%time
list_time_dicts = p.load_pkl('data/list_time_dicts.pkl')
# Out:
# Wall time: 63.8 ms

# %%
# %%time
match_results_dict = p.load_pkl('data/match_results_dict.pkl')
# Out:
# Wall time: 40.9 ms

# %%
# %%time
gamestate_by_time_dict = p.load_pkl('data/gamestate_by_time_dict.pkl')
# Out:
# Wall time: 52.9 ms

# %%
# %%time
filled_gamestate_by_time_dict = p.load_pkl('data/filled_gamestate_by_time_dict.pkl')
# Out:
# Wall time: 16.9 ms

# %%
#load unprocessed df (immediately after extraction from dict)
df = pd.read_csv('data/match_stats_df.csv')

# %%
df
# Out:
#        Unnamed: 0  GameDuration Winner firstTower firstInhibitor firstDragon  \
# 0      3411673088          1195    red        red            red         red
# 1      3435528193          1516   blue       blue            red         NaN
# 2      3447586821          1964   blue        red            red         red
# 3      3426877449           915    red        red            NaN         red
# 4      3419144205          1176    red        red            red         red
# ...           ...           ...    ...        ...            ...         ...
# 19995  3436877728          2184    red        red            red         red
# 19996  3422984098          1112   blue       blue           blue         red
# 19997  3342243749          1880    red       blue            red        blue
# 19998  3448805286          1105    red        red            NaN         red
# 19999  3427833767           896   blue       blue           blue        blue
#
#       firstRiftHerald  bluebaronKills  redbaronKills  blueriftHeraldKills  \
# 0                blue               0              0                    1
# 1                 NaN               0              0                    0
# 2                 NaN               1              0                    0
# 3                 red               0              0                    0
# 4                blue               0              0                    1
# ...               ...             ...            ...                  ...
# 19995             red               0              2                    0
# 19996            blue               0              0                    1
# 19997            blue               0              1                    1
# 19998            blue               0              0                    1
# 19999             NaN               0              0                    0
#
#        ...  2ELDER_DRAGONtime  7AIR_DRAGONteam  7AIR_DRAGONtime  \
# 0      ...                NaN              NaN              NaN
# 1      ...                NaN              NaN              NaN
# 2      ...                NaN              NaN              NaN
# 3      ...                NaN              NaN              NaN
# 4      ...                NaN              NaN              NaN
# ...    ...                ...              ...              ...
# 19995  ...                NaN              NaN              NaN
# 19996  ...                NaN              NaN              NaN
# 19997  ...                NaN              NaN              NaN
# 19998  ...                NaN              NaN              NaN
# 19999  ...                NaN              NaN              NaN
#
#        7WATER_DRAGONteam  7WATER_DRAGONtime  3ELDER_DRAGONteam  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 19995                NaN                NaN                NaN
# 19996                NaN                NaN                NaN
# 19997                NaN                NaN                NaN
# 19998                NaN                NaN                NaN
# 19999                NaN                NaN                NaN
#
#        3ELDER_DRAGONtime  BARON_NASHOR5team  BARON_NASHOR5time soul_team
# 0                    NaN                NaN                NaN       NaN
# 1                    NaN                NaN                NaN       NaN
# 2                    NaN                NaN                NaN       red
# 3                    NaN                NaN                NaN       NaN
# 4                    NaN                NaN                NaN       NaN
# ...                  ...                ...                ...       ...
# 19995                NaN                NaN                NaN       NaN
# 19996                NaN                NaN                NaN       NaN
# 19997                NaN                NaN                NaN       NaN
# 19998                NaN                NaN                NaN       NaN
# 19999                NaN                NaN                NaN       NaN
#
# [20000 rows x 109 columns]

# %%
#df of match results extracted from dict with dragon soul feat added
df_results = pd.read_csv('data/df_results.csv', index_col=0)

# %%
df_results
# Out:
#             GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088          1195    red        red            red         red
# 3435528193          1516   blue       blue            red         NaN
# 3447586821          1964   blue        red            red         red
# 3426877449           915    red        red            NaN         red
# 3419144205          1176    red        red            red         red
# ...                  ...    ...        ...            ...         ...
# 3444742545          1326    red        red            red         red
# 3424164242          1915   blue       blue           blue        blue
# 3405814162          1208    red        red            red        blue
# 3419838867          1305   blue       blue           blue        blue
# 3447495054          1658    red        red            red         red
#
#            firstRiftHerald  baronKillsdiff  riftHeraldKillsdiff  \
# 3411673088            blue               0                    1
# 3435528193             NaN               0                    0
# 3447586821             NaN               1                    0
# 3426877449             red               0                   -1
# 3419144205            blue               0                    0
# ...                    ...             ...                  ...
# 3444742545             red              -1                   -1
# 3424164242            blue               1                    1
# 3405814162            blue               0                    0
# 3419838867            blue               0                    2
# 3447495054            blue               0                    2
#
#             dragonKillsdiff  FIRE_DRAGONdiff  EARTH_DRAGONdiff firstBaron  \
# 3411673088               -2             -1.0              -1.0        NaN
# 3435528193                0              NaN               NaN        NaN
# 3447586821               -3             -2.0              -1.0       blue
# 3426877449               -2              NaN              -1.0        NaN
# 3419144205               -2             -1.0               NaN        NaN
# ...                     ...              ...               ...        ...
# 3444742545               -3             -1.0              -1.0        red
# 3424164242                1              NaN               1.0       blue
# 3405814162               -1              1.0              -1.0        NaN
# 3419838867                3              1.0               1.0        NaN
# 3447495054               -2              NaN              -1.0        NaN
#
#            FIRE_DRAGONSoul  AIR_DRAGONdiff  ELDER_DRAGONdiff  \
# 3411673088             NaN             NaN               NaN
# 3435528193             NaN             NaN               NaN
# 3447586821             red            -1.0               1.0
# 3426877449             NaN             NaN               NaN
# 3419144205             NaN             NaN               NaN
# ...                    ...             ...               ...
# 3444742545             NaN            -1.0               NaN
# 3424164242             NaN             1.0               NaN
# 3405814162             NaN             NaN               NaN
# 3419838867             NaN             NaN               NaN
# 3447495054             NaN             NaN               NaN
#
#             WATER_DRAGONdiff EARTH_DRAGONSoul WATER_DRAGONSoul AIR_DRAGONSoul
# 3411673088               NaN              NaN              NaN            NaN
# 3435528193               NaN              NaN              NaN            NaN
# 3447586821               NaN              NaN              NaN            NaN
# 3426877449              -1.0              NaN              NaN            NaN
# 3419144205              -1.0              NaN              NaN            NaN
# ...                      ...              ...              ...            ...
# 3444742545               NaN              NaN              NaN            NaN
# 3424164242              -1.0              NaN              NaN            NaN
# 3405814162              -1.0              NaN              NaN            NaN
# 3419838867               1.0              NaN              NaN            NaN
# 3447495054              -1.0              NaN              NaN            NaN
#
# [20275 rows x 19 columns]

# %%
int(match_detail_dict[3447355549]['gameDuration']/60)
# Out:
# 32

# %%
len(match_timeline_dict[3447355549]['frames'])
# Out:
# 34

# %%
match_timeline_dict[3447355549]['frames']
# Out:
# [{'participantFrames': {'1': {'participantId': 5,
#     'position': {'x': 560, 'y': 581},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '2': {'participantId': 1,
#     'position': {'x': 560, 'y': 361},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '3': {'participantId': 3,
#     'position': {'x': 351, 'y': 293},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '4': {'participantId': 4,
#     'position': {'x': 221, 'y': 471},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '5': {'participantId': 2,
#     'position': {'x': 311, 'y': 649},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '6': {'participantId': 6,
#     'position': {'x': 14486, 'y': 14511},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '7': {'participantId': 10,
#     'position': {'x': 14486, 'y': 14291},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '8': {'participantId': 7,
#     'position': {'x': 14277, 'y': 14223},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '9': {'participantId': 8,
#     'position': {'x': 14147, 'y': 14401},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0},
#    '10': {'participantId': 9,
#     'position': {'x': 14237, 'y': 14579},
#     'currentGold': 500,
#     'totalGold': 500,
#     'level': 1,
#     'xp': 0,
#     'minionsKilled': 0,
#     'jungleMinionsKilled': 0,
#     'dominionScore': 0,
#     'teamScore': 0}},
#   'events': [],
#   'timestamp': 0}]

# %%
#text_file = open("high_elo_accIds.txt", "w")
#text_file.write()
#text_file.close()

# %%
p.save_txt(str(match_stats_dict), 'data/match_stats_dict.txt')

# %%
p.pkl_file(match_dict, 'data/match_dict.pkl')

# %%
p.pkl_file(high_elo_accIds, 'data/high_elo_accIds.pkl')

# %%
p.pkl_file(match_detail_dict, 'data/match_detail_dict.pkl')

# %%
p.pkl_file(match_stats_dict, 'data/match_stats_dict.pkl')

# %%
p.pkl_file(match_timeline_dict, 'data/match_timeline_dict.pkl')

# %%
p.pkl_file(matchlist, 'data/matchlist.pkl')

# %%
p.pkl_file(list_time_dicts, 'data/list_time_dicts.pkl')

# %%
p.pkl_file(match_results_dict, 'data/match_results_dict.pkl')

# %%
p.pkl_file(gamestate_by_time_dict, 'data/gamestate_by_time_dict.pkl')

# %%
p.pkl_file(filled_gamestate_by_time_dict, 'data/filled_gamestate_by_time_dict.pkl')

# %%
p.pkl_file(best_clf, 'data/best_clf.pkl')

# %%
len(match_detail_dict)
# Out:
# 20275

# %%
len(match_timeline_dict)
# Out:
# 28627

# %%
df.to_csv('data/match_stats_df.csv')

# %%
df_results.to_csv('data/df_results.csv')

# %%
df_filled.to_csv('data/df_filled_results.csv')

# %%
def rand(to_shuffle):
    '''
    Shuffle a copy without disturbing original list
    '''
    shuffled_copy = to_shuffle.copy()
    random.shuffle(shuffled_copy)
    return shuffled_copy

# %% [markdown]
# <a id='query'></a>
# # Extracting data from Riot API:
#
# [Riot API](https://developer.riotgames.com/apis) only allows for extraction of match IDs through user accounts, not through elo rankings and times. A list of high elo matches were obtained by extracting summoner names of high elo ranks and compiling a list of their most recent matches. The [riotwatcher wrapper API](https://riot-watcher.readthedocs.io/en/) was used to facilitate extracting data.
#
# ## Summoner names
#
# Get a list of players in high elo ranks (Master, Grandmaster, Challenger)

# %%
# golbal variables
api_key = 'RGAPI-14651911-2597-416c-9c96-63fa72f1a5bb'
watcher = LolWatcher(api_key)
my_region = 'na1'
queue_type = 'RANKED_SOLO_5x5'

# %%
#get list of high elo players
chall_players = watcher.league.challenger_by_queue(my_region, queue_type)
master_players = watcher.league.masters_by_queue(my_region, queue_type)
GM_players = watcher.league.grandmaster_by_queue(my_region, queue_type)

# %%
#compile list of summoner IDs for list of high elo players
high_elo_summonerIds = []
for entry in chall_players['entries']:
    high_elo_summonerIds.append(entry['summonerId'])
for entry in master_players['entries']:
    high_elo_summonerIds.append(entry['summonerId'])
for entry in GM_players['entries']:
    high_elo_summonerIds.append(entry['summonerId'])

# %%
chall_players
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': 'c60807e8-6afb-38fd-ab9b-ae8588dc8b27',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Kha'Zix's Warriors",
#  'entries': [{'summonerId': 'aKgW_wqkTJ-nkuMnAzmcNjdlsWCFRlACgLFdttNBWvKcZIc',
#    'summonerName': 'Kandori',
#    'leaguePoints': 841,
#    'rank': 'I',
#    'wins': 224,
#    'losses': 187,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bE44fVre61r8szwuoOjlDx3_29SkNDH9qslIPoIX6MdNQXyN',
#    'summonerName': 'ADCADC123',
#    'leaguePoints': 1160,
#    'rank': 'I',
#    'wins': 344,
#    'losses': 277,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KouvFsnpxQ9H91W09mioR_0-qS0wduVKPLpjnIZUWdLuT3to',
#    'summonerName': 'Kral Closer',
#    'leaguePoints': 979,
#    'rank': 'I',
#    'wins': 313,
#    'losses': 268,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'QhGwGPOLg2fT2wdonRDW-LdFok_2Ebr-zeYOHO42wIW0e_g',
#    'summonerName': 'Quantum',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 453,
#    'losses': 434,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'ZwW1SOTDTxVbV-Ye6VPSWtdqaYHBD5jQaiReMRSUaFaBKe0',
#    'summonerName': 'Shoryu',
#    'leaguePoints': 565,
#    'rank': 'I',
#    'wins': 85,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1eqhGj1MZNDw7qFNtO2Out1E7K7LnF-vI_qwWIGgdp9D2cc',
#    'summonerName': 'Ina',
#    'leaguePoints': 959,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 95,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'H2MJBiFUfDLnWCaJlEIwdvzeEC412VkurUGxflxp24eb_TO2',
#    'summonerName': '10 lQ PLAYER',
#    'leaguePoints': 812,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 109,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'e5swbR4oydDzg6lEoC0TrApupACn65g6YsKf53uCe6GKnKs',
#    'summonerName': 'Jozyy',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 387,
#    'losses': 352,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3pOnv87a5zRsKX0upMG0tBBxQHmZhPKTFCzgWekMog',
#    'summonerName': 'Pobelter',
#    'leaguePoints': 579,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'B1Zfd2aJnRNoKXZgd2VaI6X9AJEj-bGkSoA2iCNP1IOzMAg',
#    'summonerName': 'TSM Sword',
#    'leaguePoints': 802,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 265,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AoE1AAMweHwDtCIrRaiZp6JFI8LHjb-_n1utPmdc-vRYTns',
#    'summonerName': 'Viel Glück',
#    'leaguePoints': 478,
#    'rank': 'I',
#    'wins': 257,
#    'losses': 222,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'YHvhAJ7ab04KDRXIHdxEpj5S1tiBE7oaFr4XtEl6kXCtKPA',
#    'summonerName': 'godrjsdnd',
#    'leaguePoints': 643,
#    'rank': 'I',
#    'wins': 526,
#    'losses': 482,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VsXBtET0L1F-BfpwDtrEWcd8n0XIfE-DFBNE_wytW09quiDZ',
#    'summonerName': 'TL Broxah',
#    'leaguePoints': 678,
#    'rank': 'I',
#    'wins': 351,
#    'losses': 303,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MvsWjTvomGhIwJ0s1hjz7p82ameqPRb_QijJBwnzIoE-LXw',
#    'summonerName': 'Truck Dr1ver',
#    'leaguePoints': 466,
#    'rank': 'I',
#    'wins': 163,
#    'losses': 132,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'l6x7wG61ZOD1LS9_UVMRPVkiYE1zXMh0Ww2ncv2P1EanFog',
#    'summonerName': 'Sakura Poro',
#    'leaguePoints': 443,
#    'rank': 'I',
#    'wins': 339,
#    'losses': 318,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '6UpSjFt5HXYydvnzU5-2zUL2u12y1xRWU8lgnyOldwENyde3',
#    'summonerName': 'adc4funnowhehe',
#    'leaguePoints': 429,
#    'rank': 'I',
#    'wins': 170,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_gsGl1YGAHCdqag9f-hsOp50La1LyKfa3AJI7OLdjBJFZio',
#    'summonerName': 'Busio',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Kz_Zz3Rj-6RjleOUhaF1hXEN9f8cD3-opVAThrbkBAA80lg',
#    'summonerName': 'Saiyans',
#    'leaguePoints': 372,
#    'rank': 'I',
#    'wins': 207,
#    'losses': 183,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iiCPcaJK2x1Z8u7cSYQ-os7CtmkONyVOx9AfdkNR0TFJG8s',
#    'summonerName': 'haru dad',
#    'leaguePoints': 781,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 152,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tO6Qti_4cDKfXl1EwObt299Iifi9gh4cfa3ogDqyX67ci1M',
#    'summonerName': 'Daption',
#    'leaguePoints': 446,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 157,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tT248e_0AI_ymoAYc_-cZSEUKPVpKoAF2GYXiouK_rAV5i0',
#    'summonerName': 'ODD ORANGE',
#    'leaguePoints': 444,
#    'rank': 'I',
#    'wins': 337,
#    'losses': 305,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nzLr6UUKiPn83tgPW9Qu4ntv6az2aYZlWrCT7HTjBcv6P50',
#    'summonerName': 'nams0',
#    'leaguePoints': 532,
#    'rank': 'I',
#    'wins': 435,
#    'losses': 410,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-BQ0otZtb_b2SAAANb1f8WV00qp5mqTzFntJUuK-z9C-cAo',
#    'summonerName': 'DARK WlNGS',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 207,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CIFZeh8oIgHkxuUWEdf7WPfie9e0xGHhNhtW5v_0Qd6itWPE',
#    'summonerName': 'First Kyu',
#    'leaguePoints': 955,
#    'rank': 'I',
#    'wins': 317,
#    'losses': 285,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_C1WGB6t-leQdOq6-clLSstKvi7kt2kbnXoJsm9u1YRFEdw',
#    'summonerName': 'Regedice',
#    'leaguePoints': 568,
#    'rank': 'I',
#    'wins': 491,
#    'losses': 464,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bQ85sk7IU_cVBtOoj1mPEpKDe7S7naKJAnGk9LxPmmHgK64',
#    'summonerName': 'General Sniperr',
#    'leaguePoints': 1036,
#    'rank': 'I',
#    'wins': 340,
#    'losses': 293,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'leD1j6yem93bv3Aiq4G-ZEvdTFWworuFStoVzP2qTTpcuyg',
#    'summonerName': 'Allorim',
#    'leaguePoints': 704,
#    'rank': 'I',
#    'wins': 232,
#    'losses': 211,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VTa04tSRsdPdej0TJN_sRfh5Pq6oGwzfBhLWjc9JbO-Aqg0',
#    'summonerName': 'PantsAreFacebook',
#    'leaguePoints': 717,
#    'rank': 'I',
#    'wins': 209,
#    'losses': 173,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'iLIk9JgvWYYwN9ayj_1XtyHXllybfwfCM4NgaRYYEj_PTVo',
#    'summonerName': 'Yowai',
#    'leaguePoints': 710,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'EsfInPkSXrf45zb7vLGxEHKLR0SYSkW8fTrS4TJFgZcwGX4',
#    'summonerName': 'Dhokla',
#    'leaguePoints': 692,
#    'rank': 'I',
#    'wins': 283,
#    'losses': 263,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Y-MWodN3cQJtzu7jKuUHGeFZYSHAO8qGtgp3cn_BQBJEFF0',
#    'summonerName': 'Tuesdayy',
#    'leaguePoints': 885,
#    'rank': 'I',
#    'wins': 369,
#    'losses': 335,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xpV0RGOkLo6o6nrnu-LzYrYM2X11dJxuBrZDV25s_XGQHHs',
#    'summonerName': 'BusioC',
#    'leaguePoints': 715,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nIIa6q9IKMXRTWLS2v7lvsBba3AcLw5gd2ihxVFwUDcFzxeg',
#    'summonerName': 'From Iron',
#    'leaguePoints': 1176,
#    'rank': 'I',
#    'wins': 400,
#    'losses': 325,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'UhGxjJNXanH3Z_7hnVfFbKXUHi8oE57YXV2nKTK_nmwW64I',
#    'summonerName': 'Deañ',
#    'leaguePoints': 571,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'EgiAj6JhpHXhCabj_MbbOZtxnh2oDicM7jY0rgYhZfg4oBs',
#    'summonerName': 'Kingicepop',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 314,
#    'losses': 294,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XCz4xgfUJEww_WwYjLulg_D-bMj7ay6Ng_6SeFSUiUlh7XVQ',
#    'summonerName': 'Aki no ki',
#    'leaguePoints': 1012,
#    'rank': 'I',
#    'wins': 359,
#    'losses': 243,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '80hYb8uywhBiKM3nkkRTfrgkay8_2KUnwwfw3u-sOsuQtw0',
#    'summonerName': 'RoseThorn',
#    'leaguePoints': 552,
#    'rank': 'I',
#    'wins': 183,
#    'losses': 154,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5cQCEJvN4-TTCXkOoBVE92yHchjzuOp8YhD4eUrS-eb_Az0',
#    'summonerName': 'Tactical',
#    'leaguePoints': 866,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 46,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3QHjUlURvdVjHo14CIWe6dNqj1-7zLhaL7PYBf8qibbGYCU',
#    'summonerName': 'TwTvQuyDepTraiNA',
#    'leaguePoints': 562,
#    'rank': 'I',
#    'wins': 117,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '6K88Z-n0i3F9FiQvhQF-aUWZiBJ01oiRiNguZxYPhVLTNxA',
#    'summonerName': 'jojopyun 15',
#    'leaguePoints': 1253,
#    'rank': 'I',
#    'wins': 418,
#    'losses': 312,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pA-cmbAr737RTHfY62D5rbzWPXlsbGNTiGgdcmklVkDbmjw',
#    'summonerName': 'TwTv JayJLoL',
#    'leaguePoints': 420,
#    'rank': 'I',
#    'wins': 324,
#    'losses': 306,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MOQSFMntg3NwLDJ2t8ylRe9DYHTInPlMCVX6MvEehy7-SY0',
#    'summonerName': 'TiaxWillRuleAll',
#    'leaguePoints': 497,
#    'rank': 'I',
#    'wins': 99,
#    'losses': 57,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'YOEjgVlM76tOiDRphWF1OVadTUUTs3ODFb_MCR3rddtDvHQ',
#    'summonerName': 'Dragønmin',
#    'leaguePoints': 446,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 171,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '_OnIdGjoUs72tQVBImwg68fppO8VJ3HY6HOBmNWthl-dCC9S',
#    'summonerName': '3x3n',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 360,
#    'losses': 322,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '92JvWOVsVrKY0bDrEGBP8xf0poCLOHzKu6FtJNicULMH',
#    'summonerName': 'aphromoo',
#    'leaguePoints': 662,
#    'rank': 'I',
#    'wins': 245,
#    'losses': 221,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PPAZwtZcw7FowY8GClOzqwU4f_Yq-BwI3lFb9ZBDYTxWYdfo',
#    'summonerName': 'Spirax',
#    'leaguePoints': 462,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '52dH5g-VqvhFDWaGCD5v0dOCa-8Xf-OdPzZBbKOMb9OYVs0',
#    'summonerName': 'Neøø',
#    'leaguePoints': 1204,
#    'rank': 'I',
#    'wins': 225,
#    'losses': 181,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PXQnIDRnT62TSc-cmldfuIqW04oUvqwfDsEq1CqlIZtkjqs',
#    'summonerName': 'duoking1',
#    'leaguePoints': 739,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 166,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '9jm3AhBA4fKouYfzschk00WpCUrwuSZWNjjCp1q3nm-ifD0',
#    'summonerName': 'airjelly',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 273,
#    'losses': 197,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fee3xnQIk4h7OCt5M5IA7m42nEnMriQ0Uy6UGGn_aZDbvMI',
#    'summonerName': ' Sudzzi',
#    'leaguePoints': 513,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 122,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Oz2KHFhN5F-RBaU2aHiMTaOdCRPXUxHoO0g59_AOampZeDBq',
#    'summonerName': 'C9C9C9C9C9',
#    'leaguePoints': 843,
#    'rank': 'I',
#    'wins': 257,
#    'losses': 220,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vLsfNxDEbXcdx_SEPWj-6O3LCDX4bojNXpTaY_1gDo-vDVYD',
#    'summonerName': 'WX HREB2020',
#    'leaguePoints': 664,
#    'rank': 'I',
#    'wins': 197,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'DZXRv3knoWXYzturphi-LCOsu9Vt-XzyNNEj0exVtKmWAiI',
#    'summonerName': 'Strompest',
#    'leaguePoints': 483,
#    'rank': 'I',
#    'wins': 292,
#    'losses': 276,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'nZVyVkF5lY00-4tchPd3E3A-xvFsJVnr0cxAPkuoIwvNU6j4',
#    'summonerName': 'ShendingHelpToNA',
#    'leaguePoints': 446,
#    'rank': 'I',
#    'wins': 200,
#    'losses': 117,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7wDzUdPWUIdVPXpnzFfMjZerjNHnAKYQiK6qGAD7_bmOtX4',
#    'summonerName': 'Qitong1',
#    'leaguePoints': 719,
#    'rank': 'I',
#    'wins': 282,
#    'losses': 233,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'kQzSWeh5opbf7zsECfkd3NgLfipAixETTzjK9hzI4RNYKBs',
#    'summonerName': 'Huckleeberry',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 89,
#    'losses': 58,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'eb5XMqBd4IaNGoddoSmYSkU0a50d8NCRd5ah2K_noYxbGeLR',
#    'summonerName': 'Neo Quá Non',
#    'leaguePoints': 711,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '6rapCvXgaE7m5h51Len14YRe-9vDCZ1QvvJRr4GPoK9vCV0',
#    'summonerName': 'Scyrnn',
#    'leaguePoints': 625,
#    'rank': 'I',
#    'wins': 396,
#    'losses': 365,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PqNHMQTFYf2AvAh6HN73QNtaJQDeLNTlkofjSG0OhH4ltfU',
#    'summonerName': 'goldenglue',
#    'leaguePoints': 644,
#    'rank': 'I',
#    'wins': 198,
#    'losses': 178,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'YHnMqBF4Bb75COACf32Yqx1EYyrkTMUXIuDYcE143gGNE38',
#    'summonerName': 'Kumo9',
#    'leaguePoints': 493,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '8r_hTplRLroFcKjFjM4sq4SmzcueJVIKvhx1IjGXiHcN24U',
#    'summonerName': 'TSM SIGHTSTONE',
#    'leaguePoints': 985,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 93,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'eoM4LJq-bc7Vy09kwh3fKJxnMBhePJ7MqKLGj9MTZiKEq-s',
#    'summonerName': 'Went',
#    'leaguePoints': 1069,
#    'rank': 'I',
#    'wins': 224,
#    'losses': 177,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ooIXahi49GGNEUO9y1JcS6c1J-1Jgz2_0yb7gT_EuYa0fW7E',
#    'summonerName': 'Herald For Death',
#    'leaguePoints': 676,
#    'rank': 'I',
#    'wins': 331,
#    'losses': 241,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XSp30OmSaYQq-f2C1_AStONUApoUA2Egy9vFAd8JGhBKkc4',
#    'summonerName': 'Pants for Mayi',
#    'leaguePoints': 491,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 199,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QyCkZ-VoobG8N_Zykdn2eJjbZgLBBQ4pLIarTAv_ju8mhOI',
#    'summonerName': 'flyq solo',
#    'leaguePoints': 912,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 200,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'R0wC7gYcD7nWkE5fx-e2l0vATHlMswLr1bvClm8xmQcxTopa',
#    'summonerName': 'TwiTv JayJLoL',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 175,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gczAF5jsJPj82VFvWmK_0252gIxFpTHCxmUcuZorisDgKLc',
#    'summonerName': 'qpalzmwoiaj',
#    'leaguePoints': 1256,
#    'rank': 'I',
#    'wins': 504,
#    'losses': 444,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'hV78Xkn5uvyDxUe4lsMrUzu2YPDjj0pKxF78tdNJOxXOGD4',
#    'summonerName': 'Scenari0',
#    'leaguePoints': 551,
#    'rank': 'I',
#    'wins': 133,
#    'losses': 101,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NMXrhFpZxnyEoGGinX85rd96b7cFyX1Huwm5SrW7bgUT51Gb',
#    'summonerName': 'johnnybrav0o',
#    'leaguePoints': 464,
#    'rank': 'I',
#    'wins': 154,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'uRfKSkdrd0SYl1ziDsIIruASCzKC2Ts3DUc_rggXvloFRhE',
#    'summonerName': 'Cute Yue',
#    'leaguePoints': 513,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-rdM8YRq5BpyBPNgyvE1vMeKgkbTiocu07V-VxYa9NYOrO4',
#    'summonerName': 'stuntopolis',
#    'leaguePoints': 537,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'D8N3wnODNHvxZHHbT0Gao_7yxleeYC69aiLh-osA6w7PFWdj',
#    'summonerName': 'Revenge FLY',
#    'leaguePoints': 565,
#    'rank': 'I',
#    'wins': 330,
#    'losses': 289,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xfEHAEaYetiTbViQnRA_gKgOccWWZ-POLfxWwkGiEbCeslU',
#    'summonerName': 'shaneylove',
#    'leaguePoints': 480,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 267,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gokvSqgiFTIPyO4PGttJH05dlGMac1jYseKkZca6EZ7XXKs',
#    'summonerName': 'youknowxz',
#    'leaguePoints': 570,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 64,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'tCcWXhVcZmR3KZ-yv4FmEHafD69ytvuD9jcRSzoUI6ZOiXw',
#    'summonerName': 'WX abc1006156773',
#    'leaguePoints': 496,
#    'rank': 'I',
#    'wins': 210,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'IOYHPN3jxFMpcjm4kUTBkGXyZYTMxQpiyIjhYnDVUqIvaEo',
#    'summonerName': 'Tony Top',
#    'leaguePoints': 548,
#    'rank': 'I',
#    'wins': 275,
#    'losses': 248,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'r9T45WU2JqWThpIbPFyqhW9kpqTcORRLKHy6nxyMMo71_yc',
#    'summonerName': 'Winston4',
#    'leaguePoints': 1393,
#    'rank': 'I',
#    'wins': 384,
#    'losses': 300,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'WKgLuigvrpfTcqXqtdKiyvvs6-4kIS5tUACa9uf8XK55xeag',
#    'summonerName': 'timal',
#    'leaguePoints': 513,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 188,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'b16kMRFLdA6M1alugkfd-VYVinIGy6poQ_Wp4xrBtc4tu0v5',
#    'summonerName': 'Kanav2',
#    'leaguePoints': 959,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'mA0Q7-_sYwqjTzOr2OByo87hZsdO-SklM8GYR48S_vbyv4M',
#    'summonerName': 'Laceration',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 330,
#    'losses': 313,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TTLVQLc31PXxn4gfsGWgtZQ2jA-X_wKqsGhGUp97n-hE278',
#    'summonerName': 'Busio3',
#    'leaguePoints': 515,
#    'rank': 'I',
#    'wins': 229,
#    'losses': 177,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1CvYX3Ie08eKSD9yU4e8rQLh4SuwFOhnQpYjiUBi8wHSyZA',
#    'summonerName': 'youngˉ',
#    'leaguePoints': 733,
#    'rank': 'I',
#    'wins': 226,
#    'losses': 201,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OqI2abUDF4iV93-Ww7NATrf3Iva753D8Jt3krsVCAF0TOeU',
#    'summonerName': 'TopLop',
#    'leaguePoints': 442,
#    'rank': 'I',
#    'wins': 404,
#    'losses': 369,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'hkU5n5K__6H09y1gZo7ZuuqQZ3WT1fWC2PtUjUGMFAzS4hw',
#    'summonerName': 'AltecJohnny',
#    'leaguePoints': 521,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 63,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Z8zG0KqXsmEJfEnvyP-jj4nEAAqJja-pqRomD87uG7NGxCby',
#    'summonerName': 'Rebel ad',
#    'leaguePoints': 631,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 143,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'KxwHh9V1-QAbXlLx1tr9EnWUsB4z1T70Ap98S_VwHXbIann4',
#    'summonerName': 'Myeongjin NA',
#    'leaguePoints': 709,
#    'rank': 'I',
#    'wins': 294,
#    'losses': 259,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'TRGHp9JYZLpXdCKKJgN3tjbd28Ap7i1vYVMBDNw9YxTVOoc',
#    'summonerName': '100 Prismal',
#    'leaguePoints': 586,
#    'rank': 'I',
#    'wins': 259,
#    'losses': 242,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 's5Grh_DPsEzEjdeGGSsULD32SU9mv7q7ufivlE907n9rxys',
#    'summonerName': 'TC porsche',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CNrkubtkqhDM52qNiMGJjPTtuIvpf3W_xxi2zBSPslVn-oI',
#    'summonerName': 'elise player',
#    'leaguePoints': 1002,
#    'rank': 'I',
#    'wins': 608,
#    'losses': 546,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'AYhbGd9Fk7uUZBodUQUmox8ajUMYbvnRxbklsL8lTJV021Ah',
#    'summonerName': 'lMT Eika',
#    'leaguePoints': 857,
#    'rank': 'I',
#    'wins': 426,
#    'losses': 377,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '9aGD64x3bFnEOfLRt2djpeu3LaAVait-mXYOzAHWpaYIbcrs',
#    'summonerName': 'baxaxasd',
#    'leaguePoints': 586,
#    'rank': 'I',
#    'wins': 163,
#    'losses': 135,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'l-_HEc8vmoTxUVp0SWqRhkFnaMRPWzUv7EPMPGK6t71TnBY',
#    'summonerName': 'WayOfTheTempesst',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 129,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'a9XjJuGDr06l_BvTa8gVshZOgiENjRXndCHfS2FJVK9fMkM',
#    'summonerName': 'Damonte',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 153,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7T71S3l_bKUwZ3waURNP8h5dQyCOqhn-x8cR2f-TNjihw7c',
#    'summonerName': 'Yue',
#    'leaguePoints': 511,
#    'rank': 'I',
#    'wins': 80,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'cGyuG6O4X0C7hx3artvFqEDNXV_ORkszQ7HMEqMWyMsEQiE',
#    'summonerName': 'MU Wolfe',
#    'leaguePoints': 559,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 136,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'daAq_QH2pjbAUG6w8hrWegZmCjzNrfBF3uYs2ReGp6bx_7Z_',
#    'summonerName': 'POOMEˉ',
#    'leaguePoints': 742,
#    'rank': 'I',
#    'wins': 277,
#    'losses': 252,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KEdqN4fotUa1T0_kMdsRgCRuF925iBfECm9cXnSg5wtIJwM',
#    'summonerName': 'Doublelift',
#    'leaguePoints': 722,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 216,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'l0mrg9LHAFRrcxksh_00-8QuLWhAD-OD1MaqNkuiPaXTtmY',
#    'summonerName': '37º2',
#    'leaguePoints': 543,
#    'rank': 'I',
#    'wins': 114,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'G1Oq0WJBlnnz8nx5Y2SoIp53IqVnAOHK6NoSfrIjNpdFslM',
#    'summonerName': 'Pocket Rhinooooo',
#    'leaguePoints': 787,
#    'rank': 'I',
#    'wins': 116,
#    'losses': 82,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'S_eaUniKV39EdEG7as1NMvVlJVklduTV2lNhSvhww0GTEPo',
#    'summonerName': 'Humble Diligent',
#    'leaguePoints': 496,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'aOlQLwxtRCtpxgMRKVcE_9-RpBBXoq8cNgTN9ph8P08R4FA',
#    'summonerName': 'Oriku',
#    'leaguePoints': 499,
#    'rank': 'I',
#    'wins': 104,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mEfqF-ax2P2eqhCior07Da3zaFB3YKI_ka4RIMScL-Du0gE',
#    'summonerName': 'C9 Diamond',
#    'leaguePoints': 452,
#    'rank': 'I',
#    'wins': 250,
#    'losses': 253,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SKKwdMJS-_a6eNnAIjjtASwcWVwmxE9z-zkNad9Hg0Yas7c',
#    'summonerName': 'Naraxas',
#    'leaguePoints': 666,
#    'rank': 'I',
#    'wins': 234,
#    'losses': 200,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yHYbduwmu0aeKY3vzrrmKaLqAOGYyMb3h04b4HsUPLQbVKo',
#    'summonerName': 'C9 Manny',
#    'leaguePoints': 458,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EpcroR6CMSUSxfwT8rdEClKYjgo4vydKvPcDyLwxHlqnAsc',
#    'summonerName': 'NøticeMeSenpai',
#    'leaguePoints': 468,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AHAswr3ESzFLLvdnXPtkaVLvcGsaOY86JgLeP7lpAgGbAxI',
#    'summonerName': 'CHlME',
#    'leaguePoints': 426,
#    'rank': 'I',
#    'wins': 339,
#    'losses': 325,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8HXKYZ1PRaDaRJfvG8s5ebyXIdbUTpK4SFiFbZ5TacKJ616p',
#    'summonerName': 'COCAINE OVERDOSE',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 148,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vCyooXnsrORraXP22r64w4ljBXNpHL5NitPJRmFR51oeOsE',
#    'summonerName': 'Gweiss',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 170,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '53Gly0nOb-67_jTlcMZZtw5DN0bbCiEafEEgSlDSv2IKmEQ',
#    'summonerName': 'reniart',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 103,
#    'losses': 78,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Raggw3kkKb0B1ri6WtyzguCDNp0C7UPL3czaNDTYKQZzQ0M',
#    'summonerName': 'C9 VULCANNN',
#    'leaguePoints': 1566,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 130,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Ht_Qa1GKa4_rC0yPw4iNASfnxDwuJWk76CdGzEZ2fCQZQ08',
#    'summonerName': 'Seranok',
#    'leaguePoints': 437,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 128,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8pTPGQTzoqpod4mERZElJxbflqN1GRPgtAvlkTfHAzCWktgj',
#    'summonerName': 'Westopolis',
#    'leaguePoints': 701,
#    'rank': 'I',
#    'wins': 158,
#    'losses': 73,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-xilydWs0WPb1BTNTcTfbOPEpwEEKnXerLX8qSmXN73zy2c',
#    'summonerName': 'Nuri',
#    'leaguePoints': 736,
#    'rank': 'I',
#    'wins': 103,
#    'losses': 65,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'v9DbHGqUCSad71DzLFMupZUZi9pkWLtKUnNUn1bmvqHy',
#    'summonerName': 'Meteos',
#    'leaguePoints': 613,
#    'rank': 'I',
#    'wins': 211,
#    'losses': 197,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bezVPdKgd2l98X1tMHMtuYEJAapFbQPDF35PUoBbXlv9SqA',
#    'summonerName': 'GibIe',
#    'leaguePoints': 813,
#    'rank': 'I',
#    'wins': 242,
#    'losses': 201,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '60M6sJm66h0-hqQ2D74DhnMxyGYXOKOIy8TEbfizAOLKwhI',
#    'summonerName': 'Biofrost ',
#    'leaguePoints': 919,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 161,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'q9kXtuB92CKbf_-KsNqQtxk27ku1lPhATH-MuMSqJYzk_HM',
#    'summonerName': 'Afreeca Kiin',
#    'leaguePoints': 1145,
#    'rank': 'I',
#    'wins': 323,
#    'losses': 283,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'RipVYgMElDEGHgp4l13044hqsLwmZ0B-HWNdDDfrhLBaX1Y',
#    'summonerName': 'Frostynomad',
#    'leaguePoints': 909,
#    'rank': 'I',
#    'wins': 360,
#    'losses': 333,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'naam1WkZVZc4InOyQVNq6dJlXi9_RKrKyShjKR_hE-wBT84',
#    'summonerName': 'VX Arendel',
#    'leaguePoints': 1113,
#    'rank': 'I',
#    'wins': 194,
#    'losses': 143,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_pP4QRyftYFmZ32kQquPqn6omWhfKDfcgV6NxoHtu_rPmPw',
#    'summonerName': 'Acilion',
#    'leaguePoints': 989,
#    'rank': 'I',
#    'wins': 458,
#    'losses': 415,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0n-a8mpZbZhv0-kTL_jC7bTjVkHCoGsb8KJV4krGX_Pi6gA',
#    'summonerName': 'Soulmario',
#    'leaguePoints': 803,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 95,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8kDvhaAdvUDV7GDi1r3QTT5kcbMXAfrnYhA4J0leCAtiQpc',
#    'summonerName': 'Ssumdayday',
#    'leaguePoints': 504,
#    'rank': 'I',
#    'wins': 248,
#    'losses': 213,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'imIzhq5G-ssMyDuoNxrYO0egKdmVY_K9Ppg7YPktoG8tkB0',
#    'summonerName': 'avril adc',
#    'leaguePoints': 688,
#    'rank': 'I',
#    'wins': 475,
#    'losses': 448,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qlZb3pitZi3Q6F24ihAgF71blvM5Rmee92coei03_2Igvlc',
#    'summonerName': 'Zile',
#    'leaguePoints': 557,
#    'rank': 'I',
#    'wins': 277,
#    'losses': 252,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'uwQ2OjvZUuuG1ZzIWfHoiwEE9ovSy4msj0mEmVy9Reom0OCr',
#    'summonerName': 'DISCORD TARZANED',
#    'leaguePoints': 1189,
#    'rank': 'I',
#    'wins': 254,
#    'losses': 193,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pjWl26_UtWoJF4yixUAL6d19-P6Z9t5dKoPLgxmi9kDo8guZ',
#    'summonerName': 'V1per1',
#    'leaguePoints': 1199,
#    'rank': 'I',
#    'wins': 279,
#    'losses': 219,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'W8yCfUTsRUxogiomgnDmFiOMCzmBohdJ0G4yluw2inHQrGBh',
#    'summonerName': '100 Kenvi',
#    'leaguePoints': 728,
#    'rank': 'I',
#    'wins': 412,
#    'losses': 375,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_dcI0PtL4E7Hw4_SreYKemntQm5CXfTDgQVla-EfilOtWhY',
#    'summonerName': 'Nikkone',
#    'leaguePoints': 455,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 146,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '0MyqkXsjnL4bOVlSRvNL1aPH8US9WypZipFyRqyvAHi10TM',
#    'summonerName': 'Wunderful',
#    'leaguePoints': 503,
#    'rank': 'I',
#    'wins': 528,
#    'losses': 472,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'sc3box11Aql79RgMx5K6U4GVV4VRaaOEO7F68Ymp9NvxqPs',
#    'summonerName': 'T Last Dance',
#    'leaguePoints': 561,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 137,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fcyFsJ47WYtQ3Ispg3RfRHo6RTLOvojtvva56Tu_rFQ7wRY',
#    'summonerName': 'Gabyyz',
#    'leaguePoints': 494,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '9I9Rq4RDbNNSfdJvGFcKD_PXCwO7krOBCNC6h194Js0-a-Q',
#    'summonerName': 'Joey2',
#    'leaguePoints': 435,
#    'rank': 'I',
#    'wins': 347,
#    'losses': 327,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'HfcWIpQ3dHOf0Pciikl_SjcdnyvPfA4lcLdYmEfwcPfT52E',
#    'summonerName': 'Just Chatting',
#    'leaguePoints': 624,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 258,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'p0bp2jWmpXUOXfdkDLyONk5mOGdw492oJDmkEIHTIA_xcvw',
#    'summonerName': 'Master Yoshii',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 137,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Uv5VL_Yg6aEyXJiPaTFLSe98_qp6asPXYicu8GPkjtq7cdE',
#    'summonerName': 'NILES 1V9 ',
#    'leaguePoints': 599,
#    'rank': 'I',
#    'wins': 184,
#    'losses': 148,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0wvd-Zy-IIhJ6bsXLG-5ghwy6YWBzIuI-m1Unyb8MvvthiA',
#    'summonerName': 'stupid123',
#    'leaguePoints': 974,
#    'rank': 'I',
#    'wins': 411,
#    'losses': 371,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'fhS_-ep3XCt-P37KjWbR78FipHNeOkJcaoB9mOYUNzJEVSA',
#    'summonerName': 'Blower',
#    'leaguePoints': 449,
#    'rank': 'I',
#    'wins': 139,
#    'losses': 120,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'y2QwLcjUM56ISCruD0IZLIKkySC049Nc4iNPEKqbQvGQBSY',
#    'summonerName': 'nonononononono',
#    'leaguePoints': 470,
#    'rank': 'I',
#    'wins': 488,
#    'losses': 462,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'alzJ1CNyN_whJqzN0vKQcIf_QO7rM5XGXLV3sB2ggcXRy2s',
#    'summonerName': '20200120',
#    'leaguePoints': 1018,
#    'rank': 'I',
#    'wins': 201,
#    'losses': 156,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'UFseqcI9LxsRexOZ-OQPdBb9HRlfo8TilD5rssphrOrRhys',
#    'summonerName': 'TEAMLUKEE',
#    'leaguePoints': 814,
#    'rank': 'I',
#    'wins': 376,
#    'losses': 339,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'z-OH5HfrG8JiPzF2BjH9Q61lIEazETd-xKRmvJPaNAXJ4_A',
#    'summonerName': 'ybooks',
#    'leaguePoints': 389,
#    'rank': 'I',
#    'wins': 213,
#    'losses': 195,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'MNzl2uWONOqVJOD14OJgd6PyyvbqrCKXaHnYPUTcVOsKfaRt',
#    'summonerName': 'xprz',
#    'leaguePoints': 582,
#    'rank': 'I',
#    'wins': 326,
#    'losses': 287,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jpRR9uBVKgiiH7AdzcHo6rr-HHM5kyzSVC4gVTxpB8PhQhYv',
#    'summonerName': 'haburu24',
#    'leaguePoints': 740,
#    'rank': 'I',
#    'wins': 307,
#    'losses': 263,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rHvBvMvkGwdNYP-PD5KhP5GFKqjYf5OwCuVMrCfC-q8pu1M',
#    'summonerName': 'SLAY THEM',
#    'leaguePoints': 627,
#    'rank': 'I',
#    'wins': 82,
#    'losses': 54,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8JRqjtOPHnUAiI05z6rf5ItuaBQEOOtsO_0G7hvEPmYnqUOI',
#    'summonerName': 'fim od esdjrf up',
#    'leaguePoints': 384,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 196,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'niFYWj9UFvA5MslnroCpDIXKwi5umOcA-RNxwyyAF_40-Ws',
#    'summonerName': 'IU TV',
#    'leaguePoints': 551,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 147,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AYZ9Y6i6S3cyDZuP3lJEvcFmF51z8pR-n7yah7u__TsK9sxp',
#    'summonerName': 'Kenv1',
#    'leaguePoints': 584,
#    'rank': 'I',
#    'wins': 250,
#    'losses': 208,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'lc2MCmnLjkL9FW4hyWF3jCy7UC09pHUmu091fQHpWGk_trY',
#    'summonerName': 'Skade',
#    'leaguePoints': 718,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 95,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AHoCv6u0LH2uLfoEYTPDbj9TZJg9vmtGd_n739IZ62E9xqI',
#    'summonerName': 'WayneDwops',
#    'leaguePoints': 461,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 119,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_4SPSVqwjf8cF3wDL7P-XY5Gt0DFFtQfXX-WHt6CX-slms0',
#    'summonerName': 'GG Zion',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 365,
#    'losses': 343,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VVgmtEmO5Xd2lUojt7ggQVTw9ubqXfy_Ozc0jE_Xvl90CWg',
#    'summonerName': 'DCSNT',
#    'leaguePoints': 651,
#    'rank': 'I',
#    'wins': 276,
#    'losses': 197,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0hqyvpUidZT431hYpJnEdzNp-ekjh9lgCYPXA5Zrxzgl6xc',
#    'summonerName': 'BladeGO',
#    'leaguePoints': 1235,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 124,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5XbE2VcQK5IBlGlPGMzEhLfSaWxdR1bM0z9NIAPpqh4QWEo',
#    'summonerName': 'Hyami',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 153,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KCaxEZfxKMhhqItYIFMLzJFtmoQA6DA7Cv5eLCatr1Lzt6ge',
#    'summonerName': 'Skohh',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9Zrbp285eyFkzIvlB1CFqQ7T9hY6zK1FMbyZCIIDHu5yL2U',
#    'summonerName': 'ikero',
#    'leaguePoints': 471,
#    'rank': 'I',
#    'wins': 222,
#    'losses': 166,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CSUIjnjLrZzUnPOYnO-jZnhD3JVHYoF8Qr9OMok8VoogAtTG',
#    'summonerName': 'IllIlIlIl',
#    'leaguePoints': 1289,
#    'rank': 'I',
#    'wins': 119,
#    'losses': 60,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'hjffGQZevVL9Gp8U5UGg37q-7kh9xMBWtfxnRIMc6vk',
#    'summonerName': 'SentientAI',
#    'leaguePoints': 516,
#    'rank': 'I',
#    'wins': 330,
#    'losses': 314,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vzeyIxXMECHdv_0JzjCprIF3qxZe_QQh2R2Wt1O1A4jIYNY',
#    'summonerName': 'SDzgFdfgy',
#    'leaguePoints': 581,
#    'rank': 'I',
#    'wins': 296,
#    'losses': 272,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oZn0pbNHdcMkrw2QMpLfaGjtqMZWZ1hm1bDpcUqumEdKUYk',
#    'summonerName': 'Magı',
#    'leaguePoints': 638,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'xg5qhcIQCierBuPhNrBcV4hOfUOgd1QYjMWn7tPmwFVKZUE',
#    'summonerName': 'Revenge',
#    'leaguePoints': 509,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 158,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '4IqLEj_Vt1nCKa1L6LzFHS0IUXAE6BNcNVa4s7NvJUDVbNo',
#    'summonerName': 'mn 97',
#    'leaguePoints': 654,
#    'rank': 'I',
#    'wins': 307,
#    'losses': 289,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'HcN7imzvsMD4f0vi3WVsOa2RRVUmQbI4EK9PMrduGkf0E8A',
#    'summonerName': 'Stixxay',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 240,
#    'losses': 219,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NhfT3tcI2-EAAmm0kgE1zc1GvIZlyzjgqC6e45g-JRd76DI',
#    'summonerName': 'T1 HOT RUFFLES ',
#    'leaguePoints': 510,
#    'rank': 'I',
#    'wins': 191,
#    'losses': 152,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'iPHOfqujpxQM3Y3iWydkO96IC3ggT7YjYCvGL6UDTd_Fiys',
#    'summonerName': 'BootySIapper',
#    'leaguePoints': 460,
#    'rank': 'I',
#    'wins': 287,
#    'losses': 259,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Gq1xaRY3OmjgaizrTKH5xJ6B7JyKVFkAHdGRfhFJCCUvgQ4',
#    'summonerName': 'Michael Jordan22',
#    'leaguePoints': 687,
#    'rank': 'I',
#    'wins': 218,
#    'losses': 170,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CxRy5nVCUvU-3kIuRKtu9847Kl4V_d-qnjL_bnVlFsVxETsq',
#    'summonerName': 'Cozy Shroud',
#    'leaguePoints': 573,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 111,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MZrA38v-HxKT3iQ3FwJVdafUytv6kjNvIOVMOdeelmT0zQw',
#    'summonerName': 'dog2',
#    'leaguePoints': 495,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 218,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zUxj0PMhWc9joQyszZL26tHVoYzft2nY4DStM70TY7Ln0RQ',
#    'summonerName': 'Double Deans',
#    'leaguePoints': 433,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ry6ZceKgP1l3cnIVONEGqJ7EX4B84emjaz2B9-9Ob11CWew',
#    'summonerName': 'Bíg T',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 175,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gOXb44J7-3PXV3HlydmRG7_bAPiE8KbdlnNWAubyAYRxSAM',
#    'summonerName': 'Detention',
#    'leaguePoints': 652,
#    'rank': 'I',
#    'wins': 149,
#    'losses': 122,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'recnpwZW-cuwsE6AWGsAziaK8EJrf9ISZfU-TDewJ8t9dwct',
#    'summonerName': 'The Mr Bad',
#    'leaguePoints': 443,
#    'rank': 'I',
#    'wins': 408,
#    'losses': 362,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'AM748dHASWC3pLjVYJvETVDqpEhrTI5sXAtuMKg-qGHDJrg',
#    'summonerName': '07 06 00',
#    'leaguePoints': 591,
#    'rank': 'I',
#    'wins': 127,
#    'losses': 98,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'SdqO-Q6P2V07tFSUmh4-a7pHw10DcMyL4JfnntT3q5HzPqA',
#    'summonerName': 'Shupian',
#    'leaguePoints': 436,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 158,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Cws2ifs9BPS9bzPYXCL7QjD2RXtxWCrG7BhtsYK2JwltSsI',
#    'summonerName': 'CptShrimps',
#    'leaguePoints': 725,
#    'rank': 'I',
#    'wins': 444,
#    'losses': 410,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'YY3J1arTYf-nP9JbJ1pNL_i4UniJJA8eFTwYTpJ_GystLVo',
#    'summonerName': 'evoN',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 93,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jra8Gz1qLG72e6cpnHq-liD9ailiPa4i5jZmxiw4Xfg6PytM',
#    'summonerName': '02 13 2001',
#    'leaguePoints': 471,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 183,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Taa_zLIDe_iXtI4DNXBfc3RIFC13-ZeAonhVJCS1k0JtZkMQ',
#    'summonerName': 'Kaiming Yige',
#    'leaguePoints': 456,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 202,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xyTh15FqtNNIc212yDixI7pX9rRee9PHEgK2-k7zg3FbDT8',
#    'summonerName': 'fwii',
#    'leaguePoints': 582,
#    'rank': 'I',
#    'wins': 86,
#    'losses': 71,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'YRlThmol7-cvRdDSnldYgbW_wIAvgL7qD3qRCPaPCql7rj4',
#    'summonerName': 'Spawwwwn',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 266,
#    'losses': 246,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XlTzgsa11KAhg6KrCpPr5xF3tAKAbc8k7e-SUyeqWNsJRbE',
#    'summonerName': 'Andybendy',
#    'leaguePoints': 906,
#    'rank': 'I',
#    'wins': 303,
#    'losses': 255,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'h7KeBFnt6GyHDltIC2fRtR8b2d92jW9R7bQ_TNGhfqQ0c94',
#    'summonerName': 'VX ryanmeng',
#    'leaguePoints': 505,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 121,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
# ...
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wH1JKUWnrEsqQkb8QOzaDpWwqf-LiwSG5FPAoCJc830Cexw',
#    'summonerName': 'wannabezoomer',
#    'leaguePoints': 443,
#    'rank': 'I',
#    'wins': 84,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sd2ViDK6hv0GbVz-Ft63WrRug2dgQNi_APOhLSqfgFMa',
#    'summonerName': 'Ablazeolive',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 189,
#    'losses': 169,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IHDO35quduz8nM_fXSOnW1roydWrfF3Or9Qbm1CooJJ9u6E',
#    'summonerName': 'ChuChuZ',
#    'leaguePoints': 460,
#    'rank': 'I',
#    'wins': 439,
#    'losses': 401,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9Y0oayia7RMG71WdKrfeLnTUWV7vreawYfsH3ZgevW7qpaGD',
#    'summonerName': 'WX Rika19981209',
#    'leaguePoints': 519,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TmO3R2oR39p2TZSyJyPUdrQEMOd0uMynjXS3ZIds-XJqz-wM',
#    'summonerName': '961216',
#    'leaguePoints': 456,
#    'rank': 'I',
#    'wins': 379,
#    'losses': 313,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'M41pqEv-DeGr3ITSSkGSR5uS5tUODDbG_Qm-_LoN8JwCsy8',
#    'summonerName': 'DoughnutDrew',
#    'leaguePoints': 425,
#    'rank': 'I',
#    'wins': 292,
#    'losses': 273,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tn-wrurzacELGoqlColLx6R4XXsXuLc0FTvwkLZHXC2z8Iw',
#    'summonerName': 'Ezepoon',
#    'leaguePoints': 578,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 100,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'oEUNbd1holOo8A3UqDXlaVnCPmbi4dS90DSNb0hqiYShZCY',
#    'summonerName': 'K for Kimchi',
#    'leaguePoints': 751,
#    'rank': 'I',
#    'wins': 271,
#    'losses': 235,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zxVHYlKa_favQHrOnH-lVJfcNRYadSUfj4kulA6EhI6NXRQ',
#    'summonerName': 'Nim Chimpsky',
#    'leaguePoints': 494,
#    'rank': 'I',
#    'wins': 258,
#    'losses': 238,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1l4RQlY9Jyk7caSq2jroLuvLQcEBVuRt92MqBiAcZvhJqxY',
#    'summonerName': 'AnAnorexicPanda',
#    'leaguePoints': 531,
#    'rank': 'I',
#    'wins': 131,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'gAefix6eUQptnLgSNwAGrzfhWVDH_iNGr2XisYpPxnjZ-dY',
#    'summonerName': 'Cupic',
#    'leaguePoints': 800,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 140,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'olLA7CS9iyW97GsGea97kaYv7HrQLTrIZzvb5-WDLepQs7k',
#    'summonerName': 'TSM Bjergsen',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 263,
#    'losses': 229,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nawQPzPSwaWtmt6Nh0ZeKG3BDLQsvL7VbI3__nBUL2lOsT0',
#    'summonerName': 'PANTS GAREN ONLY',
#    'leaguePoints': 907,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 146,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RL_FRRxK2m8m-56jvOSKiLfzUSUt4p5-DrDNQr7rwk5pygY',
#    'summonerName': 'social distance6',
#    'leaguePoints': 685,
#    'rank': 'I',
#    'wins': 295,
#    'losses': 272,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1X4H9guwDFRxZoc9OvPIm8C9llcBx9O91DVhuEvuxSP6pbUy',
#    'summonerName': 'qwefdsasw',
#    'leaguePoints': 567,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 145,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'iJdgzLroncPcdawF9kxOP47QRTFxwOajKu5c0S61LC3hD_q4',
#    'summonerName': 'Son',
#    'leaguePoints': 517,
#    'rank': 'I',
#    'wins': 102,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vBZj1v2s9_ctl4XQfoLZFZ8AQVNcwn3WMYFWog8CSkKi6Gz8',
#    'summonerName': 'ValorantOverLoL',
#    'leaguePoints': 446,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'xNfDU2jqUldjuXYkr8XdULxxxWpP3Gw_DNWyT1wyvPVAQLk',
#    'summonerName': 'Teamfighting',
#    'leaguePoints': 585,
#    'rank': 'I',
#    'wins': 111,
#    'losses': 80,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oem2lqJ1zAOWiAP3a_X6bRI6gHF4MzVn8_9t-amWnclZZME',
#    'summonerName': 'Shower D0G',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 166,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Dq6kxi1nt1V1GbFmSmtd_M9GF3g-CHvtyD7ZqOcMsSgkgSE',
#    'summonerName': 'VX  lovemyjanna',
#    'leaguePoints': 859,
#    'rank': 'I',
#    'wins': 95,
#    'losses': 53,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2gy6Fnxi8_qEr-0WVQjvN-LrewAJMIqCvdhxUVG0BficUdM',
#    'summonerName': 'Reppy',
#    'leaguePoints': 756,
#    'rank': 'I',
#    'wins': 208,
#    'losses': 176,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KGCwkg4azk8P1MNTaBGtNXVUXBhNZMBw7EN_pTUG5Ft4sEE',
#    'summonerName': 'TheRealPhilip',
#    'leaguePoints': 563,
#    'rank': 'I',
#    'wins': 500,
#    'losses': 467,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'lCwpFM9GYKaxL4tJSe_T-f2eMK4l2QKkPSsS5KsfV-BknYw',
#    'summonerName': 'j1hù1V',
#    'leaguePoints': 1194,
#    'rank': 'I',
#    'wins': 341,
#    'losses': 279,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '3WZDiMDTrGgX3BWfzbnBOkTGTdEZzOLxod43gi8CnNkV53vn',
#    'summonerName': 'VX HREB2020',
#    'leaguePoints': 946,
#    'rank': 'I',
#    'wins': 167,
#    'losses': 67,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'LBszf8NRJkFZiiVuWeFrXS3cHhbEv5c3N-dl-jyegMVMiS8',
#    'summonerName': 'IceSnowClever',
#    'leaguePoints': 552,
#    'rank': 'I',
#    'wins': 408,
#    'losses': 386,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1mBrCS2zuCvozbiUC-Gvs5zoUvrHYqA-rkL1S-ubQ7iHVRI',
#    'summonerName': 'Ekko dà mó wáng',
#    'leaguePoints': 596,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 181,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zD8RYBXhimACeQottMyYEiexpzYXDCsc6xiBSh_NCRpWHBg',
#    'summonerName': 'Uma Jan pupil',
#    'leaguePoints': 668,
#    'rank': 'I',
#    'wins': 410,
#    'losses': 370,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'FTZ6hwYUHQs4oOyxxs3aPLAC-ZkFWdWqN8VM1ep9ACrh',
#    'summonerName': 'Cody Pog',
#    'leaguePoints': 574,
#    'rank': 'I',
#    'wins': 334,
#    'losses': 319,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UzgowcGWmWIcX8fT6b350GsVVMu8JA8VwT99yM2zRzHgXpg',
#    'summonerName': 'TIMMY THICCCCC',
#    'leaguePoints': 533,
#    'rank': 'I',
#    'wins': 223,
#    'losses': 181,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 's8nZ0TMDe4qe9qanSHLFpri_G4fhmjYTEoP8SqP4Y8xRqCKY',
#    'summonerName': 'Dooplíss',
#    'leaguePoints': 660,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 94,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8mVEDUJ-K_YsItZ7ukdM3kJp89hrisUfTMopesr3PL_uUoo',
#    'summonerName': 'Ke Lè',
#    'leaguePoints': 565,
#    'rank': 'I',
#    'wins': 273,
#    'losses': 249,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 't633cFlCRiShVW26nCd_8L4UXLHbFFlPFHVEDfzx9rdZ69k',
#    'summonerName': 'KatEvolved',
#    'leaguePoints': 480,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 136,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'qP37K0kgdBvHvV4dnN-SIjBb_Yw9w14_XYSEjGslA2kMb9M',
#    'summonerName': 'Jeremychu',
#    'leaguePoints': 448,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 147,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'EvHPdQuzWhwT-6jzVz4an-bdMQ5mYVREjFsb8L2w38HLkfE',
#    'summonerName': 'Aizo',
#    'leaguePoints': 439,
#    'rank': 'I',
#    'wins': 354,
#    'losses': 338,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3qsJX434zoBgyhn-n--KBTplYOpuy8egm_dQo8GgLWSp1O0L',
#    'summonerName': 'Pomerzz Poggers',
#    'leaguePoints': 666,
#    'rank': 'I',
#    'wins': 481,
#    'losses': 448,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'XWwHNGszR86sZ0rNoZPXmk_O4BD2cMJIt2pTOicYQlglI2M',
#    'summonerName': 'RoseThorn1',
#    'leaguePoints': 593,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 85,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'sLwoJftn_N0HmRcd1IJqK-XjnYkl_yO2xjH2a73PsUVU4wLq',
#    'summonerName': 'always plan ahea',
#    'leaguePoints': 875,
#    'rank': 'I',
#    'wins': 246,
#    'losses': 192,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fo5S_Nug_EuhgtJsjIeiO5NpLMwzLyTI83DeP1eEGQYFvHc',
#    'summonerName': 'Liquid Impact',
#    'leaguePoints': 869,
#    'rank': 'I',
#    'wins': 325,
#    'losses': 283,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'UHy__AkC9dHTYpf9ZQ-Cd7GyLFIUsLuHYGHcig7YMGKA1dU',
#    'summonerName': 'fox solo',
#    'leaguePoints': 962,
#    'rank': 'I',
#    'wins': 346,
#    'losses': 301,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'M-NniDKIFTtv3iKDFb-sJH15h5AFoC-LehsKxQLhUVNqWpo',
#    'summonerName': 'petitpois facher',
#    'leaguePoints': 849,
#    'rank': 'I',
#    'wins': 193,
#    'losses': 156,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ws2l9wvc1v6zDrYcGeTXGh_olyFy8yWo7_e79CQwpqn0D8U',
#    'summonerName': 'YangTuo QW',
#    'leaguePoints': 556,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 126,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'j5UvYF3D9yxL3CS17dhlIibcvnXaIPHWCHm2z-C145gfiwc',
#    'summonerName': 'GONEBYSPRING',
#    'leaguePoints': 823,
#    'rank': 'I',
#    'wins': 165,
#    'losses': 79,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3wycu8BUpjIBLIadV0C-uKwOS2W2N0nu9ZfSMGWExz9qciY',
#    'summonerName': 'I Will Find You',
#    'leaguePoints': 524,
#    'rank': 'I',
#    'wins': 109,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '0mOoO597G3g1mhvlY3j4lED8Eu1pvYSzcHU-F0P7euLUg-g',
#    'summonerName': '2HERO2',
#    'leaguePoints': 561,
#    'rank': 'I',
#    'wins': 432,
#    'losses': 409,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KttjsgDiJWK_LL0EpkC3fihUZbN7kZqKatOnVeA4wzSLZjQ',
#    'summonerName': 'Pants are Dragon',
#    'leaguePoints': 1013,
#    'rank': 'I',
#    'wins': 132,
#    'losses': 81,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jOFk1OKEe4e0SVsbtM-cz-PGifWL6rZo7arxvWKvp0PTChM',
#    'summonerName': 'Draven696969',
#    'leaguePoints': 642,
#    'rank': 'I',
#    'wins': 261,
#    'losses': 235,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ptDzt732xjy4nNpydh6gJM8nqnnWwV-CsosLHFt_mQ2Wgv8',
#    'summonerName': 'tarzaned fans',
#    'leaguePoints': 726,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 189,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1brdx_3ha0BPBHvx_w05wPZKrtJqliYBSgnpUH6BNRIMroc',
#    'summonerName': 'Fortilux',
#    'leaguePoints': 448,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tH0kj_C5Njt5HzZILDnyGOBT1Fd5mDCdaOOcPXkcGcsEPC8',
#    'summonerName': 'Alaan',
#    'leaguePoints': 485,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ti6A7B9C6cbMBf--wT0FHi8hrssAeisZsxk2CcFWAcOPevA',
#    'summonerName': 'RobbyBob',
#    'leaguePoints': 545,
#    'rank': 'I',
#    'wins': 97,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bJ32UApKYgjqIJqcXQP2J8_AFwFvRh2ItG3egmbgigw2Vw0',
#    'summonerName': 'Coco9',
#    'leaguePoints': 453,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '2SyR_PBT82QsSTQMpGZnof2CktaWkic7Vo6kdmOaz1HiW4mu',
#    'summonerName': 'i am one trick',
#    'leaguePoints': 514,
#    'rank': 'I',
#    'wins': 245,
#    'losses': 164,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '41WmtRD7NiUWVPVnYRuQM3xu55SU-4ml2ApLkARQEiLBf2ii',
#    'summonerName': 'Mr Sedulous',
#    'leaguePoints': 842,
#    'rank': 'I',
#    'wins': 215,
#    'losses': 175,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'h-mYJq-2HjxR7d639ZiEPSE_vF0kmGFdlDuw2u1Tj8Tjqd0',
#    'summonerName': 'EG Matt',
#    'leaguePoints': 467,
#    'rank': 'I',
#    'wins': 259,
#    'losses': 239,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3OXIidjrvyEYdVeNzdAHLJVUo73pm2lQQ0o0C5eKcc45PbY',
#    'summonerName': 'c2 meteos',
#    'leaguePoints': 1023,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 225,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CSRG5clkYe8RAopmQspvtPwoylkuxwDmVkG1bKr2biI-z8Q',
#    'summonerName': 'Pekin Woof',
#    'leaguePoints': 643,
#    'rank': 'I',
#    'wins': 226,
#    'losses': 200,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tdgMIUSkVGZdBMdTyOykxorhYnyf37NMKBkAubvSCTncaMw',
#    'summonerName': 'Eclipse',
#    'leaguePoints': 469,
#    'rank': 'I',
#    'wins': 475,
#    'losses': 443,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '5cb-FXp-ePdLZLTkWdAPD-m0vqlIv6U00nj19WvUnvM-q8w',
#    'summonerName': 'Tempos',
#    'leaguePoints': 368,
#    'rank': 'I',
#    'wins': 536,
#    'losses': 528,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Tt7B_Mw5Cd6HLJ-F6sHNYcns2gcf_WfzOesFii-7Drdb2CXb',
#    'summonerName': 'always plan ahe2',
#    'leaguePoints': 572,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 104,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'RzgejZdhrBPSUXbwtNEGXK5v_JKXxzJ9cw_7NRcE4ensCrA',
#    'summonerName': '5fire',
#    'leaguePoints': 993,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 149,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False}]}

# %%
chall_players['entries'][0]
# Out:
# {'summonerId': 'aKgW_wqkTJ-nkuMnAzmcNjdlsWCFRlACgLFdttNBWvKcZIc',
#  'summonerName': 'Kandori',
#  'leaguePoints': 841,
#  'rank': 'I',
#  'wins': 224,
#  'losses': 187,
#  'veteran': True,
#  'inactive': False,
#  'freshBlood': False,
#  'hotStreak': False}

# %% [markdown]
# ## Account ID
#
# Convert summoner ID's to account ID's (to use for obtaining match IDs later)

# %%
watcher.summoner.by_id(my_region, 'aKgW_wqkTJ-nkuMnAzmcNjdlsWCFRlACgLFdttNBWvKcZIc')['accountId']
# Out:
# '_JBrw5ZEaW9y9ABf2VQ9Zwul4lJmTngiuVsm7XznoKHxOw'

# %%
test_accId = '_JBrw5ZEaW9y9ABf2VQ9Zwul4lJmTngiuVsm7XznoKHxOw'

# %%
# %%time
#convert summoner IDs into account IDs to obtain match IDs later
high_elo_accIds = []
for summonerID in high_elo_summonerIds:
    high_elo_accIds.append(watcher.summoner.by_id(my_region, summonerID)['accountId'])

# %%
len(high_elo_accIds)
# Out:
# 1255

# %%
high_elo_accIds
# Out:
# ['_JBrw5ZEaW9y9ABf2VQ9Zwul4lJmTngiuVsm7XznoKHxOw',
#  'hp3wQzf0Qcs5Fnj45_P0AUXBz7-DAYnJUYWKrcbSwCh8urCBpHG-GrrS',
#  '29IxleXM4jPS5T2KmsFdxcbZFZlCCzD4-OQxXI4gURHVse8nyP_OYfYc',
#  'DDzNcXIIaSnXqjFJWjvaOtOqRQoXiohNDAAF9Vv7tU0Gt1k',
#  'DmIsL2U_YfkFvgPHAaNc7gnnei2xALo0CxikkoQ0SGjYhMU',
#  'vKZQmQbwbaA2KWAhnK_pX8CI-G54swj6jHPvB32iIk03aA',
#  'p-FDVXL2PVCuWf4-NyWOwfJsUsTwkmTsdvexpCUwRr0Rqf2J1Siq9IQx',
#  'XYHw7RBsdt4zKlz6vBy6Azhst8yjFubcHSfLcfgt21_m0Q',
#  '49ktgxVhbcxyTXpK-5F4lhsCRzEyLocg7aVKeqy9_Q',
#  'GDjOrucdAH-Eydcm7Rdjmht69RbnVJ-dCLP9gstfMuqndj4',
#  'Wfr7qym3OXhzMhjBxqNzo3N-L0HfHhW0_j4ywWuW7L0XbA',
#  'mq9jRuXgZNXVxDKDMc92HPMZPSmHFF5dNdAbZAMIjntINzk',
#  'GjCSfQ1jcIzOrQ49U8n9oUQaQRBPXpl2Jaj232tQq24xMJAQedSNnoRB',
#  'NGYs92mmMn4U0WnZeYx8X10DlamLMOAKlbLOvLHXVx9YtwE',
#  '3-TmucbFNpODk8hOqAX50o8gVvzUlgFWcHlAy9o2X7L6g70',
#  '1eYnztK2x432-JeNev1eiDIMqLKWFtlE21IINb6pG2XWQs0Z1hq24gjW',
#  'xOlB6nXvNMjW-h81jpuU0bkzwadmidIydQLUcppsRI0RJVA',
#  'vOOeJ_pye8EbVBPcKOeP9LXDIZQ92z6cb6Sxza_k1rR5mw',
#  'BK3NHYNRh0EXUz7SgaucgbDn79dC4N9xqExs80ApZp8Nuuw',
#  'HSwL9yA57iiMfjKZOshxs2qj895An9Ri4cz5N8DUNkBBfg',
#  'b7lwLWp416UdCaojkfNCAA-TjOsY34tU1YlFPZoJtRpACgRr1O_IEP9y',
#  ...]

# %%
#create a randomized list to reduce  any chance of bias
import random
unordered_accIds = high_elo_accIds.copy()
random.shuffle(unordered_accIds)

# %% [markdown]
# ## Matchs
# Compile list of most recent 100 matches for each account ID, then compile the match IDs into a single list of account IDs with no duplicates.

# %%
# %%time
#for all players in high elo, find the match IDs of their most recent games and compile to a set. 
#match_dict = {} #initialize new dictionary

#for each account ID, find a list of their ??10??20?? of their most recent matches 
#and save it to a new dictionary

for acc_ID in unordered_accIds:
    if acc_ID not in match_dict.keys():
        my_matches = watcher.match.matchlist_by_account(my_region, acc_ID)['matches']
        my_matches_list = list(x['gameId'] for x in my_matches)
        #my_matches_list = []
        #for i in range(len(my_matches)):
            #my_matches_list.append(my_matches[i]['gameId'])
        match_dict[acc_ID] = my_matches_list
# Out:
# Wall time: 10min 23s

# %%
matchlist = set()
for acc_ID in match_dict:
    matchlist.update(match_dict[acc_ID])

# %%
len(matchlist)
# Out:
# 67519

# %%
matchlist = list(matchlist)

# %%
my_matches = watcher.match.matchlist_by_account(my_region, me['accountId'])

# %%
my_matches = watcher.match.matchlist_by_account(my_region, test_accId)['matches']
my_matches
# Out:
# [{'platformId': 'NA1',
#   'gameId': 3447355549,
#   'champion': 115,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1591160342189,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3447347793,
#   'champion': 412,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591158041136,
#   'role': 'SOLO',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3447015320,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591143391496,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3446937263,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591139877306,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446970246,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591137387186,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446912575,
#   'champion': 55,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591133624486,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446855076,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591129733148,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446564676,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1591096902765,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446433775,
#   'champion': 202,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591079640505,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3446382969,
#   'champion': 12,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591078521874,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3446265550,
#   'champion': 32,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591072232941,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3446242002,
#   'champion': 39,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591070839023,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3446226114,
#   'champion': 42,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1591069475182,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3444752826,
#   'champion': 92,
#   'queue': 700,
#   'season': 13,
#   'timestamp': 1590979556777,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3444672632,
#   'champion': 91,
#   'queue': 700,
#   'season': 13,
#   'timestamp': 1590976523156,
#   'role': 'DUO_CARRY',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3443958873,
#   'champion': 64,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590928251462,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3443901158,
#   'champion': 40,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590911361180,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3443799401,
#   'champion': 427,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590909952821,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3443831158,
#   'champion': 163,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590906561925,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3443368198,
#   'champion': 157,
#   'queue': 700,
#   'season': 13,
#   'timestamp': 1590896007889,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3443340240,
#   'champion': 134,
#   'queue': 700,
#   'season': 13,
#   'timestamp': 1590893420647,
#   'role': 'DUO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3443139498,
#   'champion': 236,
#   'queue': 700,
#   'season': 13,
#   'timestamp': 1590890282895,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3442877316,
#   'champion': 235,
#   'queue': 440,
#   'season': 13,
#   'timestamp': 1590877865595,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3441767271,
#   'champion': 81,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590797290481,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3441813815,
#   'champion': 64,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590796185358,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3441772095,
#   'champion': 64,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590795302631,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3441718344,
#   'champion': 131,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590793809008,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3438295929,
#   'champion': 64,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590568252141,
#   'role': 'NONE',
#   'lane': 'JUNGLE'},
#  {'platformId': 'NA1',
#   'gameId': 3438264800,
#   'champion': 81,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590566889340,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3438198574,
#   'champion': 107,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590563081301,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3438204757,
#   'champion': 55,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590561289963,
#   'role': 'NONE',
#   'lane': 'JUNGLE'},
#  {'platformId': 'NA1',
#   'gameId': 3438072464,
#   'champion': 81,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590553204560,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3437956759,
#   'champion': 412,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590551286714,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3437904969,
#   'champion': 69,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590550412132,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3437941842,
#   'champion': 64,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590549561497,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3437548546,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590542641533,
#   'role': 'DUO',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3437531203,
#   'champion': 55,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590539949598,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3436969894,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590488717955,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3436496383,
#   'champion': 236,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590459728710,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3436362101,
#   'champion': 57,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590454692213,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3436323645,
#   'champion': 81,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590452322792,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3436191324,
#   'champion': 55,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590443925755,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3435645707,
#   'champion': 79,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590393507313,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3435652738,
#   'champion': 555,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590391932895,
#   'role': 'SOLO',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3435621194,
#   'champion': 26,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590390773169,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3435548984,
#   'champion': 39,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590389493586,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3435575298,
#   'champion': 134,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590388370424,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3434993779,
#   'champion': 39,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590374440454,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3434216162,
#   'champion': 39,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590317890020,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3434205234,
#   'champion': 420,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590316536133,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3434204056,
#   'champion': 69,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590315321259,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3434222158,
#   'champion': 84,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590313751358,
#   'role': 'NONE',
#   'lane': 'JUNGLE'},
#  {'platformId': 'NA1',
#   'gameId': 3434210648,
#   'champion': 202,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590312357339,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3434156847,
#   'champion': 875,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590309678657,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3434161784,
#   'champion': 50,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590306798635,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3434038466,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590300953525,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3433898782,
#   'champion': 37,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590294211873,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3433688558,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590285176012,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3433681845,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590282919591,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3433347305,
#   'champion': 51,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590264865807,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3433330722,
#   'champion': 51,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590261655129,
#   'role': 'SOLO',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3432610494,
#   'champion': 78,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590212666992,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3432421088,
#   'champion': 29,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1590207049603,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3430911015,
#   'champion': 120,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590109027507,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3430837933,
#   'champion': 39,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1590107674182,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3429983152,
#   'champion': 245,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590048968612,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3429919709,
#   'champion': 119,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590046777187,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3429895051,
#   'champion': 58,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1590043885304,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3429351211,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590015631999,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3429241006,
#   'champion': 55,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1590010978559,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3428771055,
#   'champion': 82,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589960370796,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3428668239,
#   'champion': 15,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589958725077,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3428694955,
#   'champion': 203,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589957211047,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3428702571,
#   'champion': 164,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589956200258,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3428679989,
#   'champion': 102,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589955050082,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3428593863,
#   'champion': 412,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589952696051,
#   'role': 'DUO_SUPPORT',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3428385614,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1589944134313,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3428040913,
#   'champion': 517,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1589926050605,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3427984328,
#   'champion': 55,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1589923266798,
#   'role': 'SOLO',
#   'lane': 'MID'},
#  {'platformId': 'NA1',
#   'gameId': 3425676501,
#   'champion': 161,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589784494621,
#   'role': 'DUO_SUPPORT',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3425712358,
#   'champion': 76,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589783186392,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3425659900,
#   'champion': 517,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589781717064,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3425623270,
#   'champion': 79,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1589779712110,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3425545748,
#   'champion': 57,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1589777265977,
#   'role': 'DUO_CARRY',
#   'lane': 'BOTTOM'},
#  {'platformId': 'NA1',
#   'gameId': 3425508143,
#   'champion': 246,
#   'queue': 420,
#   'season': 13,
#   'timestamp': 1589775250362,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3425175413,
#   'champion': 84,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1589762943853,
#   'role': 'SOLO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3425171785,
#   'champion': 145,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589761646212,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3425154367,
#   'champion': 245,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589759710113,
#   'role': 'DUO',
#   'lane': 'TOP'},
#  {'platformId': 'NA1',
#   'gameId': 3425150150,
#   'champion': 120,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589758278108,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3425075640,
#   'champion': 81,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589756707604,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424394192,
#   'champion': 42,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589704097019,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424246439,
#   'champion': 55,
#   'queue': 450,
#   'season': 13,
#   'timestamp': 1589693579554,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424241865,
#   'champion': 79,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589692424184,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424127922,
#   'champion': 68,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589690994218,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424142555,
#   'champion': 134,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589689709493,
#   'role': 'DUO',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3424049681,
#   'champion': 517,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589688729851,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3423856459,
#   'champion': 48,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589679913759,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3423862529,
#   'champion': 120,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589678722224,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3423797850,
#   'champion': 67,
#   'queue': 900,
#   'season': 13,
#   'timestamp': 1589677352848,
#   'role': 'DUO_SUPPORT',
#   'lane': 'NONE'},
#  {'platformId': 'NA1',
#   'gameId': 3423616264,
#   'champion': 26,
#   'queue': 400,
#   'season': 13,
#   'timestamp': 1589673702265,
#   'role': 'DUO_SUPPORT',
#   'lane': 'BOTTOM'}]

# %%
my_matches_list = list(x['gameId'] for x in my_matches)

# %%
my_matches_list
# Out:
# [3447355549,
#  3447347793,
#  3447015320,
#  3446937263,
#  3446970246,
#  3446912575,
#  3446855076,
#  3446564676,
#  3446433775,
#  3446382969,
#  3446265550,
#  3446242002,
#  3446226114,
#  3444752826,
#  3444672632,
#  3443958873,
#  3443901158,
#  3443799401,
#  3443831158,
#  3443368198,
#  3443340240,
#  3443139498,
#  3442877316,
#  3441767271,
#  3441813815,
#  3441772095,
#  3441718344,
#  3438295929,
#  3438264800,
#  3438198574,
#  3438204757,
#  3438072464,
#  3437956759,
#  3437904969,
#  3437941842,
#  3437548546,
#  3437531203,
#  3436969894,
#  3436496383,
#  3436362101,
#  3436323645,
#  3436191324,
#  3435645707,
#  3435652738,
#  3435621194,
#  3435548984,
#  3435575298,
#  3434993779,
#  3434216162,
#  3434205234,
#  3434204056,
#  3434222158,
#  3434210648,
#  3434156847,
#  3434161784,
#  3434038466,
#  3433898782,
#  3433688558,
#  3433681845,
#  3433347305,
#  3433330722,
#  3432610494,
#  3432421088,
#  3430911015,
#  3430837933,
#  3429983152,
#  3429919709,
#  3429895051,
#  3429351211,
#  3429241006,
#  3428771055,
#  3428668239,
#  3428694955,
#  3428702571,
#  3428679989,
#  3428593863,
#  3428385614,
#  3428040913,
#  3427984328,
#  3425676501,
#  3425712358,
#  3425659900,
#  3425623270,
#  3425545748,
#  3425508143,
#  3425175413,
#  3425171785,
#  3425154367,
#  3425150150,
#  3425075640,
#  3424394192,
#  3424246439,
#  3424241865,
#  3424127922,
#  3424142555,
#  3424049681,
#  3423856459,
#  3423862529,
#  3423797850,
#  3423616264]

# %%
test_gameId = 3447355549

# %% [markdown]
# ## Match details
#
# The match details are obtained from 2 API endpoints:
# - match.by_id - gives summary stats of both teams at the end of the game
# - match.timeline_by_match - gives detailed information of all players on each team for every minute of the game

# %%
match_stats
# Out:
# {'Winner': 'red',
#  'blueElemDragNum': 4,
#  'blueFIRE_DRAGON': 1,
#  'redElemDragNum': 0,
#  'redFIRE_DRAGON': 0,
#  'drag1type': 'FIRE_DRAGON',
#  'drag1team': 'blue',
#  'drag1time': 372155,
#  'blueWATER_DRAGON': 1,
#  'redWATER_DRAGON': 0,
#  'drag2type': 'WATER_DRAGON',
#  'drag2team': 'blue',
#  'drag2time': 694819,
#  'RIFTHERALD1team': 'red',
#  'RIFTHERALD1time': 899295,
#  'blueAIR_DRAGON': 2,
#  'redAIR_DRAGON': 0,
#  'drag3type': 'AIR_DRAGON',
#  'drag3team': 'blue',
#  'drag3time': 1012964,
#  'SoulType': 'AIR_DRAGON',
#  'SoulTeam': 'blue',
#  'drag4type': 'AIR_DRAGON',
#  'drag4team': 'blue',
#  'drag4time': 1353936,
#  'drag5type': 'ELDER_DRAGON',
#  'drag5team': 'blue',
#  'drag5time': 1824420,
#  'firstTower': 'red',
#  'firstInhibitor': 'red',
#  'firstDragon': 'red',
#  'firstRiftHerald': 'blue',
#  'bluebaronKills': 0,
#  'redbaronKills': 0,
#  'blueriftHeraldKills': 1,
#  'redriftHeraldKills': 0}

# %%
match_detail = watcher.match.by_id(my_region, test_gameId)
match_detail
# Out:
# {'gameId': 3447355549,
#  'platformId': 'NA1',
#  'gameCreation': 1591160342189,
#  'gameDuration': 1968,
#  'queueId': 400,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '10.11.322.2991',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': False,
#    'firstBaron': True,
#    'firstDragon': False,
#    'firstRiftHerald': True,
#    'towerKills': 4,
#    'inhibitorKills': 0,
#    'baronKills': 1,
#    'dragonKills': 1,
#    'vilemawKills': 0,
#    'riftHeraldKills': 1,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 154, 'pickTurn': 1},
#     {'championId': 89, 'pickTurn': 2},
#     {'championId': 38, 'pickTurn': 3},
#     {'championId': 53, 'pickTurn': 4},
#     {'championId': 17, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': True,
#    'firstBaron': False,
#    'firstDragon': True,
#    'firstRiftHerald': False,
#    'towerKills': 8,
#    'inhibitorKills': 2,
#    'baronKills': 0,
#    'dragonKills': 3,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 54, 'pickTurn': 6},
#     {'championId': 104, 'pickTurn': 7},
#     {'championId': 53, 'pickTurn': 8},
#     {'championId': 110, 'pickTurn': 9},
#     {'championId': 157, 'pickTurn': 10}]}],
#  'participants': [{'participantId': 1,
#    'teamId': 100,
#    'championId': 121,
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'participantId': 1,
#     'win': False,
#     'item0': 3147,
#     'item1': 1400,
#     'item2': 3071,
#     'item3': 3156,
#     'item4': 3134,
#     'item5': 3047,
#     'item6': 3364,
#     'kills': 10,
#     'deaths': 6,
#     'assists': 8,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'killingSprees': 3,
#     'longestTimeSpentLiving': 671,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 242693,
#     'magicDamageDealt': 10413,
#     'physicalDamageDealt': 217224,
#     'trueDamageDealt': 15056,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 27006,
#     'magicDamageDealtToChampions': 2455,
#     'physicalDamageDealtToChampions': 22985,
#     'trueDamageDealtToChampions': 1566,
#     'totalHeal': 16447,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 23101,
#     'damageDealtToObjectives': 38790,
#     'damageDealtToTurrets': 0,
#     'visionScore': 19,
#     'timeCCingOthers': 15,
#     'totalDamageTaken': 36613,
#     'magicalDamageTaken': 16060,
#     'physicalDamageTaken': 20025,
#     'trueDamageTaken': 527,
#     'goldEarned': 15581,
#     'goldSpent': 14125,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 47,
#     'neutralMinionsKilled': 167,
#     'neutralMinionsKilledTeamJungle': 118,
#     'neutralMinionsKilledEnemyJungle': 9,
#     'totalTimeCrowdControlDealt': 382,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 2,
#     'wardsKilled': 3,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 1155,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 1486,
#     'perk1Var2': 360,
#     'perk1Var3': 0,
#     'perk2': 9105,
#     'perk2Var1': 13,
#     'perk2Var2': 10,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 539,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8275,
#     'perk4Var1': 26,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8233,
#     'perk5Var1': 21,
#     'perk5Var2': 50,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8200,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 1,
#     'creepsPerMinDeltas': {'10-20': 1.5999999999999999,
#      '0-10': 0.1,
#      '20-30': 1.4},
#     'xpPerMinDeltas': {'10-20': 572, '0-10': 344.6, '20-30': 639.4},
#     'goldPerMinDeltas': {'10-20': 615.4,
#      '0-10': 298.7,
#      '20-30': 440.20000000000005},
#     'csDiffPerMinDeltas': {'10-20': -2.220446049250313e-16,
#      '0-10': -1.7,
#      '20-30': -2.6},
#     'xpDiffPerMinDeltas': {'10-20': -82.19999999999999,
#      '0-10': -124.30000000000004,
#      '20-30': -49.29999999999998},
#     'damageTakenPerMinDeltas': {'10-20': 1062,
#      '0-10': 602.9,
#      '20-30': 1667.3000000000002},
#     'damageTakenDiffPerMinDeltas': {'10-20': -268.0999999999999,
#      '0-10': -55.00000000000003,
#      '20-30': -696.1999999999999},
#     'role': 'NONE',
#     'lane': 'JUNGLE'}},
#   {'participantId': 2,
#    'teamId': 100,
#    'championId': 117,
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'participantId': 2,
#     'win': False,
#     'item0': 3853,
#     'item1': 1057,
#     'item2': 3107,
#     'item3': 3117,
#     'item4': 3504,
#     'item5': 0,
#     'item6': 3364,
#     'kills': 0,
#     'deaths': 14,
#     'assists': 7,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 264,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 19892,
#     'magicDamageDealt': 14863,
#     'physicalDamageDealt': 4395,
#     'trueDamageDealt': 634,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 3942,
#     'magicDamageDealtToChampions': 2491,
#     'physicalDamageDealtToChampions': 816,
#     'trueDamageDealtToChampions': 634,
#     'totalHeal': 1702,
#     'totalUnitsHealed': 5,
#     'damageSelfMitigated': 13499,
#     'damageDealtToObjectives': 662,
#     'damageDealtToTurrets': 246,
#     'visionScore': 63,
#     'timeCCingOthers': 36,
#     'totalDamageTaken': 22804,
#     'magicalDamageTaken': 14559,
#     'physicalDamageTaken': 7759,
#     'trueDamageTaken': 486,
#     'goldEarned': 7139,
#     'goldSpent': 6995,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 18,
#     'neutralMinionsKilled': 4,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 294,
#     'champLevel': 13,
#     'visionWardsBoughtInGame': 5,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 20,
#     'wardsKilled': 9,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8465,
#     'perk0Var1': 2062,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8463,
#     'perk1Var1': 1088,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8473,
#     'perk2Var1': 450,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8451,
#     'perk3Var1': 147,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8226,
#     'perk4Var1': 250,
#     'perk4Var2': 296,
#     'perk4Var3': 0,
#     'perk5': 8210,
#     'perk5Var1': 0,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8400,
#     'perkSubStyle': 8200,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 2,
#     'creepsPerMinDeltas': {'10-20': 0.9, '0-10': 0.2, '20-30': 0.4},
#     'xpPerMinDeltas': {'10-20': 258.5,
#      '0-10': 230.60000000000002,
#      '20-30': 490.70000000000005},
#     'goldPerMinDeltas': {'10-20': 239, '0-10': 142.7, '20-30': 227.2},
#     'csDiffPerMinDeltas': {'10-20': -0.2999999999999996,
#      '0-10': -0.34999999999999953,
#      '20-30': -1.7},
#     'xpDiffPerMinDeltas': {'10-20': -167.1,
#      '0-10': -66.99999999999999,
#      '20-30': -229.45},
#     'damageTakenPerMinDeltas': {'10-20': 555.8,
#      '0-10': 308.3,
#      '20-30': 961.6999999999999},
#     'damageTakenDiffPerMinDeltas': {'10-20': -17.899999999999977,
#      '0-10': 72.7,
#      '20-30': -36.49999999999994},
#     'role': 'DUO_SUPPORT',
#     'lane': 'BOTTOM'}},
#   {'participantId': 3,
#    'teamId': 100,
#    'championId': 517,
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'participantId': 3,
#     'win': False,
#     'item0': 2033,
#     'item1': 3157,
#     'item2': 3136,
#     'item3': 3065,
#     'item4': 3285,
#     'item5': 3020,
#     'item6': 3364,
#     'kills': 9,
#     'deaths': 7,
#     'assists': 9,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'killingSprees': 3,
#     'longestTimeSpentLiving': 482,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 110399,
#     'magicDamageDealt': 94879,
#     'physicalDamageDealt': 10589,
#     'trueDamageDealt': 4931,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 25354,
#     'magicDamageDealtToChampions': 23311,
#     'physicalDamageDealtToChampions': 806,
#     'trueDamageDealtToChampions': 1236,
#     'totalHeal': 8806,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 25482,
#     'damageDealtToObjectives': 2817,
#     'damageDealtToTurrets': 1664,
#     'visionScore': 20,
#     'timeCCingOthers': 30,
#     'totalDamageTaken': 38453,
#     'magicalDamageTaken': 21158,
#     'physicalDamageTaken': 15722,
#     'trueDamageTaken': 1573,
#     'goldEarned': 12848,
#     'goldSpent': 13025,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 132,
#     'neutralMinionsKilled': 11,
#     'neutralMinionsKilledTeamJungle': 7,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 244,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 3,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 7,
#     'wardsKilled': 1,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 1556,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8009,
#     'perk1Var1': 3045,
#     'perk1Var2': 500,
#     'perk1Var3': 0,
#     'perk2': 9105,
#     'perk2Var1': 14,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8299,
#     'perk3Var1': 867,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8453,
#     'perk4Var1': 1125,
#     'perk4Var2': 127,
#     'perk4Var3': 0,
#     'perk5': 8444,
#     'perk5Var1': 1396,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8400,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 3,
#     'creepsPerMinDeltas': {'10-20': 3.7, '0-10': 6, '20-30': 3},
#     'xpPerMinDeltas': {'10-20': 438.3, '0-10': 521.6, '20-30': 536.5},
#     'goldPerMinDeltas': {'10-20': 441.9,
#      '0-10': 328.20000000000005,
#      '20-30': 388.6},
#     'csDiffPerMinDeltas': {'10-20': -1.7999999999999998,
#      '0-10': 0.3999999999999999,
#      '20-30': -2.1},
#     'xpDiffPerMinDeltas': {'10-20': -74.19999999999996,
#      '0-10': 162.10000000000002,
#      '20-30': 27.69999999999999},
#     'damageTakenPerMinDeltas': {'10-20': 1212.2,
#      '0-10': 654.7,
#      '20-30': 1333.6},
#     'damageTakenDiffPerMinDeltas': {'10-20': 588.8,
#      '0-10': 118.89999999999998,
#      '20-30': 317.79999999999995},
#     'role': 'SOLO',
#     'lane': 'MIDDLE'}},
#   {'participantId': 4,
#    'teamId': 100,
#    'championId': 51,
#    'spell1Id': 7,
#    'spell2Id': 4,
#    'stats': {'participantId': 4,
#     'win': False,
#     'item0': 1055,
#     'item1': 3031,
#     'item2': 3155,
#     'item3': 3006,
#     'item4': 1038,
#     'item5': 3123,
#     'item6': 3340,
#     'kills': 1,
#     'deaths': 12,
#     'assists': 5,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 421,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 109325,
#     'magicDamageDealt': 4400,
#     'physicalDamageDealt': 104925,
#     'trueDamageDealt': 0,
#     'largestCriticalStrike': 808,
#     'totalDamageDealtToChampions': 11762,
#     'magicDamageDealtToChampions': 410,
#     'physicalDamageDealtToChampions': 11351,
#     'trueDamageDealtToChampions': 0,
#     'totalHeal': 2905,
#     'totalUnitsHealed': 2,
#     'damageSelfMitigated': 8926,
#     'damageDealtToObjectives': 6770,
#     'damageDealtToTurrets': 2151,
#     'visionScore': 14,
#     'timeCCingOthers': 15,
#     'totalDamageTaken': 27653,
#     'magicalDamageTaken': 18099,
#     'physicalDamageTaken': 8761,
#     'trueDamageTaken': 792,
#     'goldEarned': 9268,
#     'goldSpent': 8550,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 149,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 31,
#     'champLevel': 13,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 9,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8021,
#     'perk0Var1': 1109,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 396,
#     'perk1Var2': 120,
#     'perk1Var3': 0,
#     'perk2': 9103,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 90,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8275,
#     'perk4Var1': 9,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8236,
#     'perk5Var1': 28,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8200,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 4,
#     'creepsPerMinDeltas': {'10-20': 5.800000000000001,
#      '0-10': 5.7,
#      '20-30': 3.3},
#     'xpPerMinDeltas': {'10-20': 350.1, '0-10': 271.9, '20-30': 434.9},
#     'goldPerMinDeltas': {'10-20': 353.6, '0-10': 217.1, '20-30': 255.2},
#     'csDiffPerMinDeltas': {'10-20': -0.2999999999999996,
#      '0-10': -0.34999999999999953,
#      '20-30': -1.7},
#     'xpDiffPerMinDeltas': {'10-20': -167.1,
#      '0-10': -66.99999999999999,
#      '20-30': -229.45},
#     'damageTakenPerMinDeltas': {'10-20': 888.7,
#      '0-10': 406.7,
#      '20-30': 1113.2},
#     'damageTakenDiffPerMinDeltas': {'10-20': -17.899999999999977,
#      '0-10': 72.7,
#      '20-30': -36.49999999999994},
#     'role': 'DUO_CARRY',
#     'lane': 'BOTTOM'}},
#   {'participantId': 5,
#    'teamId': 100,
#    'championId': 420,
#    'spell1Id': 12,
#    'spell2Id': 4,
#    'stats': {'participantId': 5,
#     'win': False,
#     'item0': 3123,
#     'item1': 3812,
#     'item2': 3111,
#     'item3': 3071,
#     'item4': 3053,
#     'item5': 3065,
#     'item6': 3340,
#     'kills': 8,
#     'deaths': 12,
#     'assists': 9,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'killingSprees': 4,
#     'longestTimeSpentLiving': 341,
#     'doubleKills': 2,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 233825,
#     'magicDamageDealt': 1015,
#     'physicalDamageDealt': 232222,
#     'trueDamageDealt': 587,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 44940,
#     'magicDamageDealtToChampions': 409,
#     'physicalDamageDealtToChampions': 44193,
#     'trueDamageDealtToChampions': 337,
#     'totalHeal': 16412,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 45926,
#     'damageDealtToObjectives': 5994,
#     'damageDealtToTurrets': 4693,
#     'visionScore': 26,
#     'timeCCingOthers': 5,
#     'totalDamageTaken': 54466,
#     'magicalDamageTaken': 25474,
#     'physicalDamageTaken': 23035,
#     'trueDamageTaken': 5956,
#     'goldEarned': 16034,
#     'goldSpent': 15850,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 226,
#     'neutralMinionsKilled': 8,
#     'neutralMinionsKilledTeamJungle': 6,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 56,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 2,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 10,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 5484,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 1863,
#     'perk1Var2': 340,
#     'perk1Var3': 0,
#     'perk2': 9105,
#     'perk2Var1': 13,
#     'perk2Var2': 10,
#     'perk2Var3': 0,
#     'perk3': 8299,
#     'perk3Var1': 4384,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8226,
#     'perk4Var1': 250,
#     'perk4Var2': 654,
#     'perk4Var3': 0,
#     'perk5': 8210,
#     'perk5Var1': 12,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8200,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 5,
#     'creepsPerMinDeltas': {'10-20': 7.300000000000001,
#      '0-10': 7.699999999999999,
#      '20-30': 4.9},
#     'xpPerMinDeltas': {'10-20': 481.9, '0-10': 478.5, '20-30': 514.3},
#     'goldPerMinDeltas': {'10-20': 427.5, '0-10': 354.4, '20-30': 550.5},
#     'csDiffPerMinDeltas': {'10-20': 7.300000000000001,
#      '0-10': 3.8,
#      '20-30': 4.9},
#     'xpDiffPerMinDeltas': {'10-20': 478.9,
#      '0-10': 105.19999999999996,
#      '20-30': 514.3},
#     'damageTakenPerMinDeltas': {'10-20': 1172.4,
#      '0-10': 572.3,
#      '20-30': 2726.7},
#     'damageTakenDiffPerMinDeltas': {'10-20': 1142.1,
#      '0-10': 9.599999999999966,
#      '20-30': 2726.7},
#     'role': 'SOLO',
#     'lane': 'TOP'}},
#   {'participantId': 6,
#    'teamId': 200,
#    'championId': 62,
#    'spell1Id': 4,
#    'spell2Id': 12,
#    'stats': {'participantId': 6,
#     'win': True,
#     'item0': 1054,
#     'item1': 3044,
#     'item2': 1028,
#     'item3': 0,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3340,
#     'kills': 0,
#     'deaths': 3,
#     'assists': 1,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'killingSprees': 0,
#     'longestTimeSpentLiving': 395,
#     'doubleKills': 0,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 12723,
#     'magicDamageDealt': 3634,
#     'physicalDamageDealt': 9088,
#     'trueDamageDealt': 0,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 4175,
#     'magicDamageDealtToChampions': 1134,
#     'physicalDamageDealtToChampions': 3040,
#     'trueDamageDealtToChampions': 0,
#     'totalHeal': 216,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 4078,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'visionScore': 1,
#     'timeCCingOthers': 2,
#     'totalDamageTaken': 5930,
#     'magicalDamageTaken': 124,
#     'physicalDamageTaken': 5806,
#     'trueDamageTaken': 0,
#     'goldEarned': 5690,
#     'goldSpent': 2350,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 39,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 12,
#     'champLevel': 7,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 1,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 222,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 41,
#     'perk1Var2': 20,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 76,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8473,
#     'perk4Var1': 113,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8451,
#     'perk5Var1': 33,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8400,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 6,
#     'creepsPerMinDeltas': {'10-20': 0, '0-10': 3.9000000000000004, '20-30': 0},
#     'xpPerMinDeltas': {'10-20': 3, '0-10': 373.3, '20-30': 0},
#     'goldPerMinDeltas': {'10-20': 132.4, '0-10': 199.8, '20-30': 152.5},
#     'csDiffPerMinDeltas': {'10-20': -7.300000000000001,
#      '0-10': -3.8,
#      '20-30': -4.9},
#     'xpDiffPerMinDeltas': {'10-20': -478.9,
#      '0-10': -105.19999999999996,
#      '20-30': -514.3},
#     'damageTakenPerMinDeltas': {'10-20': 30.3, '0-10': 562.7, '20-30': 0},
#     'damageTakenDiffPerMinDeltas': {'10-20': -1142.1,
#      '0-10': -9.599999999999966,
#      '20-30': -2726.7},
#     'role': 'SOLO',
#     'lane': 'TOP'}},
#   {'participantId': 7,
#    'teamId': 200,
#    'championId': 246,
#    'spell1Id': 14,
#    'spell2Id': 4,
#    'stats': {'participantId': 7,
#     'win': True,
#     'item0': 3147,
#     'item1': 3142,
#     'item2': 3009,
#     'item3': 3179,
#     'item4': 3123,
#     'item5': 3035,
#     'item6': 3364,
#     'kills': 9,
#     'deaths': 10,
#     'assists': 8,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'killingSprees': 2,
#     'longestTimeSpentLiving': 303,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 128222,
#     'magicDamageDealt': 5754,
#     'physicalDamageDealt': 110883,
#     'trueDamageDealt': 11584,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 23704,
#     'magicDamageDealtToChampions': 1398,
#     'physicalDamageDealtToChampions': 21516,
#     'trueDamageDealtToChampions': 789,
#     'totalHeal': 4609,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 11607,
#     'damageDealtToObjectives': 2452,
#     'damageDealtToTurrets': 2071,
#     'visionScore': 21,
#     'timeCCingOthers': 18,
#     'totalDamageTaken': 25437,
#     'magicalDamageTaken': 9801,
#     'physicalDamageTaken': 14217,
#     'trueDamageTaken': 1418,
#     'goldEarned': 11759,
#     'goldSpent': 11575,
#     'turretKills': 1,
#     'inhibitorKills': 1,
#     'totalMinionsKilled': 166,
#     'neutralMinionsKilled': 10,
#     'neutralMinionsKilledTeamJungle': 4,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 89,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 1,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 6,
#     'wardsKilled': 6,
#     'firstBloodKill': True,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': True,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8112,
#     'perk0Var1': 1184,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8143,
#     'perk1Var1': 818,
#     'perk1Var2': 0,
#     'perk1Var3': 0,
#     'perk2': 8138,
#     'perk2Var1': 18,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8135,
#     'perk3Var1': 3535,
#     'perk3Var2': 5,
#     'perk3Var3': 0,
#     'perk4': 8345,
#     'perk4Var1': 3,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8352,
#     'perk5Var1': 151,
#     'perk5Var2': 914,
#     'perk5Var3': 58,
#     'perkPrimaryStyle': 8100,
#     'perkSubStyle': 8300,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 7,
#     'creepsPerMinDeltas': {'10-20': 5.5, '0-10': 5.6, '20-30': 5.1},
#     'xpPerMinDeltas': {'10-20': 512.5, '0-10': 359.5, '20-30': 508.8},
#     'goldPerMinDeltas': {'10-20': 427.9,
#      '0-10': 242.60000000000002,
#      '20-30': 375.6},
#     'csDiffPerMinDeltas': {'10-20': 1.7999999999999998,
#      '0-10': -0.3999999999999999,
#      '20-30': 2.1},
#     'xpDiffPerMinDeltas': {'10-20': 74.19999999999996,
#      '0-10': -162.10000000000002,
#      '20-30': -27.69999999999999},
#     'damageTakenPerMinDeltas': {'10-20': 623.4000000000001,
#      '0-10': 535.8,
#      '20-30': 1015.8000000000001},
#     'damageTakenDiffPerMinDeltas': {'10-20': -588.8,
#      '0-10': -118.89999999999998,
#      '20-30': -317.79999999999995},
#     'role': 'SOLO',
#     'lane': 'MIDDLE'}},
#   {'participantId': 8,
#    'teamId': 200,
#    'championId': 115,
#    'spell1Id': 4,
#    'spell2Id': 12,
#    'stats': {'participantId': 8,
#     'win': True,
#     'item0': 3165,
#     'item1': 3089,
#     'item2': 3151,
#     'item3': 3020,
#     'item4': 3041,
#     'item5': 3285,
#     'item6': 3363,
#     'kills': 26,
#     'deaths': 7,
#     'assists': 10,
#     'largestKillingSpree': 9,
#     'largestMultiKill': 3,
#     'killingSprees': 7,
#     'longestTimeSpentLiving': 635,
#     'doubleKills': 4,
#     'tripleKills': 2,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 301298,
#     'magicDamageDealt': 256901,
#     'physicalDamageDealt': 15109,
#     'trueDamageDealt': 29286,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 70211,
#     'magicDamageDealtToChampions': 64959,
#     'physicalDamageDealtToChampions': 3023,
#     'trueDamageDealtToChampions': 2228,
#     'totalHeal': 7688,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 16744,
#     'damageDealtToObjectives': 34942,
#     'damageDealtToTurrets': 34743,
#     'visionScore': 21,
#     'timeCCingOthers': 30,
#     'totalDamageTaken': 38351,
#     'magicalDamageTaken': 10206,
#     'physicalDamageTaken': 26379,
#     'trueDamageTaken': 1766,
#     'goldEarned': 19566,
#     'goldSpent': 17312,
#     'turretKills': 5,
#     'inhibitorKills': 1,
#     'totalMinionsKilled': 225,
#     'neutralMinionsKilled': 20,
#     'neutralMinionsKilledTeamJungle': 12,
#     'neutralMinionsKilledEnemyJungle': 8,
#     'totalTimeCrowdControlDealt': 339,
#     'champLevel': 17,
#     'visionWardsBoughtInGame': 2,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 12,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': True,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': True,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8229,
#     'perk0Var1': 2471,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 1668,
#     'perk1Var3': 0,
#     'perk2': 8210,
#     'perk2Var1': 0,
#     'perk2Var2': 0,
#     'perk2Var3': 0,
#     'perk3': 8237,
#     'perk3Var1': 948,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8139,
#     'perk4Var1': 2396,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 6233,
#     'perk5Var2': 5,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8100,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5002},
#    'timeline': {'participantId': 8,
#     'creepsPerMinDeltas': {'10-20': 7.1, '0-10': 6.3, '20-30': 7},
#     'xpPerMinDeltas': {'10-20': 581.2, '0-10': 330.4, '20-30': 728.9},
#     'goldPerMinDeltas': {'10-20': 669.3, '0-10': 345.1, '20-30': 730.5},
#     'csDiffPerMinDeltas': {'10-20': 0.2999999999999996,
#      '0-10': 0.34999999999999953,
#      '20-30': 1.7},
#     'xpDiffPerMinDeltas': {'10-20': 167.1,
#      '0-10': 66.99999999999999,
#      '20-30': 229.45},
#     'damageTakenPerMinDeltas': {'10-20': 973.4,
#      '0-10': 424.79999999999995,
#      '20-30': 1728.5},
#     'damageTakenDiffPerMinDeltas': {'10-20': 17.899999999999977,
#      '0-10': -72.7,
#      '20-30': 36.49999999999994},
#     'role': 'DUO_CARRY',
#     'lane': 'BOTTOM'}},
#   {'participantId': 9,
#    'teamId': 200,
#    'championId': 350,
#    'spell1Id': 3,
#    'spell2Id': 14,
#    'stats': {'participantId': 9,
#     'win': True,
#     'item0': 3222,
#     'item1': 3853,
#     'item2': 3041,
#     'item3': 3174,
#     'item4': 0,
#     'item5': 3504,
#     'item6': 3364,
#     'kills': 3,
#     'deaths': 5,
#     'assists': 26,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'killingSprees': 1,
#     'longestTimeSpentLiving': 647,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 22600,
#     'magicDamageDealt': 19393,
#     'physicalDamageDealt': 1998,
#     'trueDamageDealt': 1209,
#     'largestCriticalStrike': 0,
#     'totalDamageDealtToChampions': 14701,
#     'magicDamageDealtToChampions': 12479,
#     'physicalDamageDealtToChampions': 1012,
#     'trueDamageDealtToChampions': 1209,
#     'totalHeal': 26652,
#     'totalUnitsHealed': 4,
#     'damageSelfMitigated': 7172,
#     'damageDealtToObjectives': 2224,
#     'damageDealtToTurrets': 1870,
#     'visionScore': 58,
#     'timeCCingOthers': 29,
#     'totalDamageTaken': 13227,
#     'magicalDamageTaken': 2307,
#     'physicalDamageTaken': 10267,
#     'trueDamageTaken': 653,
#     'goldEarned': 9926,
#     'goldSpent': 8775,
#     'turretKills': 0,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 6,
#     'neutralMinionsKilled': 0,
#     'neutralMinionsKilledTeamJungle': 0,
#     'neutralMinionsKilledEnemyJungle': 0,
#     'totalTimeCrowdControlDealt': 54,
#     'champLevel': 16,
#     'visionWardsBoughtInGame': 5,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 28,
#     'wardsKilled': 4,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': True,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8214,
#     'perk0Var1': 1692,
#     'perk0Var2': 3293,
#     'perk0Var3': 0,
#     'perk1': 8226,
#     'perk1Var1': 250,
#     'perk1Var2': 511,
#     'perk1Var3': 0,
#     'perk2': 8233,
#     'perk2Var1': 20,
#     'perk2Var2': 10,
#     'perk2Var3': 0,
#     'perk3': 8237,
#     'perk3Var1': 471,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8009,
#     'perk4Var1': 5918,
#     'perk4Var2': 500,
#     'perk4Var3': 0,
#     'perk5': 8017,
#     'perk5Var1': 1173,
#     'perk5Var2': 0,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8200,
#     'perkSubStyle': 8000,
#     'statPerk0': 5008,
#     'statPerk1': 5008,
#     'statPerk2': 5003},
#    'timeline': {'participantId': 9,
#     'creepsPerMinDeltas': {'10-20': 0.2, '0-10': 0.3, '20-30': 0.1},
#     'xpPerMinDeltas': {'10-20': 361.6,
#      '0-10': 306.1,
#      '20-30': 655.5999999999999},
#     'goldPerMinDeltas': {'10-20': 287,
#      '0-10': 267,
#      '20-30': 326.70000000000005},
#     'csDiffPerMinDeltas': {'10-20': 0.2999999999999996,
#      '0-10': 0.34999999999999953,
#      '20-30': 1.7},
#     'xpDiffPerMinDeltas': {'10-20': 167.1,
#      '0-10': 66.99999999999999,
#      '20-30': 229.45},
#     'damageTakenPerMinDeltas': {'10-20': 506.9, '0-10': 144.8, '20-30': 419.4},
#     'damageTakenDiffPerMinDeltas': {'10-20': 17.899999999999977,
#      '0-10': -72.7,
#      '20-30': 36.49999999999994},
#     'role': 'DUO_SUPPORT',
#     'lane': 'BOTTOM'}},
#   {'participantId': 10,
#    'teamId': 200,
#    'championId': 106,
#    'spell1Id': 11,
#    'spell2Id': 4,
#    'stats': {'participantId': 10,
#     'win': True,
#     'item0': 1401,
#     'item1': 3047,
#     'item2': 3053,
#     'item3': 3075,
#     'item4': 3143,
#     'item5': 3211,
#     'item6': 3340,
#     'kills': 13,
#     'deaths': 3,
#     'assists': 8,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 2,
#     'killingSprees': 3,
#     'longestTimeSpentLiving': 670,
#     'doubleKills': 1,
#     'tripleKills': 0,
#     'quadraKills': 0,
#     'pentaKills': 0,
#     'unrealKills': 0,
#     'totalDamageDealt': 264817,
#     'magicDamageDealt': 144758,
#     'physicalDamageDealt': 109381,
#     'trueDamageDealt': 10677,
#     'largestCriticalStrike': 29,
#     'totalDamageDealtToChampions': 34369,
#     'magicDamageDealtToChampions': 11058,
#     'physicalDamageDealtToChampions': 18932,
#     'trueDamageDealtToChampions': 4378,
#     'totalHeal': 22572,
#     'totalUnitsHealed': 1,
#     'damageSelfMitigated': 93283,
#     'damageDealtToObjectives': 21874,
#     'damageDealtToTurrets': 3683,
#     'visionScore': 17,
#     'timeCCingOthers': 30,
#     'totalDamageTaken': 52027,
#     'magicalDamageTaken': 8725,
#     'physicalDamageTaken': 42365,
#     'trueDamageTaken': 936,
#     'goldEarned': 15776,
#     'goldSpent': 15750,
#     'turretKills': 1,
#     'inhibitorKills': 0,
#     'totalMinionsKilled': 82,
#     'neutralMinionsKilled': 167,
#     'neutralMinionsKilledTeamJungle': 119,
#     'neutralMinionsKilledEnemyJungle': 10,
#     'totalTimeCrowdControlDealt': 752,
#     'champLevel': 18,
#     'visionWardsBoughtInGame': 0,
#     'sightWardsBoughtInGame': 0,
#     'wardsPlaced': 9,
#     'wardsKilled': 0,
#     'firstBloodKill': False,
#     'firstBloodAssist': False,
#     'firstTowerKill': False,
#     'firstTowerAssist': False,
#     'firstInhibitorKill': False,
#     'firstInhibitorAssist': False,
#     'combatPlayerScore': 0,
#     'objectivePlayerScore': 0,
#     'totalPlayerScore': 0,
#     'totalScoreRank': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'perk0': 8010,
#     'perk0Var1': 1994,
#     'perk0Var2': 0,
#     'perk0Var3': 0,
#     'perk1': 9111,
#     'perk1Var1': 2755,
#     'perk1Var2': 420,
#     'perk1Var3': 0,
#     'perk2': 9104,
#     'perk2Var1': 11,
#     'perk2Var2': 50,
#     'perk2Var3': 0,
#     'perk3': 8014,
#     'perk3Var1': 942,
#     'perk3Var2': 0,
#     'perk3Var3': 0,
#     'perk4': 8126,
#     'perk4Var1': 979,
#     'perk4Var2': 0,
#     'perk4Var3': 0,
#     'perk5': 8135,
#     'perk5Var1': 10385,
#     'perk5Var2': 5,
#     'perk5Var3': 0,
#     'perkPrimaryStyle': 8000,
#     'perkSubStyle': 8100,
#     'statPerk0': 5005,
#     'statPerk1': 5008,
#     'statPerk2': 5001},
#    'timeline': {'participantId': 10,
#     'creepsPerMinDeltas': {'10-20': 1.6, '0-10': 1.8, '20-30': 4},
#     'xpPerMinDeltas': {'10-20': 654.2,
#      '0-10': 468.90000000000003,
#      '20-30': 688.7},
#     'goldPerMinDeltas': {'10-20': 549.8, '0-10': 350.2, '20-30': 535.2},
#     'csDiffPerMinDeltas': {'10-20': 2.220446049250313e-16,
#      '0-10': 1.7,
#      '20-30': 2.6},
#     'xpDiffPerMinDeltas': {'10-20': 82.19999999999999,
#      '0-10': 124.30000000000004,
#      '20-30': 49.29999999999998},
#     'damageTakenPerMinDeltas': {'10-20': 1330.1,
#      '0-10': 657.9,
#      '20-30': 2363.5},
#     'damageTakenDiffPerMinDeltas': {'10-20': 268.0999999999999,
#      '0-10': 55.00000000000003,
#      '20-30': 696.1999999999999},
#     'role': 'NONE',
#     'lane': 'JUNGLE'}}],
#  'participantIdentities': [{'participantId': 1,
#    'player': {'platformId': 'NA1',
#     'accountId': 'cvvpu_nCoK7HcXkCq2VOEhbwd1ewRKd90prohoZkmkH_f8U',
#     'summonerName': 'Good at vxlove',
#     'summonerId': 'fP6m2_8yHGE33_G42mcdj3xHqug2cbdM56y6kogKTziGJ2c',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'cvvpu_nCoK7HcXkCq2VOEhbwd1ewRKd90prohoZkmkH_f8U',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/220575339',
#     'profileIcon': 4532}},
#   {'participantId': 2,
#    'player': {'platformId': 'NA1',
#     'accountId': 'KiweijBOIwU0lHENW8OoF_ND1O_z6EjMEahKZRvx6uD8o04',
#     'summonerName': 'jcshomie',
#     'summonerId': 'LeiGNNoLptzOdUK_CpTSUyJisLMarx06ujRJ56HWc7kl41s',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'KiweijBOIwU0lHENW8OoF_ND1O_z6EjMEahKZRvx6uD8o04',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/214119131',
#     'profileIcon': 4563}},
#   {'participantId': 3,
#    'player': {'platformId': 'NA1',
#     'accountId': 'tffItKoKKLrlGASL3DL4xPjP6hScDLhYE3p3MVruY5Zh0Q',
#     'summonerName': 'Yangmiemie',
#     'summonerId': 'nrIN2TIhGsweh9QDMxgCHiogWSXfaUQLMD27_IB8fBb286M',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'tffItKoKKLrlGASL3DL4xPjP6hScDLhYE3p3MVruY5Zh0Q',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/42179105',
#     'profileIcon': 4574}},
#   {'participantId': 4,
#    'player': {'platformId': 'NA1',
#     'accountId': 'gnIsDLrNrF08sCqAyVea4PyGs-y9F1ei2ehMjU03AeruSnI',
#     'summonerName': 'Top lose Bot not',
#     'summonerId': 'LXcn2OH2LAiklcYxgM-x3KQg1PiFckLfR65aSuUgQjBP5FY',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'gnIsDLrNrF08sCqAyVea4PyGs-y9F1ei2ehMjU03AeruSnI',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/207479614',
#     'profileIcon': 4213}},
#   {'participantId': 5,
#    'player': {'platformId': 'NA1',
#     'accountId': '_rzrz6Z7o4xwcg5M3kySRJyOgYICvuou7_yKMi8-Je79fdM',
#     'summonerName': 'Cowfan',
#     'summonerId': 'Hvyb4T9F9mULzw2kwk8Jb_aKwi33OHB6TH6xGneKXj8MI94',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': '_rzrz6Z7o4xwcg5M3kySRJyOgYICvuou7_yKMi8-Je79fdM',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/232392169',
#     'profileIcon': 4466}},
#   {'participantId': 6,
#    'player': {'platformId': 'NA1',
#     'accountId': 'aQlCzbIzMFPNfyDpBoukX5yS8lgykYEwpoSztNCW36lyow',
#     'summonerName': 'Joeda89',
#     'summonerId': 'zDZ2eAJoGRBw_pNOLzvBo98CtDfQ4nUToKs2NFbIARYUIlw',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'aQlCzbIzMFPNfyDpBoukX5yS8lgykYEwpoSztNCW36lyow',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/46456913',
#     'profileIcon': 560}},
#   {'participantId': 7,
#    'player': {'platformId': 'NA',
#     'accountId': 'vT418Se-8Xbf-dl2YZ1tFXPdBLQFyI9mR5QQHNz8g_AonQ',
#     'summonerName': 'LOONA Chuuu',
#     'summonerId': '65KsOHYoiQ-2FK_xiEUbwZ6yVgagMD4n32uQ-Rx9xQEcgSE',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'vT418Se-8Xbf-dl2YZ1tFXPdBLQFyI9mR5QQHNz8g_AonQ',
#     'matchHistoryUri': '/v1/stats/player_history/NA/36843052',
#     'profileIcon': 4561}},
#   {'participantId': 8,
#    'player': {'platformId': 'NA1',
#     'accountId': '_JBrw5ZEaW9y9ABf2VQ9Zwul4lJmTngiuVsm7XznoKHxOw',
#     'summonerName': 'Kandori',
#     'summonerId': 'aKgW_wqkTJ-nkuMnAzmcNjdlsWCFRlACgLFdttNBWvKcZIc',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': '_JBrw5ZEaW9y9ABf2VQ9Zwul4lJmTngiuVsm7XznoKHxOw',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/44526714',
#     'profileIcon': 4521}},
#   {'participantId': 9,
#    'player': {'platformId': 'NA1',
#     'accountId': 'GNehFTvVvbvIO9kIEmwg90Pnhmf1aKfeVEGMsWljk3AGuzU',
#     'summonerName': 'candylishious',
#     'summonerId': 'K1autio8HkBpWg7ymFn8xMweuRstFl2uKXDWv3FFjidbgME',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'GNehFTvVvbvIO9kIEmwg90Pnhmf1aKfeVEGMsWljk3AGuzU',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/223352053',
#     'profileIcon': 4574}},
#   {'participantId': 10,
#    'player': {'platformId': 'NA1',
#     'accountId': 'hNH_ZfpcFE4zUBSjlFvDxsBNm_FpxZUWy-nk5nMg_kNIud8',
#     'summonerName': 'RaiReapNewb',
#     'summonerId': 'AtwRYD_8XrvQuKXP-DGDOpqaEYeaobqoCFap4jNEKUm37UQ',
#     'currentPlatformId': 'NA1',
#     'currentAccountId': 'hNH_ZfpcFE4zUBSjlFvDxsBNm_FpxZUWy-nk5nMg_kNIud8',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/217330072',
#     'profileIcon': 3367}}]}

# %%
match_detail_dict = {} #initialize match detail dict

# %% [markdown]
# HTTPError: 503 Server Error: Service Unavailable for url: https://na1.api.riotgames.com/lol/match/v4/matches/3430810044

# %%
len(match_detail_dict)
# Out:
# 20275

# %%
# %%time
#retrieve match details
@retry(stop_max_attempt_number=20, wait_random_min=1000, wait_random_max=2000)
def retrieve_match_detail():
    for gameId in matchlist:
        if gameId not in match_detail_dict.keys():
            match_detail = watcher.match.by_id(my_region, gameId)
            match_detail_dict[gameId] = match_detail
# Out:
# Wall time: 0 ns

# %%
# %%time
retrieve_match_detail()
# Out:
# From cffi callback <function _verify_callback at 0x000001C0EEDBCF78>:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     218                     jitter = random.random() * self._wait_jitter_max
#     219                     sleep = sleep + max(0, jitter)
# --> 220                 time.sleep(sleep / 1000.0)
#     221
#     222             attempt_number += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Match Timeline
# Using the API endpoint match.timeline_by_match, a match timeline was extracted for each game in matchlist via inputting gameId. The extracted timelines are stored in match_timeline_dict with the gameId as the key. The resulting dictionary file is very large since each timeline provides comprehensive information about the gamestate for each minute interval.

# %%
match_timeline_dict = {}  #initialize match timeline dict

# %%
# %%time
len(match_timeline_dict)
# Out:
# Wall time: 1.05 ms
# 28627

# %%
from retrying import retry

# %%
@retry(stop_max_attempt_number=20, wait_random_min=1000, wait_random_max=2000)
def retrieve_match_timeline():
    #retrieve match timeline:
    for gameId in matchlist:
        if gameId not in match_timeline_dict.keys():
            match_timeline = watcher.match.timeline_by_match(my_region, gameId)
            match_timeline_dict[gameId] = match_timeline

# %%
# %%time
retrieve_match_timeline()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\riotwatcher\Handlers\ThrowOnErrorHandler.py in after_request(self, region, endpoint_name, method_name, url, response)
#      17         try:
# ---> 18             response.raise_for_status()
#      19         except requests.HTTPError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 504 Server Error: Gateway Timeout for url: https://na1.api.riotgames.com/lol/match/v4/timelines/by-match/3434010758
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     210                 if not self._wrap_exception and attempt.has_exception:
#     211                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 212                     raise attempt.get()
#     213                 else:
#     214                     raise RetryError(attempt)
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# C:\ProgramData\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# <ipython-input-588-7d0b140004bc> in retrieve_match_timeline()
#       4     for gameId in matchlist:
#       5         if gameId not in match_timeline_dict.keys():
# ----> 6             match_timeline = watcher.match.timeline_by_match(my_region, gameId)
#       7             match_timeline_dict[gameId] = match_timeline
#
# C:\ProgramData\Anaconda3\lib\site-packages\riotwatcher\_apis\league_of_legends\MatchApiV4.py in timeline_by_match(self, region, match_id)
#     107             region,
#     108             MatchApiV4Urls.timeline_by_match,
# --> 109             match_id=match_id,
#     110         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\riotwatcher\_apis\NamedEndpoint.py in _request_endpoint(self, method_name, region, endpoint, **kwargs)
#      34         url, query = endpoint(platform=region, **kwargs)
#      35         return self._base_api.raw_request(
# ---> 36             self._endpoint_name, method_name, region, url, query
#      37         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\riotwatcher\_apis\BaseApi.py in raw_request(self, endpoint_name, method_name, region, url, query_params)
#      49             for handler in self._request_handlers[early_ret_idx:None:-1]:
#      50                 mod = handler.after_request(
# ---> 51                     region, endpoint_name, method_name, url, response
#      52                 )
#      53                 if mod is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\riotwatcher\Handlers\ThrowOnErrorHandler.py in after_request(self, region, endpoint_name, method_name, url, response)
#      18             response.raise_for_status()
#      19         except requests.HTTPError as err:
# ---> 20             raise ApiError(*err.args, request=err.request, response=err.response)
#
# HTTPError: 504 Server Error: Gateway Timeout for url: https://na1.api.riotgames.com/lol/match/v4/timelines/by-match/3434010758

# %%
match_timeline
# Out:
# {'frames': [{'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 560, 'y': 581},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 560, 'y': 361},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 351, 'y': 293},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 221, 'y': 471},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 311, 'y': 649},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 14486, 'y': 14511},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 14486, 'y': 14291},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 14277, 'y': 14223},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 14147, 'y': 14401},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 14237, 'y': 14579},
#      'currentGold': 500,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [],
#    'timestamp': 0},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 760, 'y': 10618},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 7705, 'y': 830},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 6498, 'y': 4690},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 9589, 'y': 3499},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 9785, 'y': 3353},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 6911, 'y': 11446},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 11907, 'y': 7149},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 8853, 'y': 5451},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 7621, 'y': 5021},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 11907, 'y': 7149},
#      'currentGold': 0,
#      'totalGold': 500,
#      'level': 1,
#      'xp': 0,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_PURCHASED',
#      'timestamp': 7201,
#      'participantId': 6,
#      'itemId': 1054},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7564,
#      'participantId': 6,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 7960,
#      'participantId': 6,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 8093,
#      'participantId': 4,
#      'itemId': 1055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 8357,
#      'participantId': 4,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 8654,
#      'participantId': 4,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 13179,
#      'participantId': 8,
#      'itemId': 1056},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 13642,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 13807,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 14038,
#      'participantId': 8,
#      'itemId': 3340},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 16151,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16680,
#      'participantId': 3,
#      'itemId': 2033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 16713,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17043,
#      'participantId': 3,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17406,
#      'participantId': 7,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17836,
#      'participantId': 7,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 17935,
#      'participantId': 5,
#      'itemId': 2033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 18430,
#      'participantId': 5,
#      'itemId': 3340},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 20280,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 20346,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 21402,
#      'participantId': 1,
#      'itemId': 1039},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 21601,
#      'participantId': 1,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 21865,
#      'participantId': 1,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 23221,
#      'participantId': 2,
#      'itemId': 3850},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 23320,
#      'participantId': 2,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 23518,
#      'participantId': 2,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 23848,
#      'participantId': 2,
#      'itemId': 3340},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 25532,
#      'participantId': 7,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 26754,
#      'participantId': 10,
#      'itemId': 1041},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 27217,
#      'participantId': 10,
#      'itemId': 2031},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 27646,
#      'participantId': 10,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 29429,
#      'participantId': 9,
#      'itemId': 3340},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 29992,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 30256,
#      'participantId': 9,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 30983,
#      'participantId': 9,
#      'itemId': 3850},
#     {'type': 'WARD_PLACED',
#      'timestamp': 40693,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 43665,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 48983,
#      'participantId': 9,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 55953,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 8}],
#    'timestamp': 60016},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 1891, 'y': 12326},
#      'currentGold': 84,
#      'totalGold': 584,
#      'level': 1,
#      'xp': 181,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 3640, 'y': 6558},
#      'currentGold': 151,
#      'totalGold': 651,
#      'level': 2,
#      'xp': 350,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 6,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 7279, 'y': 7193},
#      'currentGold': 42,
#      'totalGold': 542,
#      'level': 1,
#      'xp': 211,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 12321, 'y': 1849},
#      'currentGold': 84,
#      'totalGold': 584,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 12722, 'y': 1834},
#      'currentGold': 23,
#      'totalGold': 523,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 2631, 'y': 12877},
#      'currentGold': 42,
#      'totalGold': 542,
#      'level': 1,
#      'xp': 181,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 12370, 'y': 6615},
#      'currentGold': 121,
#      'totalGold': 621,
#      'level': 2,
#      'xp': 320,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 7607, 'y': 7762},
#      'currentGold': 112,
#      'totalGold': 612,
#      'level': 1,
#      'xp': 270,
#      'minionsKilled': 5,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 12797, 'y': 2751},
#      'currentGold': 84,
#      'totalGold': 584,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 12797, 'y': 2751},
#      'currentGold': 23,
#      'totalGold': 523,
#      'level': 1,
#      'xp': 113,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_PLACED',
#      'timestamp': 61045,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 71151,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 2},
#     {'type': 'WARD_PLACED',
#      'timestamp': 81653,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 82611,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 83172,
#      'participantId': 2,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 85947,
#      'participantId': 10,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 86013,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 6},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 89778,
#      'participantId': 3,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 102031,
#      'participantId': 1,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 107811,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 108669,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 109429,
#      'participantId': 10,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 120034},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 1953, 'y': 12048},
#      'currentGold': 339,
#      'totalGold': 839,
#      'level': 2,
#      'xp': 632,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 2169, 'y': 9843},
#      'currentGold': 533,
#      'totalGold': 1033,
#      'level': 3,
#      'xp': 840,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 6482, 'y': 6280},
#      'currentGold': 304,
#      'totalGold': 804,
#      'level': 3,
#      'xp': 692,
#      'minionsKilled': 9,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 12574, 'y': 2769},
#      'currentGold': 455,
#      'totalGold': 955,
#      'level': 2,
#      'xp': 526,
#      'minionsKilled': 16,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 12469, 'y': 2801},
#      'currentGold': 232,
#      'totalGold': 732,
#      'level': 2,
#      'xp': 526,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 2254, 'y': 12648},
#      'currentGold': 330,
#      'totalGold': 830,
#      'level': 3,
#      'xp': 845,
#      'minionsKilled': 10,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 7166, 'y': 12363},
#      'currentGold': 618,
#      'totalGold': 1118,
#      'level': 3,
#      'xp': 995,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 20,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 6765, 'y': 6310},
#      'currentGold': 462,
#      'totalGold': 962,
#      'level': 3,
#      'xp': 904,
#      'minionsKilled': 16,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 13439, 'y': 3701},
#      'currentGold': 45,
#      'totalGold': 720,
#      'level': 1,
#      'xp': 198,
#      'minionsKilled': 4,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13969, 'y': 10939},
#      'currentGold': 142,
#      'totalGold': 717,
#      'level': 1,
#      'xp': 198,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 124328,
#      'participantId': 7,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 129480,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 130371,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 9},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 133807,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 136185,
#      'participantId': 2,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 137474,
#      'participantId': 6,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 146361,
#      'participantId': 10,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 147319,
#      'participantId': 5,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 152373,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 156900,
#      'participantId': 7,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 158288,
#      'participantId': 2,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 160269,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 1},
#     {'type': 'WARD_PLACED',
#      'timestamp': 162515,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 163010,
#      'participantId': 2,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 163242,
#      'participantId': 4,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_KILL',
#      'timestamp': 165752,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 168989,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 169121,
#      'participantId': 6,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 172886,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 7},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 174999,
#      'participantId': 8,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 175198,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 177509,
#      'participantId': 3,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'}],
#    'timestamp': 180060},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 2696, 'y': 12917},
#      'currentGold': 753,
#      'totalGold': 1253,
#      'level': 4,
#      'xp': 1295,
#      'minionsKilled': 25,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 691, 'y': 500},
#      'currentGold': 6,
#      'totalGold': 1156,
#      'level': 3,
#      'xp': 840,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 16,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 2557, 'y': 2345},
#      'currentGold': 150,
#      'totalGold': 1085,
#      'level': 4,
#      'xp': 1265,
#      'minionsKilled': 16,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 13089, 'y': 2723},
#      'currentGold': 683,
#      'totalGold': 1183,
#      'level': 3,
#      'xp': 827,
#      'minionsKilled': 22,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 13014, 'y': 1915},
#      'currentGold': 412,
#      'totalGold': 912,
#      'level': 3,
#      'xp': 827,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 5210, 'y': 9243},
#      'currentGold': 486,
#      'totalGold': 986,
#      'level': 3,
#      'xp': 1116,
#      'minionsKilled': 12,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 3860, 'y': 10625},
#      'currentGold': 953,
#      'totalGold': 1453,
#      'level': 4,
#      'xp': 1417,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 28,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 7174, 'y': 8148},
#      'currentGold': 1132,
#      'totalGold': 1632,
#      'level': 4,
#      'xp': 1644,
#      'minionsKilled': 24,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 13677, 'y': 3045},
#      'currentGold': 277,
#      'totalGold': 952,
#      'level': 3,
#      'xp': 688,
#      'minionsKilled': 8,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13677, 'y': 3045},
#      'currentGold': 337,
#      'totalGold': 912,
#      'level': 2,
#      'xp': 537,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 181215,
#      'participantId': 5,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 181710,
#      'participantId': 1,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 190660,
#      'participantId': 8,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 198357,
#      'participantId': 2,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 198654,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 199083,
#      'participantId': 4,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_KILL',
#      'timestamp': 202354,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 206385,
#      'participantId': 7,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 210217,
#      'participantId': 10,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 211605,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 212199,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 212992,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 5},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 214709,
#      'participantId': 4,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 219995,
#      'participantId': 6,
#      'itemId': 2003},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 221647,
#      'position': {'x': 6974, 'y': 8107},
#      'killerId': 7,
#      'victimId': 3,
#      'assistingParticipantIds': []},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 223364,
#      'participantId': 7,
#      'itemId': 2010},
#     {'type': 'WARD_PLACED',
#      'timestamp': 228055,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 230928,
#      'participantId': 3,
#      'itemId': 1052},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 234395,
#      'participantId': 8,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 237600,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 238822,
#      'participantId': 1,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 239847,
#      'participantId': 1,
#      'itemId': 1001}],
#    'timestamp': 240078},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 1716, 'y': 9413},
#      'currentGold': 89,
#      'totalGold': 1389,
#      'level': 4,
#      'xp': 1446,
#      'minionsKilled': 26,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 6957, 'y': 4657},
#      'currentGold': 205,
#      'totalGold': 1355,
#      'level': 3,
#      'xp': 1026,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 20,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 6924, 'y': 6633},
#      'currentGold': 719,
#      'totalGold': 1654,
#      'level': 5,
#      'xp': 2143,
#      'minionsKilled': 22,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 10257, 'y': 1220},
#      'currentGold': 945,
#      'totalGold': 1445,
#      'level': 4,
#      'xp': 1157,
#      'minionsKilled': 27,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 5501, 'y': 980},
#      'currentGold': 236,
#      'totalGold': 1061,
#      'level': 3,
#      'xp': 883,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 3830, 'y': 13325},
#      'currentGold': 484,
#      'totalGold': 1384,
#      'level': 4,
#      'xp': 1684,
#      'minionsKilled': 18,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 13603, 'y': 12678},
#      'currentGold': 45,
#      'totalGold': 1895,
#      'level': 4,
#      'xp': 1503,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 28,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 8200, 'y': 7868},
#      'currentGold': 238,
#      'totalGold': 1838,
#      'level': 5,
#      'xp': 2067,
#      'minionsKilled': 29,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 14340, 'y': 14391},
#      'currentGold': 867,
#      'totalGold': 1542,
#      'level': 4,
#      'xp': 1181,
#      'minionsKilled': 17,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 14334, 'y': 14362},
#      'currentGold': 666,
#      'totalGold': 1241,
#      'level': 3,
#      'xp': 1030,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_PLACED',
#      'timestamp': 243578,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 9},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 243578,
#      'participantId': 6,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 244569,
#      'participantId': 6,
#      'itemId': 2003},
#     {'type': 'WARD_PLACED',
#      'timestamp': 244998,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'WARD_PLACED',
#      'timestamp': 247343,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 254113,
#      'participantId': 7,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 254377,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 254708,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 5},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 258904,
#      'participantId': 8,
#      'itemId': 2003},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 261116,
#      'participantId': 7,
#      'itemId': 2010},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 262470,
#      'position': {'x': 8066, 'y': 8379},
#      'killerId': 3,
#      'victimId': 7,
#      'assistingParticipantIds': []},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 264056,
#      'position': {'x': 1708, 'y': 10950},
#      'killerId': 10,
#      'victimId': 5,
#      'assistingParticipantIds': [6]},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 264386,
#      'position': {'x': 11503, 'y': 1161},
#      'killerId': 8,
#      'victimId': 2,
#      'assistingParticipantIds': [9]},
#     {'type': 'WARD_KILL',
#      'timestamp': 266499,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 266962,
#      'participantId': 7,
#      'itemId': 3134},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 266962,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 267985,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 269043,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 269803,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 269935,
#      'participantId': 5,
#      'itemId': 3123},
#     {'type': 'WARD_KILL',
#      'timestamp': 270199,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'WARD_PLACED',
#      'timestamp': 273569,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 1},
#     {'type': 'WARD_KILL',
#      'timestamp': 277829,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'WARD_PLACED',
#      'timestamp': 278786,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 279645,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 279810,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 285921,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 290412,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 293884,
#      'participantId': 10,
#      'itemId': 3706},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 293884,
#      'participantId': 10,
#      'itemId': 1041},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 294709,
#      'participantId': 10,
#      'itemId': 1001},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 297285,
#      'participantId': 10,
#      'itemId': 1028},
#     {'type': 'WARD_PLACED',
#      'timestamp': 298078,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5}],
#    'timestamp': 300095},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 2289, 'y': 12529},
#      'currentGold': 345,
#      'totalGold': 1645,
#      'level': 5,
#      'xp': 1837,
#      'minionsKilled': 33,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 3411, 'y': 6654},
#      'currentGold': 613,
#      'totalGold': 1763,
#      'level': 4,
#      'xp': 1607,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 26,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 1000, 'y': 897},
#      'currentGold': 511,
#      'totalGold': 2311,
#      'level': 6,
#      'xp': 2757,
#      'minionsKilled': 33,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 10978, 'y': 1725},
#      'currentGold': 64,
#      'totalGold': 1589,
#      'level': 4,
#      'xp': 1396,
#      'minionsKilled': 28,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 11612, 'y': 1436},
#      'currentGold': 371,
#      'totalGold': 1196,
#      'level': 3,
#      'xp': 1043,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 3004, 'y': 13168},
#      'currentGold': 759,
#      'totalGold': 1659,
#      'level': 5,
#      'xp': 2255,
#      'minionsKilled': 26,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 8809, 'y': 9762},
#      'currentGold': 445,
#      'totalGold': 2295,
#      'level': 5,
#      'xp': 2144,
#      'minionsKilled': 2,
#      'jungleMinionsKilled': 36,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 10171, 'y': 9707},
#      'currentGold': 67,
#      'totalGold': 2017,
#      'level': 5,
#      'xp': 2218,
#      'minionsKilled': 32,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 12190, 'y': 2372},
#      'currentGold': 298,
#      'totalGold': 1843,
#      'level': 4,
#      'xp': 1480,
#      'minionsKilled': 25,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 11882, 'y': 3419},
#      'currentGold': 551,
#      'totalGold': 1376,
#      'level': 4,
#      'xp': 1236,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'SKILL_LEVEL_UP',
#      'timestamp': 300426,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 301647,
#      'participantId': 6,
#      'itemId': 2003},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 303234,
#      'participantId': 8,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 303366,
#      'participantId': 8,
#      'itemId': 1052},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 303399,
#      'participantId': 9,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 303663,
#      'participantId': 9,
#      'itemId': 1004},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 312616,
#      'participantId': 6,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 317371,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 318296,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 320080,
#      'participantId': 4,
#      'itemId': 1037},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 325430,
#      'participantId': 3,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 329131,
#      'participantId': 4,
#      'itemId': 2031},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 330387,
#      'position': {'x': 7120, 'y': 6726},
#      'killerId': 3,
#      'victimId': 7,
#      'assistingParticipantIds': [1]},
#     {'type': 'WARD_PLACED',
#      'timestamp': 338247,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_KILL',
#      'timestamp': 341252,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 343464,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'WARD_PLACED',
#      'timestamp': 345050,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 2},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 345050,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 347494,
#      'participantId': 10,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 347990,
#      'participantId': 5,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 349773,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 2},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 351292,
#      'participantId': 9,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 353208,
#      'participantId': 3,
#      'itemId': 3802},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 353208,
#      'participantId': 3,
#      'itemId': 1052},
#     {'type': 'WARD_PLACED',
#      'timestamp': 355124,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 9},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 355124,
#      'participantId': 9,
#      'itemId': 2055},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 357372,
#      'participantId': 3,
#      'itemId': 1001},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 359520,
#      'participantId': 3,
#      'afterId': 0,
#      'beforeId': 1001}],
#    'timestamp': 360115},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 2563, 'y': 13499},
#      'currentGold': 1315,
#      'totalGold': 2615,
#      'level': 6,
#      'xp': 2726,
#      'minionsKilled': 48,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 2072, 'y': 12485},
#      'currentGold': 1365,
#      'totalGold': 2515,
#      'level': 6,
#      'xp': 2475,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 32,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 6858, 'y': 6978},
#      'currentGold': 396,
#      'totalGold': 2496,
#      'level': 6,
#      'xp': 3178,
#      'minionsKilled': 37,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 10803, 'y': 3458},
#      'currentGold': 364,
#      'totalGold': 1889,
#      'level': 5,
#      'xp': 1792,
#      'minionsKilled': 36,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 11608, 'y': 3197},
#      'currentGold': 595,
#      'totalGold': 1420,
#      'level': 4,
#      'xp': 1439,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 10913, 'y': 13923},
#      'currentGold': 87,
#      'totalGold': 1887,
#      'level': 6,
#      'xp': 2708,
#      'minionsKilled': 29,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 1992, 'y': 12703},
#      'currentGold': 1067,
#      'totalGold': 2917,
#      'level': 6,
#      'xp': 2854,
#      'minionsKilled': 3,
#      'jungleMinionsKilled': 42,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 7592, 'y': 7437},
#      'currentGold': 441,
#      'totalGold': 2391,
#      'level': 6,
#      'xp': 2848,
#      'minionsKilled': 47,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 9839, 'y': 3361},
#      'currentGold': 704,
#      'totalGold': 2249,
#      'level': 5,
#      'xp': 1874,
#      'minionsKilled': 34,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 10813, 'y': 3285},
#      'currentGold': 1089,
#      'totalGold': 1914,
#      'level': 4,
#      'xp': 1631,
#      'minionsKilled': 2,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_KILL',
#      'timestamp': 360742,
#      'wardType': 'YELLOW_TRINKET',
#      'killerId': 9},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 361205,
#      'participantId': 3,
#      'itemId': 1029},
#     {'type': 'WARD_PLACED',
#      'timestamp': 364145,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_KILL',
#      'timestamp': 369396,
#      'wardType': 'UNDEFINED',
#      'killerId': 6},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 371707,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 373327,
#      'participantId': 7,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 375341,
#      'participantId': 6,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 381715,
#      'participantId': 2,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 388983,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 390502,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 8},
#     {'type': 'WARD_KILL',
#      'timestamp': 395622,
#      'wardType': 'CONTROL_WARD',
#      'killerId': 9},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 395853,
#      'position': {'x': 1896, 'y': 11520},
#      'killerId': 1,
#      'victimId': 6,
#      'assistingParticipantIds': [5]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 397306,
#      'participantId': 4,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 399488,
#      'participantId': 10,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 402791,
#      'participantId': 5,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 403716,
#      'participantId': 6,
#      'itemId': 3044},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 403716,
#      'participantId': 6,
#      'itemId': 1036},
#     {'type': 'WARD_PLACED',
#      'timestamp': 407483,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 407945,
#      'participantId': 8,
#      'skillSlot': 1,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 408210,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 408210,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 409960,
#      'position': {'x': 2072, 'y': 12485},
#      'killerId': 10,
#      'victimId': 1,
#      'assistingParticipantIds': []},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 412106,
#      'position': {'x': 1992, 'y': 12703},
#      'killerId': 5,
#      'victimId': 10,
#      'assistingParticipantIds': [1]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 413295,
#      'participantId': 1,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 415112,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 7},
#     {'type': 'WARD_PLACED',
#      'timestamp': 417426,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 4},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 417856,
#      'position': {'x': 11608, 'y': 3197},
#      'killerId': 9,
#      'victimId': 2,
#      'assistingParticipantIds': [8]}],
#    'timestamp': 420138},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 2532, 'y': 11839},
#      'currentGold': 630,
#      'totalGold': 3255,
#      'level': 7,
#      'xp': 3763,
#      'minionsKilled': 58,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 8660, 'y': 2399},
#      'currentGold': 273,
#      'totalGold': 2823,
#      'level': 6,
#      'xp': 2830,
#      'minionsKilled': 0,
#      'jungleMinionsKilled': 38,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 7558, 'y': 6169},
#      'currentGold': 1169,
#      'totalGold': 3269,
#      'level': 8,
#      'xp': 4214,
#      'minionsKilled': 47,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 11124, 'y': 1633},
#      'currentGold': 298,
#      'totalGold': 2123,
#      'level': 5,
#      'xp': 2150,
#      'minionsKilled': 43,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 11408, 'y': 1713},
#      'currentGold': 118,
#      'totalGold': 1568,
#      'level': 5,
#      'xp': 1797,
#      'minionsKilled': 1,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 1568, 'y': 10407},
#      'currentGold': 214,
#      'totalGold': 2014,
#      'level': 6,
#      'xp': 2708,
#      'minionsKilled': 29,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 9784, 'y': 7035},
#      'currentGold': 298,
#      'totalGold': 3188,
#      'level': 7,
#      'xp': 3220,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 46,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 8631, 'y': 8457},
#      'currentGold': 148,
#      'totalGold': 2548,
#      'level': 6,
#      'xp': 2999,
#      'minionsKilled': 49,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 13840, 'y': 8302},
#      'currentGold': 55,
#      'totalGold': 2755,
#      'level': 5,
#      'xp': 2249,
#      'minionsKilled': 40,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 13840, 'y': 8302},
#      'currentGold': 124,
#      'totalGold': 2474,
#      'level': 5,
#      'xp': 2005,
#      'minionsKilled': 2,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'CHAMPION_KILL',
#      'timestamp': 421294,
#      'position': {'x': 10660, 'y': 3376},
#      'killerId': 9,
#      'victimId': 4,
#      'assistingParticipantIds': [8]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 425787,
#      'participantId': 3,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 427207,
#      'participantId': 5,
#      'itemId': 3044},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 428562,
#      'participantId': 1,
#      'itemId': 3134},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 428562,
#      'participantId': 1,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 428991,
#      'participantId': 10,
#      'itemId': 3751},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 428991,
#      'participantId': 10,
#      'itemId': 1028},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 430213,
#      'participantId': 4,
#      'itemId': 1001},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 430378,
#      'participantId': 1,
#      'itemId': 3364},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 430378,
#      'participantId': 1,
#      'itemId': 3340},
#     {'type': 'ITEM_SOLD',
#      'timestamp': 432260,
#      'participantId': 10,
#      'itemId': 2031},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 432756,
#      'participantId': 7,
#      'itemId': 2010},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 432987,
#      'participantId': 2,
#      'itemId': 3114},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 432987,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 432987,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 433846,
#      'participantId': 9,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 434110,
#      'participantId': 5,
#      'itemId': 2055},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 434341,
#      'participantId': 1,
#      'skillSlot': 1,
#      'levelUpType': 'EVOLVE'},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 434605,
#      'position': {'x': 7335, 'y': 6911},
#      'killerId': 3,
#      'victimId': 7,
#      'assistingParticipantIds': []},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 434803,
#      'participantId': 10,
#      'itemId': 1401},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 434803,
#      'participantId': 10,
#      'itemId': 3751},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 434803,
#      'participantId': 10,
#      'itemId': 3706},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 435431,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'WARD_PLACED',
#      'timestamp': 436289,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 437313,
#      'participantId': 1,
#      'itemId': 3706},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 437313,
#      'participantId': 1,
#      'itemId': 1039},
#     {'type': 'WARD_PLACED',
# ...
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1773499,
#      'participantId': 1,
#      'skillSlot': 2,
#      'levelUpType': 'EVOLVE'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1773763,
#      'participantId': 10,
#      'itemId': 2138},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1773763,
#      'participantId': 10,
#      'itemId': 2138},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1776405,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1785322,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1789256,
#      'participantId': 3,
#      'itemId': 1033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1790676,
#      'participantId': 8,
#      'itemId': 2139},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1790676,
#      'participantId': 8,
#      'itemId': 2139},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1794377,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5}],
#    'timestamp': 1800620},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 13281, 'y': 7275},
#      'currentGold': 1437,
#      'totalGold': 14386,
#      'level': 16,
#      'xp': 15662,
#      'minionsKilled': 212,
#      'jungleMinionsKilled': 8,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 5679, 'y': 3824},
#      'currentGold': 532,
#      'totalGold': 14596,
#      'level': 16,
#      'xp': 16363,
#      'minionsKilled': 37,
#      'jungleMinionsKilled': 167,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 4621, 'y': 5426},
#      'currentGold': 966,
#      'totalGold': 12320,
#      'level': 16,
#      'xp': 15091,
#      'minionsKilled': 129,
#      'jungleMinionsKilled': 11,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 4185, 'y': 4633},
#      'currentGold': 413,
#      'totalGold': 8902,
#      'level': 13,
#      'xp': 10810,
#      'minionsKilled': 149,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 7787, 'y': 5974},
#      'currentGold': 490,
#      'totalGold': 6765,
#      'level': 12,
#      'xp': 9902,
#      'minionsKilled': 17,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 14340, 'y': 14391},
#      'currentGold': 3120,
#      'totalGold': 5470,
#      'level': 7,
#      'xp': 3763,
#      'minionsKilled': 39,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 13298, 'y': 8054},
#      'currentGold': 165,
#      'totalGold': 15294,
#      'level': 18,
#      'xp': 18811,
#      'minionsKilled': 74,
#      'jungleMinionsKilled': 167,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 5571, 'y': 5081},
#      'currentGold': 684,
#      'totalGold': 11098,
#      'level': 15,
#      'xp': 13911,
#      'minionsKilled': 163,
#      'jungleMinionsKilled': 10,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 5731, 'y': 6127},
#      'currentGold': 1659,
#      'totalGold': 18606,
#      'level': 17,
#      'xp': 17150,
#      'minionsKilled': 214,
#      'jungleMinionsKilled': 20,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 5731, 'y': 6127},
#      'currentGold': 729,
#      'totalGold': 9504,
#      'level': 15,
#      'xp': 13780,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'WARD_PLACED',
#      'timestamp': 1804321,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1804387,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 4},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1807260,
#      'wardType': 'CONTROL_WARD',
#      'creatorId': 2},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1807260,
#      'participantId': 2,
#      'itemId': 2055},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1807854,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1808152,
#      'participantId': 1,
#      'itemId': 3156},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1808152,
#      'participantId': 1,
#      'itemId': 3155},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1808152,
#      'participantId': 1,
#      'itemId': 1036},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1810069,
#      'participantId': 1,
#      'itemId': 3134},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1813934,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1816412,
#      'participantId': 10,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1819549,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 4},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1819813,
#      'participantId': 8,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1821332,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1827178,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 2},
#     {'type': 'WARD_KILL',
#      'timestamp': 1828301,
#      'wardType': 'BLUE_TRINKET',
#      'killerId': 2},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1834807,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1842241,
#      'participantId': 10,
#      'itemId': 3211},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1842241,
#      'participantId': 10,
#      'itemId': 1033},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1843562,
#      'wardType': 'BLUE_TRINKET',
#      'creatorId': 8},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1844718,
#      'wardType': 'SIGHT_WARD',
#      'creatorId': 9},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1848284,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_KILL',
#      'timestamp': 1848516,
#      'wardType': 'YELLOW_TRINKET',
#      'killerId': 7},
#     {'type': 'WARD_KILL',
#      'timestamp': 1849641,
#      'wardType': 'UNDEFINED',
#      'killerId': 7},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1850136,
#      'position': {'x': 7787, 'y': 5974},
#      'killerId': 8,
#      'victimId': 2,
#      'assistingParticipantIds': [9]}],
#    'timestamp': 1860644},
#   {'participantFrames': {'1': {'participantId': 5,
#      'position': {'x': 14047, 'y': 6956},
#      'currentGold': 2171,
#      'totalGold': 15120,
#      'level': 16,
#      'xp': 16281,
#      'minionsKilled': 222,
#      'jungleMinionsKilled': 8,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '2': {'participantId': 1,
#      'position': {'x': 2042, 'y': 2786},
#      'currentGold': 830,
#      'totalGold': 14894,
#      'level': 17,
#      'xp': 16717,
#      'minionsKilled': 45,
#      'jungleMinionsKilled': 167,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '3': {'participantId': 3,
#      'position': {'x': 1203, 'y': 963},
#      'currentGold': 1129,
#      'totalGold': 12604,
#      'level': 16,
#      'xp': 15318,
#      'minionsKilled': 131,
#      'jungleMinionsKilled': 11,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '4': {'participantId': 4,
#      'position': {'x': 2893, 'y': 3415},
#      'currentGold': 585,
#      'totalGold': 9075,
#      'level': 13,
#      'xp': 10860,
#      'minionsKilled': 149,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '5': {'participantId': 2,
#      'position': {'x': 1496, 'y': 2464},
#      'currentGold': 252,
#      'totalGold': 6977,
#      'level': 13,
#      'xp': 9978,
#      'minionsKilled': 18,
#      'jungleMinionsKilled': 4,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '6': {'participantId': 6,
#      'position': {'x': 14340, 'y': 14391},
#      'currentGold': 3242,
#      'totalGold': 5592,
#      'level': 7,
#      'xp': 3763,
#      'minionsKilled': 39,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '7': {'participantId': 10,
#      'position': {'x': 11065, 'y': 10556},
#      'currentGold': 478,
#      'totalGold': 15608,
#      'level': 18,
#      'xp': 19203,
#      'minionsKilled': 81,
#      'jungleMinionsKilled': 167,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '8': {'participantId': 7,
#      'position': {'x': 1933, 'y': 2544},
#      'currentGold': 1071,
#      'totalGold': 11486,
#      'level': 15,
#      'xp': 14424,
#      'minionsKilled': 166,
#      'jungleMinionsKilled': 10,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '9': {'participantId': 8,
#      'position': {'x': 2908, 'y': 2230},
#      'currentGold': 2019,
#      'totalGold': 18966,
#      'level': 17,
#      'xp': 17595,
#      'minionsKilled': 221,
#      'jungleMinionsKilled': 20,
#      'dominionScore': 0,
#      'teamScore': 0},
#     '10': {'participantId': 9,
#      'position': {'x': 2908, 'y': 2230},
#      'currentGold': 939,
#      'totalGold': 9714,
#      'level': 15,
#      'xp': 14278,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 0,
#      'dominionScore': 0,
#      'teamScore': 0}},
#    'events': [{'type': 'ITEM_PURCHASED',
#      'timestamp': 1865136,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1865334,
#      'participantId': 2,
#      'itemId': 1004},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 1866853,
#      'participantId': 2,
#      'afterId': 0,
#      'beforeId': 1004},
#     {'type': 'ITEM_UNDO',
#      'timestamp': 1867117,
#      'participantId': 2,
#      'afterId': 0,
#      'beforeId': 1004},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1867845,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1868671,
#      'participantId': 2,
#      'itemId': 1033},
#     {'type': 'BUILDING_KILL',
#      'timestamp': 1871676,
#      'position': {'x': 3203, 'y': 3208},
#      'killerId': 8,
#      'assistingParticipantIds': [7],
#      'teamId': 100,
#      'buildingType': 'INHIBITOR_BUILDING',
#      'laneType': 'MID_LANE',
#      'towerType': 'UNDEFINED_TURRET'},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1876270,
#      'participantId': 1,
#      'skillSlot': 3,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_KILL',
#      'timestamp': 1884364,
#      'wardType': 'UNDEFINED',
#      'killerId': 10},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1888825,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1896486,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 5},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1898732,
#      'position': {'x': 2893, 'y': 3415},
#      'killerId': 7,
#      'victimId': 4,
#      'assistingParticipantIds': [9]},
#     {'type': 'WARD_KILL',
#      'timestamp': 1899195,
#      'wardType': 'UNDEFINED',
#      'killerId': 10},
#     {'type': 'BUILDING_KILL',
#      'timestamp': 1906264,
#      'position': {'x': 13327, 'y': 8226},
#      'killerId': 5,
#      'assistingParticipantIds': [],
#      'teamId': 200,
#      'buildingType': 'TOWER_BUILDING',
#      'laneType': 'BOT_LANE',
#      'towerType': 'INNER_TURRET'},
#     {'type': 'ITEM_SOLD',
#      'timestamp': 1916140,
#      'participantId': 3,
#      'itemId': 1033},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1919840,
#      'participantId': 3,
#      'itemId': 1052}],
#    'timestamp': 1920665},
#   {'participantFrames': {'1': {'participantId': 5,
#      'currentGold': 184,
#      'totalGold': 16034,
#      'level': 17,
#      'xp': 17229,
#      'minionsKilled': 226,
#      'jungleMinionsKilled': 8},
#     '2': {'participantId': 1,
#      'currentGold': 1456,
#      'totalGold': 15581,
#      'level': 17,
#      'xp': 17651,
#      'minionsKilled': 47,
#      'jungleMinionsKilled': 167},
#     '3': {'participantId': 3,
#      'currentGold': -177,
#      'totalGold': 12848,
#      'level': 16,
#      'xp': 16016,
#      'minionsKilled': 132,
#      'jungleMinionsKilled': 11},
#     '4': {'participantId': 4,
#      'currentGold': 718,
#      'totalGold': 9268,
#      'level': 13,
#      'xp': 11349,
#      'minionsKilled': 149,
#      'jungleMinionsKilled': 0},
#     '5': {'participantId': 2,
#      'currentGold': 144,
#      'totalGold': 7139,
#      'level': 13,
#      'xp': 10285,
#      'minionsKilled': 18,
#      'jungleMinionsKilled': 4},
#     '6': {'participantId': 6,
#      'currentGold': 3340,
#      'totalGold': 5690,
#      'level': 7,
#      'xp': 3763,
#      'minionsKilled': 39,
#      'jungleMinionsKilled': 0},
#     '7': {'participantId': 10,
#      'currentGold': 26,
#      'totalGold': 15776,
#      'level': 18,
#      'xp': 19264,
#      'minionsKilled': 82,
#      'jungleMinionsKilled': 167},
#     '8': {'participantId': 7,
#      'currentGold': 184,
#      'totalGold': 11759,
#      'level': 16,
#      'xp': 14856,
#      'minionsKilled': 166,
#      'jungleMinionsKilled': 10},
#     '9': {'participantId': 8,
#      'currentGold': 2254,
#      'totalGold': 19566,
#      'level': 17,
#      'xp': 18122,
#      'minionsKilled': 225,
#      'jungleMinionsKilled': 20},
#     '10': {'participantId': 9,
#      'currentGold': 1151,
#      'totalGold': 9926,
#      'level': 16,
#      'xp': 14903,
#      'minionsKilled': 6,
#      'jungleMinionsKilled': 0}},
#    'events': [{'type': 'ITEM_PURCHASED',
#      'timestamp': 1921492,
#      'participantId': 5,
#      'itemId': 3065},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1921492,
#      'participantId': 5,
#      'itemId': 3067},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1922681,
#      'position': {'x': 1592, 'y': 2401},
#      'killerId': 7,
#      'victimId': 2,
#      'assistingParticipantIds': [8, 9]},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1923605,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1927040,
#      'position': {'x': 1944, 'y': 1609},
#      'killerId': 5,
#      'victimId': 7,
#      'assistingParticipantIds': [1, 3, 2]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1928032,
#      'participantId': 5,
#      'skillSlot': 2,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1932231,
#      'participantId': 7,
#      'itemId': 3035},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1932231,
#      'participantId': 7,
#      'itemId': 1036},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1936496,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1939209,
#      'position': {'x': 4134, 'y': 2888},
#      'killerId': 8,
#      'victimId': 3,
#      'assistingParticipantIds': [7, 9]},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1940564,
#      'position': {'x': 4315, 'y': 3208},
#      'killerId': 5,
#      'victimId': 8,
#      'assistingParticipantIds': [1, 3]},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1945851,
#      'participantId': 9,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1948131,
#      'wardType': 'YELLOW_TRINKET',
#      'creatorId': 10},
#     {'type': 'WARD_PLACED',
#      'timestamp': 1950840,
#      'wardType': 'UNDEFINED',
#      'creatorId': 5},
#     {'type': 'SKILL_LEVEL_UP',
#      'timestamp': 1951434,
#      'participantId': 7,
#      'skillSlot': 4,
#      'levelUpType': 'NORMAL'},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1954406,
#      'participantId': 2,
#      'itemId': 1057},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1954406,
#      'participantId': 2,
#      'itemId': 1033},
#     {'type': 'CHAMPION_KILL',
#      'timestamp': 1960952,
#      'position': {'x': 1937, 'y': 2391},
#      'killerId': 1,
#      'victimId': 9,
#      'assistingParticipantIds': [5, 4]},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1962538,
#      'participantId': 5,
#      'itemId': 2140},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1962538,
#      'participantId': 5,
#      'itemId': 2140},
#     {'type': 'ITEM_PURCHASED',
#      'timestamp': 1963100,
#      'participantId': 3,
#      'itemId': 3136},
#     {'type': 'ITEM_DESTROYED',
#      'timestamp': 1963100,
#      'participantId': 3,
#      'itemId': 1052}],
#    'timestamp': 1980665}],
#  'frameInterval': 60000}

# %%
match_obj_dict = {} #iinitialize dict

# %% [markdown]
# <a id ='explore'> </a>
#
# # Data Preprocessing

# %% [markdown]
# ### Extract match info / Create features
# The match data extracted from Riot's API contains comprehensive information about the gamestate at every minute interval. This includes player locations, experience points, items, etc. Data concerning objectives was extracted from match_details and match_timeline dictionaries. The extracted post-game data is stored in match_results_dict with 20275 matches.

# %%
#functions used to create the first df and model which predicts winners based on post-game stats
# %%time
for gameId in matchlist:
    
    match_detail = match_detail_dict[gameId] #retrieve game details from dict
    match_stats = {} #initialize dict for game
    #create a key for the game winner
    match_stats['GameDuration'] = match_detail['gameDuration']
    if match_detail['teams'][0]['win'] == 'Win':
        match_stats['Winner'] = 'blue' 
    elif match_detail['teams'][1]['win'] == 'Win':
        match_stats['Winner'] = 'red' 

    #store bool params in match details
    for param in bool_params:
        if match_detail['teams'][0][param] == True:
            match_stats[param] = 'blue'
        elif match_detail['teams'][1][param] == True:
            match_stats[param] = 'red'

    #store num params in match details
    for param in num_params:
        match_stats['blue'+param] = match_detail['teams'][0][param]
        match_stats['red'+param] = match_detail['teams'][1][param]


    match_timeline = match_timeline_dict[gameId]
    #create a key for objective stats
    match_obj = []
    for i in range(len(match_timeline['frames'])):
        for event in match_timeline['frames'][i]['events']:
            #type == 'ELITE_MONSTER_KILL'
            if event['type'] == 'ELITE_MONSTER_KILL':
                if event['killerId'] == 0:
                    pass
                elif event['killerId'] > 0:
                    obj = {}
                    obj['ObjectiveType'] = event['monsterType']
                    if event['monsterType'] == 'DRAGON':
                        obj['DragElement'] = event['monsterSubType']
                    obj['timestamp'] = event['timestamp']
                    if 1<= event['killerId'] <= 5:
                        obj['team'] = 'blue'
                    elif 6<= event['killerId'] <= 10:
                        obj['team'] = 'red'
                    match_obj.append(obj)

    match_obj_dict[gameId] = match_obj
    if len(match_obj) > 0:
        obj_timeline_df = pd.DataFrame(match_obj)

        if obj_timeline_df[obj_timeline_df['ObjectiveType'] == 'DRAGON'].shape[0] > 0:
            
            #store team+timestamp of any elder dragons
            elder_drag_df = obj_timeline_df[obj_timeline_df['DragElement'] == 'ELDER_DRAGON'].reset_index()
            for row_idx, row in elder_drag_df.iterrows():
                match_stats[str(row_idx+1)+'ELDER_DRAGONteam'] = row['team']
                match_stats[str(row_idx+1)+'ELDER_DRAGONtime'] = row['timestamp']
            
            elem_drag_df = obj_timeline_df[obj_timeline_df['DragElement'] != 'ELDER_DRAGON'].dropna(axis=0).reset_index()
            #store total# of elemental drakes on each team, soul dragon info, and # of types of drakes for each team
            for side in ['blue', 'red']:
                match_stats[side+'ElemDragNum'] = elem_drag_df[elem_drag_df['team'] == side].shape[0]
                if match_stats[side+'ElemDragNum'] == 4:
                    match_stats[str(elem_drag_df['DragElement'][2])+'Soulteam'] = side
                    match_stats[str(elem_drag_df['DragElement'][2])+'Soultime'] = elem_drag_df[elem_drag_df['team'] == side].reset_index()['timestamp'][3]
                for drag_elem in list(elem_drag_df['DragElement'].unique()):
                    match_stats[str(side+drag_elem)] = elem_drag_df.query('DragElement == @drag_elem and team == @side').shape[0]

            for row_idx, row in elem_drag_df.iterrows():
                match_stats[str(row_idx+1)+str(row['DragElement'])+'team'] = row['team']
                match_stats[str(row_idx+1)+str(row['DragElement'])+'time'] = row['timestamp']

        if obj_timeline_df[obj_timeline_df['ObjectiveType'] != 'DRAGON'].shape[0] > 0:
            #store details about rift heralds and barons killed
            for obj_type in ['RIFTHERALD', 'BARON_NASHOR']:
                #slice the df with the relevant objective
                obj_type_df = obj_timeline_df[obj_timeline_df['ObjectiveType'] == obj_type].reset_index()

                #for each herald/baron, extract the team that killed the objective and the time it occured
                for row_idx, row in obj_type_df.iterrows():
                    match_stats[str(obj_type+str(row_idx+1)+'team')] = obj_type_df['team'][row_idx]
                    match_stats[str(obj_type+str(row_idx+1)+'time')] = obj_type_df['timestamp'][row_idx]
    
    match_stats_dict3 [gameId] = match_stats
# Out:
# Wall time: 12min 42s

# %%
bool_params = ['firstTower', 'firstInhibitor', 'firstBaron', 'firstDragon', 
               'firstRiftHerald']
num_params = ['baronKills', 'riftHeraldKills', 'dragonKills']

# %%
#obtain the longest game time in the dataset to determine 
#a reasonable maximum time interval for obtaining gamestate
df['GameDuration'].max()/60
# Out:
# 58.45

# %%
# %%time
match_results_dict, list_time_dicts = gamestate_by_time(list(match_detail_dict.keys()))
# Out:
# Wall time: 10min 28s

# %%
match_results_dict
# Out:
# {3411673088: {'GameDuration': 1195,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -2},
#  3435528193: {'GameDuration': 1516,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3447586821: {'GameDuration': 1964,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3426877449: {'GameDuration': 915,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3419144205: {'GameDuration': 1176,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3428843533: {'GameDuration': 758,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3433824271: {'GameDuration': 1154,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3445751824: {'GameDuration': 1954,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 5},
#  3442737172: {'GameDuration': 1716,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3397648407: {'GameDuration': 1511,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -1},
#  3422683163: {'GameDuration': 1436,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 4},
#  3383099420: {'GameDuration': 621,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3442868254: {'GameDuration': 1519,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -4},
#  3421372448: {'GameDuration': 942,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3441557537: {'GameDuration': 1941,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 3},
#  3431858209: {'GameDuration': 1747,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3433168932: {'GameDuration': 2054,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3439329317: {'GameDuration': 1763,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -2},
#  3445358630: {'GameDuration': 1639,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3435135015: {'GameDuration': 1420,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -4},
#  3446931493: {'GameDuration': 1454,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3408527402: {'GameDuration': 623,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3442999340: {'GameDuration': 1065,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3411935277: {'GameDuration': 1678,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 3},
#  3438280750: {'GameDuration': 1524,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3403677743: {'GameDuration': 1592,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -1},
#  3446931503: {'GameDuration': 1354,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3333816369: {'GameDuration': 1789,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3442429427: {'GameDuration': 1509,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 4},
#  3433693240: {'GameDuration': 1773,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3437625401: {'GameDuration': 838,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3445882941: {'GameDuration': 1259,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3396337725: {'GameDuration': 1522,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3416391746: {'GameDuration': 1348,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3323854914: {'GameDuration': 1768,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -4},
#  3426091077: {'GameDuration': 879,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3398041670: {'GameDuration': 1507,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 4},
#  3447586889: {'GameDuration': 1334,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3444572234: {'GameDuration': 946,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3446276173: {'GameDuration': 1076,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3378643023: {'GameDuration': 1741,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -3},
#  3422814288: {'GameDuration': 1192,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 2},
#  3446145105: {'GameDuration': 1447,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 4},
#  3384934484: {'GameDuration': 1829,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3435790421: {'GameDuration': 1184,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3435528278: {'GameDuration': 719,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3347578965: {'GameDuration': 1543,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 0},
#  3422552155: {'GameDuration': 647,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3405119580: {'GameDuration': 2256,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3448766565: {'GameDuration': 1774,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3431858280: {'GameDuration': 1189,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3412197481: {'GameDuration': 2141,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': 1},
#  3439198314: {'GameDuration': 1532,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 3},
#  3441950828: {'GameDuration': 2100,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 1},
#  3444834413: {'GameDuration': 962,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3443785838: {'GameDuration': 1141,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3440377967: {'GameDuration': 1349,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3384672365: {'GameDuration': 1097,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3440902257: {'GameDuration': 1430,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3425435758: {'GameDuration': 2183,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': 1},
#  3432513651: {'GameDuration': 1417,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -3},
#  3436707956: {'GameDuration': 1734,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 0},
#  3421503604: {'GameDuration': 1118,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3445882990: {'GameDuration': 1465,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3418620024: {'GameDuration': 1598,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3386638457: {'GameDuration': 1699,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3421241469: {'GameDuration': 1370,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 3},
#  3437363330: {'GameDuration': 951,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3334602883: {'GameDuration': 1323,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3404071043: {'GameDuration': 2372,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 3,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3438018694: {'GameDuration': 762,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3444703368: {'GameDuration': 1093,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3432120460: {'GameDuration': 2318,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -2},
#  3434741902: {'GameDuration': 731,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3442999440: {'GameDuration': 1655,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3435135120: {'GameDuration': 1521,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 3},
#  3442868371: {'GameDuration': 1509,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -3},
#  3416785043: {'GameDuration': 1672,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -2},
#  3412197524: {'GameDuration': 1273,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3398959254: {'GameDuration': 1586,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3406168214: {'GameDuration': 1223,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3439329431: {'GameDuration': 1179,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3442868372: {'GameDuration': 1972,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3428581530: {'GameDuration': 2175,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 3},
#  3434217627: {'GameDuration': 947,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3368026274: {'GameDuration': 1773,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 4},
#  3323199651: {'GameDuration': 1067,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3368026276: {'GameDuration': 1101,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3407347877: {'GameDuration': 2169,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -1},
#  3435004070: {'GameDuration': 1468,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 3},
#  3441950888: {'GameDuration': 1350,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3448111275: {'GameDuration': 1178,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3419537579: {'GameDuration': 1765,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -4},
#  3401973936: {'GameDuration': 1755,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3410100401: {'GameDuration': 1341,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3413115064: {'GameDuration': 1471,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': 1},
#  3423862968: {'GameDuration': 1420,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 0},
#  3358458050: {'GameDuration': 1508,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 3},
#  3356885187: {'GameDuration': 917,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3443916996: {'GameDuration': 1358,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  3396337861: {'GameDuration': 1480,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3428581574: {'GameDuration': 1146,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  3445752005: {'GameDuration': 1290,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3444572359: {'GameDuration': 1501,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3444703432: {'GameDuration': 1282,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3441164490: {'GameDuration': 1924,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -4},
#  3429630160: {'GameDuration': 1591,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 2},
#  3438543058: {'GameDuration': 1871,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -1},
#  3436576981: {'GameDuration': 1259,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3424911576: {'GameDuration': 1120,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3446538457: {'GameDuration': 1025,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3425566938: {'GameDuration': 1167,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3411542232: {'GameDuration': 1694,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3423863006: {'GameDuration': 1028,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3426877665: {'GameDuration': 1847,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3436183779: {'GameDuration': 1640,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3440115940: {'GameDuration': 1392,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 3},
#  3436839145: {'GameDuration': 1306,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3441819886: {'GameDuration': 1409,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -1},
#  3437101295: {'GameDuration': 1902,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3434873078: {'GameDuration': 2226,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3445358839: {'GameDuration': 1444,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 3},
#  3441033464: {'GameDuration': 1426,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3431596282: {'GameDuration': 2527,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -2},
#  3441950972: {'GameDuration': 1104,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3431596288: {'GameDuration': 1266,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -3},
#  3442999553: {'GameDuration': 1288,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3447456000: {'GameDuration': 1656,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -2},
#  3388211462: {'GameDuration': 1541,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': 0},
#  3422421261: {'GameDuration': 1350,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -3},
#  3415212302: {'GameDuration': 1252,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3395420430: {'GameDuration': 1205,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -1},
#  3337879822: {'GameDuration': 1438,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3437232402: {'GameDuration': 1154,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3411149075: {'GameDuration': 1829,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3441688850: {'GameDuration': 965,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3433431314: {'GameDuration': 1509,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -3},
#  3447324947: {'GameDuration': 1248,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -3},
#  3438018840: {'GameDuration': 1964,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 3},
#  3447456024: {'GameDuration': 1411,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3442737434: {'GameDuration': 1955,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -3},
#  3434610969: {'GameDuration': 946,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 1},
#  3433169181: {'GameDuration': 1922,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3425304862: {'GameDuration': 1526,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3412853023: {'GameDuration': 1546,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -1},
#  3425960221: {'GameDuration': 1296,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3423863073: {'GameDuration': 1346,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3428450595: {'GameDuration': 1219,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 4},
#  3401974053: {'GameDuration': 1628,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -4},
#  3375497510: {'GameDuration': 1502,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 1},
#  3436577062: {'GameDuration': 731,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3430809896: {'GameDuration': 1814,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3368026417: {'GameDuration': 1631,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3428450611: {'GameDuration': 1131,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 0},
#  3432251701: {'GameDuration': 1348,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 4},
#  3334471991: {'GameDuration': 2033,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 1},
#  3428188473: {'GameDuration': 1084,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3399876921: {'GameDuration': 966,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3434479933: {'GameDuration': 1232,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3424649534: {'GameDuration': 1881,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 2,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 3},
#  3429237054: {'GameDuration': 1267,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3439198533: {'GameDuration': 1004,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3429630280: {'GameDuration': 1741,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -4},
#  3395551564: {'GameDuration': 1566,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3404726605: {'GameDuration': 967,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3447849294: {'GameDuration': 1388,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3425435983: {'GameDuration': 2566,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3447980369: {'GameDuration': 1809,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 4},
#  3399745874: {'GameDuration': 1570,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 1},
#  3435004243: {'GameDuration': 598,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3418882388: {'GameDuration': 707,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3387162965: {'GameDuration': 2333,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3413639510: {'GameDuration': 1567,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3439460696: {'GameDuration': 1797,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  2859991384: {'GameDuration': 2078,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 4},
#  3447718232: {'GameDuration': 1972,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -5},
#  3421765977: {'GameDuration': 974,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 3},
#  3447849313: {'GameDuration': 1280,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3412197729: {'GameDuration': 2572,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 0},
#  3424911715: {'GameDuration': 1649,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3438281061: {'GameDuration': 1197,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3415212391: {'GameDuration': 1627,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3444965739: {'GameDuration': 1448,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -4},
#  3436839276: {'GameDuration': 749,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3307995501: {'GameDuration': 1625,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  3428188529: {'GameDuration': 1521,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3434479987: {'GameDuration': 1751,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -4},
#  3443917172: {'GameDuration': 1889,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3438543221: {'GameDuration': 1381,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3368288627: {'GameDuration': 1632,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 4},
#  3438412151: {'GameDuration': 939,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3402891639: {'GameDuration': 2311,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3446014323: {'GameDuration': 1890,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3315597690: {'GameDuration': 1347,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3446276475: {'GameDuration': 935,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3397124474: {'GameDuration': 921,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -2},
#  3258057085: {'GameDuration': 1673,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3438281086: {'GameDuration': 1414,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3368943999: {'GameDuration': 2234,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 5},
#  3442868610: {'GameDuration': 1471,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 3},
#  3375497603: {'GameDuration': 1515,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3375497605: {'GameDuration': 921,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3363045767: {'GameDuration': 1893,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -2},
#  3422421387: {'GameDuration': 1106,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 0},
#  3436315019: {'GameDuration': 1257,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3443917198: {'GameDuration': 1355,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3430678933: {'GameDuration': 1901,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 4},
#  3415212438: {'GameDuration': 764,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3227124123: {'GameDuration': 1577,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3413639585: {'GameDuration': 1180,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 0},
#  3361604004: {'GameDuration': 855,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
# ...
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3433826050: {'GameDuration': 998,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 2},
#  3440903934: {'GameDuration': 1293,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3401058053: {'GameDuration': 1643,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -4},
#  3443918597: {'GameDuration': 2094,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3442607883: {'GameDuration': 1651,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -1},
#  3441821451: {'GameDuration': 2121,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 1},
#  3442083600: {'GameDuration': 952,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 0},
#  3411937040: {'GameDuration': 1220,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3402499859: {'GameDuration': 1732,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': -4},
#  3414689556: {'GameDuration': 974,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3380610836: {'GameDuration': 2184,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3435136791: {'GameDuration': 1007,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3440772889: {'GameDuration': 1216,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3416917786: {'GameDuration': 912,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3428058908: {'GameDuration': 1400,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 2},
#  3406169887: {'GameDuration': 1433,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3442345760: {'GameDuration': 1283,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3429238561: {'GameDuration': 1406,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3388081953: {'GameDuration': 1121,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 2},
#  3416655654: {'GameDuration': 944,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -1},
#  3440248614: {'GameDuration': 1941,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -5},
#  3448112940: {'GameDuration': 1574,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3343779628: {'GameDuration': 1526,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 1},
#  3422029616: {'GameDuration': 1183,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3408004915: {'GameDuration': 1338,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3420063539: {'GameDuration': 1183,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3396339510: {'GameDuration': 2619,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -2},
#  3414820663: {'GameDuration': 1357,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3408529211: {'GameDuration': 1175,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 2},
#  3447195452: {'GameDuration': 1459,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3436054331: {'GameDuration': 1819,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 5},
#  3439068990: {'GameDuration': 1563,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3444574015: {'GameDuration': 1844,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -4},
#  3430811458: {'GameDuration': 1196,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3447850819: {'GameDuration': 1800,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 3},
#  3387950919: {'GameDuration': 1119,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -1},
#  3437365065: {'GameDuration': 1465,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 2},
#  3409708874: {'GameDuration': 1934,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': 1},
#  3429762891: {'GameDuration': 1266,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3397781326: {'GameDuration': 1998,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3409446739: {'GameDuration': 2166,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3440904020: {'GameDuration': 1233,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': -2,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3444967254: {'GameDuration': 1619,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3386771289: {'GameDuration': 1388,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3358066521: {'GameDuration': 971,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 0},
#  3325036379: {'GameDuration': 1513,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -3},
#  3397257053: {'GameDuration': 1261,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -2},
#  3411150686: {'GameDuration': 915,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3337750371: {'GameDuration': 1596,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 2},
#  3436578661: {'GameDuration': 1169,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3434874726: {'GameDuration': 1832,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -4},
#  3421374311: {'GameDuration': 1176,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3445753704: {'GameDuration': 999,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3431335786: {'GameDuration': 1019,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  3421374315: {'GameDuration': 954,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 2,
#   'dragonKillsdiff': 1},
#  3424388972: {'GameDuration': 821,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3430287215: {'GameDuration': 1667,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': -2,
#   'dragonKillsdiff': -1},
#  3410757490: {'GameDuration': 1473,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3442345844: {'GameDuration': 1288,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': 0},
#  3394897781: {'GameDuration': 1645,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -2},
#  3425175413: {'GameDuration': 1749,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 4},
#  3431204729: {'GameDuration': 1005,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -1},
#  3409839994: {'GameDuration': 990,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': -1,
#   'dragonKillsdiff': -2},
#  3447195516: {'GameDuration': 2260,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0},
#  3399878526: {'GameDuration': 2271,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': 0},
#  3440641921: {'GameDuration': 1963,
#   'Winner': 'red',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'firstBaron': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -2},
#  3439200129: {'GameDuration': 1169,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'baronKillsdiff': -1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  3442870148: {'GameDuration': 957,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstBaron': 'blue',
#   'firstDragon': 'red',
#   'baronKillsdiff': 1,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': -4},
#  3366193030: {'GameDuration': 2107,
#   'Winner': 'blue',
#   'firstTower': 'red',
#   'firstInhibitor': 'blue',
#   'firstBaron': 'red',
#   'firstDragon': 'blue',
#   'firstRiftHerald': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 1},
#  ...}

# %% [markdown]
# match_results_dict features:
# - 'GameDuration':
# - 'Winner'
# - 'firstTower'
# - 'firstInhibitor'
# - 'firstDragon'
# - 'firstRiftHerald'
# - 'baronKillsdiff'
# - 'riftHeraldKillsdiff'
# - 'dragonKillsdiff'

# %%
match_results_dict
# Out:
# {3411673088: {'GameDuration': 1195,
#   'Winner': 'red',
#   'firstTower': 'red',
#   'firstInhibitor': 'red',
#   'firstDragon': 'red',
#   'firstRiftHerald': 'blue',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 1,
#   'dragonKillsdiff': -2},
#  3435528193: {'GameDuration': 1516,
#   'Winner': 'blue',
#   'firstTower': 'blue',
#   'firstInhibitor': 'red',
#   'baronKillsdiff': 0,
#   'riftHeraldKillsdiff': 0,
#   'dragonKillsdiff': 0}}

# %%
len(match_results_dict)
# Out:
# 20275

# %%
#create df of match_results_dict
#add dragon soul to this df
df_results = pd.DataFrame(match_results_dict).transpose()

# %%
df_results
# Out:
#            GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088         1195    red        red            red         red
# 3435528193         1516   blue       blue            red         NaN
# 3447586821         1964   blue        red            red         red
# 3426877449          915    red        red            NaN         red
# 3419144205         1176    red        red            red         red
# ...                 ...    ...        ...            ...         ...
# 3444742545         1326    red        red            red         red
# 3424164242         1915   blue       blue           blue        blue
# 3405814162         1208    red        red            red        blue
# 3419838867         1305   blue       blue           blue        blue
# 3447495054         1658    red        red            red         red
#
#            firstRiftHerald baronKillsdiff riftHeraldKillsdiff dragonKillsdiff  \
# 3411673088            blue              0                   1              -2
# 3435528193             NaN              0                   0               0
# 3447586821             NaN              1                   0              -3
# 3426877449             red              0                  -1              -2
# 3419144205            blue              0                   0              -2
# ...                    ...            ...                 ...             ...
# 3444742545             red             -1                  -1              -3
# 3424164242            blue              1                   1               1
# 3405814162            blue              0                   0              -1
# 3419838867            blue              0                   2               3
# 3447495054            blue              0                   2              -2
#
#            FIRE_DRAGONdiff EARTH_DRAGONdiff firstBaron FIRE_DRAGONSoul  \
# 3411673088              -1               -1        NaN             NaN
# 3435528193             NaN              NaN        NaN             NaN
# 3447586821              -2               -1       blue             red
# 3426877449             NaN               -1        NaN             NaN
# 3419144205              -1              NaN        NaN             NaN
# ...                    ...              ...        ...             ...
# 3444742545              -1               -1        red             NaN
# 3424164242             NaN                1       blue             NaN
# 3405814162               1               -1        NaN             NaN
# 3419838867               1                1        NaN             NaN
# 3447495054             NaN               -1        NaN             NaN
#
#            AIR_DRAGONdiff ELDER_DRAGONdiff WATER_DRAGONdiff EARTH_DRAGONSoul  \
# 3411673088            NaN              NaN              NaN              NaN
# 3435528193            NaN              NaN              NaN              NaN
# 3447586821             -1                1              NaN              NaN
# 3426877449            NaN              NaN               -1              NaN
# 3419144205            NaN              NaN               -1              NaN
# ...                   ...              ...              ...              ...
# 3444742545             -1              NaN              NaN              NaN
# 3424164242              1              NaN               -1              NaN
# 3405814162            NaN              NaN               -1              NaN
# 3419838867            NaN              NaN                1              NaN
# 3447495054            NaN              NaN               -1              NaN
#
#            WATER_DRAGONSoul AIR_DRAGONSoul
# 3411673088              NaN            NaN
# 3435528193              NaN            NaN
# 3447586821              NaN            NaN
# 3426877449              NaN            NaN
# 3419144205              NaN            NaN
# ...                     ...            ...
# 3444742545              NaN            NaN
# 3424164242              NaN            NaN
# 3405814162              NaN            NaN
# 3419838867              NaN            NaN
# 3447495054              NaN            NaN
#
# [20275 rows x 19 columns]

# %% [markdown]
# # First look at the data

# %% [markdown]
# ### Removing "remakes"

# %% [markdown]
# The outcome for every match is **always** either red or blue with no missing values. However, the outcome may not always be meaningful - if there are players who never load into the game, their teams are able to surrender within the first few minutes. These games are considered "remakes", and their outcomes are meaningless even though winners are still assigned. Remakes are available from 3:00 to 4:00 and takes a maximum of 90 seconds, meaning that 5:30 would be the longest time possible for a remake. Therefore the remakes are dropped from the dataset by removing any games under 5:30 mins length (330s).

# %% [markdown]
# #### Quick Look at Game Lengths
#
# The mean match length is 24 minutes with a stardard deviation of 7 minutes. Over 2/3 of the match are between 16:49 and 31:19 minutes in length, and 95% of match are between 9:33 and 38:34.

# %%
s_descrip_gamelength = (df_results['GameDuration']/60).describe()
s_descrip_gamelength
# Out:
# count    20275.000000
# mean        24.063714
# std          7.253025
# min          3.166667
# 25%         18.766667
# 50%         23.583333
# 75%         29.050000
# max         58.450000
# Name: GameDuration, dtype: float64

# %%
((df_results['GameDuration']/60).round(0)).median()
# Out:
# 24.0

# %%
((df_results['GameDuration']/60).round(0)).mode()
# Out:
# 0    22.0
# dtype: float64

# %%
display(str('1st upper STD:'), s_descrip_gamelength['mean']+s_descrip_gamelength['std'], '1st lower STD:', s_descrip_gamelength['mean']-s_descrip_gamelength['std'])
display(str('2nd upper STD:'), s_descrip_gamelength['mean']+s_descrip_gamelength['std']*2, '2nd lower STD:', s_descrip_gamelength['mean']-s_descrip_gamelength['std']*2)
# Out:
# '1st upper STD:'
# 31.31673902955386
# '1st lower STD:'
# 16.810688837277535
# '2nd upper STD:'
# 38.569764125692025
# '2nd lower STD:'
# 9.557663741139372

# %% [markdown]
# The histogram of match length distribution shows that there is an outlier group of matches at 3-4 minutes. This group represents the remake games explained above.

# %%
plt.hist(df_results['GameDuration']/60, bins = 30)
plt.xlabel('Game length (min)', fontsize = 12)
plt.ylabel('# Games', fontsize = 12)
plt.title('Distribution of Game Lengths (Figure 2)')
# Out:
# Text(0.5, 1.0, 'Distribution of Game Lengths (Figure 2)')

# %%
df_dropped = df_results[df_results['GameDuration'] > 330]

# %%
df_dropped.shape[0]
# Out:
# 20154

# %%
plt.hist(df_dropped['GameDuration']/60, bins = 60)
plt.xlabel('Game length (min)', fontsize = 12)
plt.ylabel('# Games', fontsize = 12)
plt.title('Distribution of Game Lengths, remake games dropped (Figure 3)')
# Out:
# Text(0.5, 1.0, 'Distribution of Game Lengths, remake games dropped (Figure 3)')

# %% [markdown]
# The histogram was re-plotted to confirm that the data dropping was successful.

# %% [markdown]
# #### Initial look at post-game dataframe

# %%
df_dropped
# Out:
#             GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088          1195    red        red            red         red
# 3435528193          1516   blue       blue            red         NaN
# 3447586821          1964   blue        red            red         red
# 3426877449           915    red        red            NaN         red
# 3419144205          1176    red        red            red         red
# ...                  ...    ...        ...            ...         ...
# 3444742545          1326    red        red            red         red
# 3424164242          1915   blue       blue           blue        blue
# 3405814162          1208    red        red            red        blue
# 3419838867          1305   blue       blue           blue        blue
# 3447495054          1658    red        red            red         red
#
#            firstRiftHerald  baronKillsdiff  riftHeraldKillsdiff  \
# 3411673088            blue               0                    1
# 3435528193             NaN               0                    0
# 3447586821             NaN               1                    0
# 3426877449             red               0                   -1
# 3419144205            blue               0                    0
# ...                    ...             ...                  ...
# 3444742545             red              -1                   -1
# 3424164242            blue               1                    1
# 3405814162            blue               0                    0
# 3419838867            blue               0                    2
# 3447495054            blue               0                    2
#
#             dragonKillsdiff  FIRE_DRAGONdiff  EARTH_DRAGONdiff firstBaron  \
# 3411673088               -2             -1.0              -1.0        NaN
# 3435528193                0              NaN               NaN        NaN
# 3447586821               -3             -2.0              -1.0       blue
# 3426877449               -2              NaN              -1.0        NaN
# 3419144205               -2             -1.0               NaN        NaN
# ...                     ...              ...               ...        ...
# 3444742545               -3             -1.0              -1.0        red
# 3424164242                1              NaN               1.0       blue
# 3405814162               -1              1.0              -1.0        NaN
# 3419838867                3              1.0               1.0        NaN
# 3447495054               -2              NaN              -1.0        NaN
#
#            FIRE_DRAGONSoul  AIR_DRAGONdiff  ELDER_DRAGONdiff  \
# 3411673088             NaN             NaN               NaN
# 3435528193             NaN             NaN               NaN
# 3447586821             red            -1.0               1.0
# 3426877449             NaN             NaN               NaN
# 3419144205             NaN             NaN               NaN
# ...                    ...             ...               ...
# 3444742545             NaN            -1.0               NaN
# 3424164242             NaN             1.0               NaN
# 3405814162             NaN             NaN               NaN
# 3419838867             NaN             NaN               NaN
# 3447495054             NaN             NaN               NaN
#
#             WATER_DRAGONdiff EARTH_DRAGONSoul WATER_DRAGONSoul AIR_DRAGONSoul
# 3411673088               NaN              NaN              NaN            NaN
# 3435528193               NaN              NaN              NaN            NaN
# 3447586821               NaN              NaN              NaN            NaN
# 3426877449              -1.0              NaN              NaN            NaN
# 3419144205              -1.0              NaN              NaN            NaN
# ...                      ...              ...              ...            ...
# 3444742545               NaN              NaN              NaN            NaN
# 3424164242              -1.0              NaN              NaN            NaN
# 3405814162              -1.0              NaN              NaN            NaN
# 3419838867               1.0              NaN              NaN            NaN
# 3447495054              -1.0              NaN              NaN            NaN
#
# [20154 rows x 19 columns]

# %%
plt.barh(df_dropped.columns, df_dropped.count()/df_results.shape[0]*100)
plt.title('% of Games with values for various features')
plt.xlabel('Percentage(%)')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_dropped.count()/df_results.shape[0]*100
# Out:
# GameDuration           99.403206
# Winner                 99.403206
# firstTower             99.344020
# firstInhibitor         82.688039
# firstDragon            81.908755
# firstRiftHerald        65.045623
# baronKillsdiff         99.403206
# riftHeraldKillsdiff    99.403206
# dragonKillsdiff        99.403206
# FIRE_DRAGONdiff        56.182491
# EARTH_DRAGONdiff       56.478422
# firstBaron             49.864365
# FIRE_DRAGONSoul         4.779285
# AIR_DRAGONdiff         55.901356
# ELDER_DRAGONdiff        3.067818
# WATER_DRAGONdiff       56.769420
# EARTH_DRAGONSoul        5.040691
# WATER_DRAGONSoul        5.040691
# AIR_DRAGONSoul          4.739827
# dtype: float64

# %%
#summarize in df
tot_games = df.shape[0] #total num of games
num_games_by_time_df = pd.DataFrame(index=[str(str(x)+' min') for x in list_time_dicts.keys()], columns=['Games', 'Games with obj events'])
for time in list_time_dicts.keys():
    num_games_by_time_df['Games'][str(str(time)+' min')] = len(list_time_dicts[time])
    num_games_by_time_df['Games with obj events'][str(str(time)+' min')] = (p.count_dictvals_above_thres(list_time_dicts[time].values()))
    
    #make column of proportions
    num_games_by_time_df['% Games Remaining'] = num_games_by_time_df['Games']/tot_games*100

# %%
num_games_by_time_df['% of remaining games with obj events'] = num_games_by_time_df['Games with obj events']/num_games_by_time_df['Games']*100

# %%
num_games_by_time_df['% of remaining games without obj events'] = (1-(num_games_by_time_df['% of remaining games with obj events']/100))*100

# %% [markdown]
# #### Prevalence of objectives by 5 min intervals
#
# The objective event includes non-neutral objectives, and so any turrets, inhibitors, dragons, etc will count towards this score.
# No objectives are taken within the first 5 minutes, which is to be expected based on game design. The first neutral objective spawns at 5:00, and turrets might be damaged but are designed to be practically impossible to destroy during the first 5 minutes. By 15:00, however, the vast majority (>90%) of games will have had at least one objective event.

# %%
num_games_by_time_df
# Out:
#         Games Games with obj events % Games Remaining  \
# 5 min   20156                     0            100.78
# 10 min  20012                 11542            100.06
# 15 min  18641                 15571            93.205
# 20 min  14060                 12634              70.3
# 25 min   8722                  8340             43.61
# 30 min   4342                  4274             21.71
# 35 min   1474                  1465              7.37
# 40 min    370                   370              1.85
# 45 min     68                    68              0.34
# 50 min     10                    10              0.05
# 55 min      2                     2              0.01
#
#        % of remaining games with obj events  \
# 5 min                                     0
# 10 min                              57.6754
# 15 min                              83.5309
# 20 min                              89.8578
# 25 min                              95.6203
# 30 min                              98.4339
# 35 min                              99.3894
# 40 min                                  100
# 45 min                                  100
# 50 min                                  100
# 55 min                                  100
#
#        % of remaining games without obj events
# 5 min                                      100
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3442868254: {'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3421372448: {'AIR_DRAGONdiff': -1},
#   3441557537: {'FIRE_DRAGONdiff': 1},
#   3431858209: {'AIR_DRAGONdiff': -1},
#   3433168932: {},
#   3439329317: {'WATER_DRAGONdiff': -1},
#   3445358630: {},
#   3435135015: {'EARTH_DRAGONdiff': -1},
#   3446931493: {},
#   3408527402: {},
#   3442999340: {},
#   3411935277: {},
#   3438280750: {'FIRE_DRAGONdiff': -1},
#   3403677743: {'EARTH_DRAGONdiff': -1},
#   3446931503: {'FIRE_DRAGONdiff': -1},
#   3333816369: {},
#   3442429427: {'FIRE_DRAGONdiff': 1},
#   3433693240: {'WATER_DRAGONdiff': -1},
#   3437625401: {'FIRE_DRAGONdiff': -1},
#   3445882941: {},
#   3396337725: {},
#   3416391746: {},
#   3323854914: {'FIRE_DRAGONdiff': -1},
#   3426091077: {},
#   3398041670: {'FIRE_DRAGONdiff': 1},
#   3447586889: {},
#   3444572234: {},
#   3446276173: {},
#   3378643023: {},
#   3422814288: {'AIR_DRAGONdiff': 1},
#   3446145105: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3384934484: {'AIR_DRAGONdiff': 1},
#   3435790421: {'EARTH_DRAGONdiff': -1},
#   3435528278: {'WATER_DRAGONdiff': 1, 'EARTH_DRAGONdiff': -1},
#   3347578965: {},
#   3422552155: {'FIRE_DRAGONdiff': 1, 'AIR_DRAGONdiff': 1},
#   3405119580: {},
#   3448766565: {'AIR_DRAGONdiff': -1},
#   3431858280: {},
#   3412197481: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3439198314: {},
#   3441950828: {'AIR_DRAGONdiff': 1},
#   3444834413: {},
#   3443785838: {},
#   3440377967: {'WATER_DRAGONdiff': 1},
#   3384672365: {},
#   3440902257: {},
#   3425435758: {},
#   3432513651: {'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3436707956: {'EARTH_DRAGONdiff': -1},
#   3421503604: {'EARTH_DRAGONdiff': -1},
#   3445882990: {'AIR_DRAGONdiff': -1},
#   3418620024: {},
#   3386638457: {'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3421241469: {'AIR_DRAGONdiff': 1},
#   3437363330: {'EARTH_DRAGONdiff': -1},
#   3334602883: {},
#   3404071043: {'WATER_DRAGONdiff': -1},
#   3438018694: {},
#   3444703368: {'WATER_DRAGONdiff': -1},
#   3432120460: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3434741902: {},
#   3442999440: {'AIR_DRAGONdiff': -1},
#   3435135120: {'RIFTHERALDdiff': -1, 'BARON_NASHORdiff': 0},
#   3441951142: {'WATER_DRAGONdiff': 1},
#   3425305001: {'WATER_DRAGONdiff': 1},
#   3429237165: {'EARTH_DRAGONdiff': 1},
#   3394109870: {'AIR_DRAGONdiff': -1},
#   3441033648: {'WATER_DRAGONdiff': -1},
#   3430810032: {'EARTH_DRAGONdiff': 1},
#   3431727538: {},
#   3438018994: {'AIR_DRAGONdiff': 1},
#   3326345653: {'WATER_DRAGONdiff': -1},
#   3401318839: {'WATER_DRAGONdiff': 1},
#   3354788281: {'WATER_DRAGONdiff': 1},
#   3430810044: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3425698237: {'EARTH_DRAGONdiff': 1},
#   3436708286: {},
#   3434742206: {},
#   3431727552: {'FIRE_DRAGONdiff': -1},
#   3389784508: {},
#   3445883330: {'EARTH_DRAGONdiff': -1},
#   3387687365: {'WATER_DRAGONdiff': 1},
#   3378512326: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3351249353: {'AIR_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3322544586: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3444179404: {},
#   3429630413: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3433169356: {'AIR_DRAGONdiff': -1},
#   3417965004: {'FIRE_DRAGONdiff': -1},
#   3407610322: {'EARTH_DRAGONdiff': 1},
#   3428057554: {'WATER_DRAGONdiff': 1},
#   3434349014: {'AIR_DRAGONdiff': 1},
#   3322675672: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3419144664: {'FIRE_DRAGONdiff': -1},
#   3445359067: {},
#   3414819291: {},
#   3437363679: {},
#   3421372896: {},
#   3446014432: {},
#   3414032870: {},
#   3439329767: {},
#   3440378344: {},
#   3443786215: {},
#   3446145511: {'AIR_DRAGONdiff': -1},
#   3427795437: {},
#   3394765296: {},
#   3440771571: {'EARTH_DRAGONdiff': -1},
#   3440640501: {'WATER_DRAGONdiff': -1},
#   3445490166: {'RIFTHERALDdiff': -1, 'BARON_NASHORdiff': 0},
#   3432251895: {'AIR_DRAGONdiff': 1},
#   3408790007: {'WATER_DRAGONdiff': 1},
#   3385852405: {'FIRE_DRAGONdiff': -1},
#   3372089850: {},
#   3400925694: {},
#   3426091521: {'AIR_DRAGONdiff': 1},
#   3443917321: {'EARTH_DRAGONdiff': 1},
#   3428450825: {'FIRE_DRAGONdiff': -1},
#   3417178636: {},
#   3415212557: {},
#   3443917327: {},
#   3440771599: {'WATER_DRAGONdiff': 1, 'EARTH_DRAGONdiff': 1},
#   3433562641: {'WATER_DRAGONdiff': 1},
#   3405382164: {},
#   3438674453: {'AIR_DRAGONdiff': 1},
#   3438150168: {},
#   3357540889: {'EARTH_DRAGONdiff': 1},
#   3433300506: {},
#   3448767003: {'WATER_DRAGONdiff': 1},
#   3396207133: {'FIRE_DRAGONdiff': 1},
#   3410100768: {'WATER_DRAGONdiff': 1},
#   3446407718: {},
#   3322937896: {},
#   3429892651: {},
#   3334079021: {},
#   3446145582: {'WATER_DRAGONdiff': 1},
#   3414032944: {'AIR_DRAGONdiff': -1},
#   3448635965: {},
#   3447194175: {},
#   3421635139: {'AIR_DRAGONdiff': -1},
#   3431858757: {},
#   3447325253: {'FIRE_DRAGONdiff': 1},
#   3432383045: {},
#   3430548040: {'AIR_DRAGONdiff': -1},
#   3429630537: {'AIR_DRAGONdiff': -1},
#   3317826120: {},
#   3424649807: {},
#   3446014544: {'EARTH_DRAGONdiff': 1},
#   3434742352: {},
#   3437625939: {'EARTH_DRAGONdiff': 1},
#   3402236500: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3426484822: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3445752406: {'EARTH_DRAGONdiff': -1, 'AIR_DRAGONdiff': -1},
#   3429106264: {'FIRE_DRAGONdiff': -1},
#   3424256600: {'AIR_DRAGONdiff': -1},
#   3369468506: {},
#   3420193371: {},
#   3359244892: {},
#   3405120092: {'AIR_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3446800990: {'WATER_DRAGONdiff': -1},
#   3326476893: {},
#   3443786341: {},
#   3409838694: {'AIR_DRAGONdiff': 1},
#   3396338279: {},
#   3437232742: {'AIR_DRAGONdiff': 1},
#   3412197992: {},
#   3440116330: {'FIRE_DRAGONdiff': 1},
#   3419538025: {'WATER_DRAGONdiff': 1},
#   3420062316: {'AIR_DRAGONdiff': 1},
#   3363045997: {},
#   3422028394: {},
#   3442868847: {'WATER_DRAGONdiff': -1},
#   3408921199: {},
#   3418882673: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3436315253: {'WATER_DRAGONdiff': -1},
#   3439329910: {},
#   3438019189: {},
#   3444834936: {'WATER_DRAGONdiff': -1},
#   3351511674: {'FIRE_DRAGONdiff': 1},
#   3389129339: {},
#   3440378494: {'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3431727742: {},
#   3440378495: {},
#   3419538049: {},
#   3424387714: {},
#   3443131010: {},
#   3426091654: {},
#   3394765450: {},
#   3438936715: {},
#   3414688396: {'FIRE_DRAGONdiff': 1},
#   3379692172: {},
#   3349807758: {'WATER_DRAGONdiff': 1},
#   3444310672: {'AIR_DRAGONdiff': -1},
#   3444441753: {},
#   3355050650: {'FIRE_DRAGONdiff': -1},
#   3436708507: {},
#   3435528864: {'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3428450977: {},
#   3444703904: {'WATER_DRAGONdiff': -1},
#   3440771912: {},
#   3442344778: {'FIRE_DRAGONdiff': -1},
#   3431203659: {},
#   3448374095: {'WATER_DRAGONdiff': -1},
#   3435922257: {'FIRE_DRAGONdiff': 1},
#   3425174357: {},
#   3437495127: {},
#   3429237592: {'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3440903005: {},
#   3429892957: {'FIRE_DRAGONdiff': -1},
#   3443655519: {'EARTH_DRAGONdiff': -1},
#   3418620768: {'WATER_DRAGONdiff': 1},
#   3448374114: {'AIR_DRAGONdiff': 1},
#   3443655528: {'WATER_DRAGONdiff': -1},
#   3416392553: {'EARTH_DRAGONdiff': 1},
#   3412722536: {'AIR_DRAGONdiff': 1},
#   3370910568: {},
#   3410494313: {'EARTH_DRAGONdiff': -1},
#   3438936941: {'FIRE_DRAGONdiff': 1},
#   3426485104: {'AIR_DRAGONdiff': -1},
#   3444048753: {'EARTH_DRAGONdiff': 1},
#   3359376243: {},
#   3421897591: {},
#   3396862840: {},
#   3335783290: {'AIR_DRAGONdiff': -1},
#   3448767360: {},
#   3443917697: {'EARTH_DRAGONdiff': 1},
#   3421373313: {'AIR_DRAGONdiff': 1, 'EARTH_DRAGONdiff': -1},
#   3446539138: {},
#   3442738050: {'FIRE_DRAGONdiff': 1},
#   3392406409: {'EARTH_DRAGONdiff': 1},
#   3405906830: {'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3421504402: {'AIR_DRAGONdiff': -1},
#   3439330196: {},
#   3431465877: {'WATER_DRAGONdiff': 1},
#   3442213781: {},
#   3443131286: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3440771991: {'FIRE_DRAGONdiff': -1},
#   3343123353: {'FIRE_DRAGONdiff': -1},
#   3435004826: {},
#   3443393436: {},
#   3391095709: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3434480545: {},
#   3409576866: {'FIRE_DRAGONdiff': -1},
#   3407610787: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3444704166: {'WATER_DRAGONdiff': -1},
#   3425698726: {},
#   3446539179: {},
#   3398960046: {'EARTH_DRAGONdiff': 1},
#   3445228466: {'WATER_DRAGONdiff': -1},
#   3351905203: {},
#   3417179063: {'FIRE_DRAGONdiff': -1},
#   3419669431: {},
#   3429630909: {'AIR_DRAGONdiff': 1},
#   3404727230: {'AIR_DRAGONdiff': -1},
#   3436053439: {},
#   3439199167: {},
#   3413902273: {},
#   3443917762: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3431596996: {'FIRE_DRAGONdiff': 1},
#   3377595336: {},
#   3436315595: {'AIR_DRAGONdiff': -1},
#   3421766606: {},
#   3418096593: {},
#   3448636375: {},
#   3443393498: {'FIRE_DRAGONdiff': -1},
#   3406824525: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3418883150: {'WATER_DRAGONdiff': 1},
#   3406169167: {'AIR_DRAGONdiff': -1},
#   3440510029: {'EARTH_DRAGONdiff': 1},
#   3415213138: {},
#   3440116818: {'EARTH_DRAGONdiff': -1},
#   3445228629: {},
#   3415213142: {},
#   3409577047: {},
#   3328967766: {'WATER_DRAGONdiff': 1},
#   3405907033: {},
#   3356886115: {},
#   3355051109: {'WATER_DRAGONdiff': 1},
#   3374711909: {'AIR_DRAGONdiff': 1},
#   3448636521: {'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3351118956: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3391489133: {'EARTH_DRAGONdiff': 1},
#   3430679663: {'FIRE_DRAGONdiff': -1},
#   3420062833: {},
#   3419669618: {},
#   3412984953: {'EARTH_DRAGONdiff': -1},
#   3427796093: {'WATER_DRAGONdiff': 1, 'EARTH_DRAGONdiff': -1},
#   3431990398: {'EARTH_DRAGONdiff': 1},
#   3435922559: {'FIRE_DRAGONdiff': 1},
#   3445752959: {'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3415868546: {},
#   3443655810: {},
#   3410494596: {'FIRE_DRAGONdiff': -1},
#   3438281862: {},
#   3448505480: {},
#   3409708169: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3419407497: {},
#   3424257163: {'FIRE_DRAGONdiff': 1},
#   3440247948: {'AIR_DRAGONdiff': -1},
#   3425174667: {'FIRE_DRAGONdiff': 1},
#   3402105995: {'EARTH_DRAGONdiff': -1},
#   3412984974: {},
#   3381134480: {},
#   3423601808: {'FIRE_DRAGONdiff': -1},
#   3422553233: {},
#   3400795283: {'EARTH_DRAGONdiff': 1},
#   3446932627: {'AIR_DRAGONdiff': -1},
#   3438544021: {'FIRE_DRAGONdiff': -1},
#   3435791510: {'AIR_DRAGONdiff': -1},
#   3436709010: {'WATER_DRAGONdiff': 1},
#   3418752152: {},
#   3442345115: {'EARTH_DRAGONdiff': -1},
#   3429893276: {},
#   3427140765: {},
#   3433301150: {},
#   3421504672: {},
#   3427271840: {'AIR_DRAGONdiff': 1},
#   3427271842: {'AIR_DRAGONdiff': -1},
#   3421635750: {},
#   3421373607: {'AIR_DRAGONdiff': -1},
#   3409970345: {'WATER_DRAGONdiff': 1},
#   3369600174: {},
#   3401974958: {'EARTH_DRAGONdiff': -1},
#   3392537777: {'FIRE_DRAGONdiff': -1},
#   3436577972: {'FIRE_DRAGONdiff': 1},
#   3442607284: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3331196087: {'WATER_DRAGONdiff': 1},
#   3443393720: {'AIR_DRAGONdiff': -1},
#   3437626553: {'EARTH_DRAGONdiff': -1},
#   3397387452: {'AIR_DRAGONdiff': 1},
#   3445884096: {},
#   3401057477: {},
#   3400795338: {'AIR_DRAGONdiff': -1},
#   3435005133: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3399615695: {'WATER_DRAGONdiff': -1},
#   3395421394: {'WATER_DRAGONdiff': -1},
#   3407348947: {'EARTH_DRAGONdiff': -1},
#   3422815444: {},
#   3426878677: {'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3440510168: {},
#   3357279449: {},
#   3397780698: {},
#   3345614043: {'FIRE_DRAGONdiff': 1},
#   3447063770: {'FIRE_DRAGONdiff': 1},
#   3431859423: {'EARTH_DRAGONdiff': -1},
#   3438150880: {'EARTH_DRAGONdiff': 1},
#   3427140832: {'WATER_DRAGONdiff': -1},
#   3428844775: {},
#   3442345192: {},
#   3434611943: {},
#   3436709096: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3429893352: {},
#   3440248045: {},
#   3385984238: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3447981295: {'WATER_DRAGONdiff': -1},
#   3438281966: {'AIR_DRAGONdiff': -1},
#   3427009780: {'AIR_DRAGONdiff': -1},
#   3351512309: {'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3409970422: {'AIR_DRAGONdiff': 1},
#   3316122872: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3444049145: {'AIR_DRAGONdiff': 1},
#   3388212474: {'EARTH_DRAGONdiff': -1},
#   3374056707: {},
#   3426485507: {'AIR_DRAGONdiff': 1},
#   2842166533: {},
#   3440641284: {'FIRE_DRAGONdiff': 1},
#   3435791625: {'FIRE_DRAGONdiff': -1},
#   3432252683: {},
#   3437626638: {'WATER_DRAGONdiff': 1},
#   3433694481: {'AIR_DRAGONdiff': 1},
#   3405382930: {},
#   3393848596: {'WATER_DRAGONdiff': -1},
#   3400926485: {'AIR_DRAGONdiff': 1},
#   3406300438: {'EARTH_DRAGONdiff': 1},
#   3422815511: {'EARTH_DRAGONdiff': 1},
#   3426223388: {'EARTH_DRAGONdiff': 1},
#   3445490973: {},
#   3339978014: {},
#   3436840227: {},
#   3412854051: {},
#   3336963366: {'AIR_DRAGONdiff': -1},
#   3434874152: {'AIR_DRAGONdiff': -1},
#   3445097768: {'AIR_DRAGONdiff': -1},
#   3446408492: {'FIRE_DRAGONdiff': 1},
#   3399484717: {},
#   3448767794: {'EARTH_DRAGONdiff': 1},
#   3431335218: {'AIR_DRAGONdiff': -1},
#   3445884212: {},
#   3421111605: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3418883382: {'EARTH_DRAGONdiff': 1},
#   3376809271: {'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3441558841: {'EARTH_DRAGONdiff': 1},
#   3439985981: {'AIR_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3433694526: {'EARTH_DRAGONdiff': 1},
#   3440117054: {},
#   3431990591: {},
#   3443000637: {},
#   3433563461: {'AIR_DRAGONdiff': 1},
#   3435529543: {'AIR_DRAGONdiff': 1},
#   3447326023: {},
#   3436578119: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3445884235: {},
#   3344041291: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3430417741: {},
#   3393848657: {'FIRE_DRAGONdiff': -1},
#   3415082326: {},
#   3433301336: {},
#   3416393052: {'EARTH_DRAGONdiff': -1},
#   3442738525: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3426354526: {'AIR_DRAGONdiff': -1},
#   3441165663: {'AIR_DRAGONdiff': 1},
#   3422684512: {'AIR_DRAGONdiff': -1},
#   3434612065: {},
#   3423602018: {'WATER_DRAGONdiff': 1},
#   3419276638: {},
#   3393979748: {'FIRE_DRAGONdiff': 1},
#   3447457126: {'WATER_DRAGONdiff': 1},
#   3382969705: {'WATER_DRAGONdiff': -1},
#   3445097833: {},
#   3403285868: {'FIRE_DRAGONdiff': -1},
#   3422029166: {},
#   3420849520: {'FIRE_DRAGONdiff': -1},
#   3377857904: {'AIR_DRAGONdiff': -1},
#   3448374645: {},
#   3431335288: {},
#   3437626747: {'EARTH_DRAGONdiff': 1},
#   3442345341: {},
#   3421898112: {'AIR_DRAGONdiff': -1},
#   3431990660: {'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3368289669: {'RIFTHERALDdiff': 1, 'BARON_NASHORdiff': 0},
#   3417179527: {'EARTH_DRAGONdiff': 1},
#   3442345352: {},
#   3443656072: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3447850377: {},
#   3439986066: {},
#   3425437075: {'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3402499476: {},
#   3377989013: {'AIR_DRAGONdiff': 1},
#   3406038423: {'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3441952153: {'EARTH_DRAGONdiff': -1},
#   3378382233: {'WATER_DRAGONdiff': 1},
#   3260024219: {},
#   3437233565: {'AIR_DRAGONdiff': 1},
#   3441034656: {},
#   3424519584: {'EARTH_DRAGONdiff': -1},
#   3329099169: {},
#   3428713890: {'FIRE_DRAGONdiff': 1},
#   3438675367: {},
#   3432252842: {'EARTH_DRAGONdiff': 1},
#   3445228970: {'AIR_DRAGONdiff': -1},
#   3385984428: {},
#   3396994622: {'WATER_DRAGONdiff': 1},
#   3424126530: {},
#   3448768066: {'AIR_DRAGONdiff': 1},
#   3443131972: {'EARTH_DRAGONdiff': -1},
#   3436840517: {'WATER_DRAGONdiff': -1},
#   3411150407: {'FIRE_DRAGONdiff': 1},
#   3437364807: {'WATER_DRAGONdiff': 1},
#   3386902089: {'AIR_DRAGONdiff': -1},
#   3442476618: {'WATER_DRAGONdiff': -1},
#   3398960720: {'EARTH_DRAGONdiff': 1},
#   3388737109: {},
#   3415344726: {'WATER_DRAGONdiff': 1},
#   3442214487: {},
#   3419145816: {'WATER_DRAGONdiff': -1},
#   3400926806: {'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3395421785: {'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3419539036: {'AIR_DRAGONdiff': 1},
#   3410232925: {'AIR_DRAGONdiff': 1},
#   3440772700: {},
#   3415344744: {},
#   3385329257: {},
#   3432121962: {'FIRE_DRAGONdiff': 1},
#   3422422632: {'RIFTHERALDdiff': -1, 'BARON_NASHORdiff': 0},
#   3431073387: {'FIRE_DRAGONdiff': -1},
#   3436578410: {},
#   3443132008: {},
#   3431990898: {'WATER_DRAGONdiff': 1},
#   3342599795: {'FIRE_DRAGONdiff': 1},
#   3426485874: {'WATER_DRAGONdiff': 1},
#   3438151285: {},
#   3439986295: {},
#   3433039480: {},
#   3436054140: {'WATER_DRAGONdiff': -1},
#   3439330940: {},
#   3430942334: {'EARTH_DRAGONdiff': 1},
#   3435660927: {'WATER_DRAGONdiff': -1},
#   3438020223: {'WATER_DRAGONdiff': 1},
#   3410888319: {'AIR_DRAGONdiff': 1},
#   3435529854: {},
#   3326477951: {},
#   3434612356: {},
#   3436840584: {'EARTH_DRAGONdiff': -1},
#   3436578441: {'WATER_DRAGONdiff': -1},
#   3446802058: {},
#   3416393358: {},
#   3361080977: {},
#   3440641682: {},
#   3395552919: {},
#   3435136663: {'FIRE_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3446933145: {},
#   3330016922: {'AIR_DRAGONdiff': 1},
#   3339978395: {},
# ...
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': -2},
#   3415906247: {'FIRE_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 2},
#   3433994192: {'FIRE_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -3,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 1},
#   3314980923: {'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -2,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3438844086: {'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 1},
#   3420231888: {'AIR_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': -2},
#   3378813180: {'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3433077044: {'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 0}},
#  45: {3355051109: {'EARTH_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 1},
#   3440248045: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 4,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 2},
#   3410627769: {'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3425308071: {'EARTH_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 0,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 2},
#   3419279859: {'AIR_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 0},
#   3439334154: {'EARTH_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 2},
#   3389396513: {'WATER_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -2},
#   3411940904: {'WATER_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 3,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -2},
#   3433175124: {'WATER_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -2},
#   3411024326: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': -2},
#   3444578857: {'WATER_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -2},
#   3444055282: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 0},
#   3350733004: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3433046335: {'FIRE_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 1},
#   3401851344: {'FIRE_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': -3},
#   3439207129: {'EARTH_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 0,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 2},
#   3442091373: {'WATER_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 0},
#   3341166557: {'FIRE_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -3,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3300403190: {'AIR_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 1},
#   3429115959: {'AIR_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 1},
#   3396086323: {'AIR_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 3,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 2},
#   3343658127: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -3,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3418238798: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 1},
#   3415224222: {'FIRE_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -2},
#   3424792941: {'EARTH_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': -1},
#   3393074119: {'EARTH_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': -1},
#   3443012753: {'FIRE_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 0,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 1},
#   3440784567: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3405788992: {'AIR_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 3,
#    'ELDER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 1},
#   3412081329: {'FIRE_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 1},
#   3438689290: {'AIR_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3443670344: {'WATER_DRAGONSoulteam': 'red',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -2},
#   3385212634: {'WATER_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': -2},
#   3443539770: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': -2},
#   3421651480: {'AIR_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -4,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 0},
#   3442754190: {'AIR_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3440526162: {'AIR_DRAGONSoulteam': 'red',
#    'EARTH_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -3,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3431746629: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 2,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 1},
#   3396882161: {'AIR_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 3,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 2},
#   3440136995: {'WATER_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 3},
#   3388363558: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 3,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 2},
#   3371455319: {'WATER_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 2},
#   3419429532: {'EARTH_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 1},
#   3392691410: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 1},
#   3414451484: {'FIRE_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 2},
#   3438831361: {'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3425463224: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -3,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 0},
#   3425070011: {'WATER_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': -1},
#   3419040967: {'EARTH_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 0},
#   3419173173: {'AIR_DRAGONSoulteam': 'red',
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 3},
#   3433853353: {'WATER_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': -1},
#   3427170397: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3416291566: {'WATER_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': -2},
#   3411574242: {'WATER_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 0,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 0},
#   3346431955: {'EARTH_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': -1,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3440935032: {'AIR_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 3,
#    'ELDER_DRAGONdiff': -2,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': -1},
#   3444736786: {'AIR_DRAGONSoulteam': 'red',
#    'EARTH_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 0},
#   3364129356: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -1},
#   3354956215: {'AIR_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -3,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3425342144: {'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3394147202: {'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -2,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': -1},
#   3430061057: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 4,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -2},
#   3434779731: {'FIRE_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': -3},
#   3435566739: {'WATER_DRAGONSoulteam': 'red',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 0,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3433994192: {'FIRE_DRAGONSoulteam': 'red',
#    'WATER_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -3,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3438844086: {'WATER_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 2},
#   3378813180: {'AIR_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': 2,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 0},
#   3433077044: {'EARTH_DRAGONSoulteam': 'red',
#    'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 0}},
#  50: {3440248045: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 4,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 3},
#   3396086323: {'AIR_DRAGONSoulteam': 'blue',
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 3,
#    'ELDER_DRAGONdiff': -1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': 1},
#   3431746629: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': 1},
#   3440136995: {'WATER_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'AIR_DRAGONdiff': -1,
#    'WATER_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 2,
#    'BARON_NASHORdiff': 3},
#   3419429532: {'EARTH_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 1},
#   3392691410: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'EARTH_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': -2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': 0},
#   3425463224: {'FIRE_DRAGONSoulteam': 'red',
#    'AIR_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -3,
#    'RIFTHERALDdiff': -2,
#    'BARON_NASHORdiff': -1},
#   3427170397: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -1},
#   3364129356: {'EARTH_DRAGONSoulteam': 'blue',
#    'FIRE_DRAGONdiff': 1,
#    'WATER_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': 1,
#    'BARON_NASHORdiff': -2},
#   3430061057: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 4,
#    'ELDER_DRAGONdiff': 1,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -3}},
#  55: {3419429532: {'EARTH_DRAGONSoulteam': 'blue',
#    'AIR_DRAGONdiff': 1,
#    'FIRE_DRAGONdiff': -1,
#    'EARTH_DRAGONdiff': 2,
#    'ELDER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': 0,
#    'BARON_NASHORdiff': 2},
#   3430061057: {'FIRE_DRAGONSoulteam': 'blue',
#    'EARTH_DRAGONdiff': -1,
#    'AIR_DRAGONdiff': -1,
#    'FIRE_DRAGONdiff': 4,
#    'ELDER_DRAGONdiff': 0,
#    'RIFTHERALDdiff': -1,
#    'BARON_NASHORdiff': -4}}}

# %%
list_time_dicts.keys()
# Out:
# dict_keys([5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55])

# %%
#summarize in df
tot_games = df.shape[0] #total num of games
num_games_by_time_df = pd.DataFrame(index=[str(str(x)+' min') for x in list_time_dicts.keys()], columns=['Games', 'Games with obj events'])
for time in list_time_dicts.keys():
    num_games_by_time_df['Games'][str(str(time)+' min')] = len(list_time_dicts[time])
    num_games_by_time_df['Games with obj events'][str(str(time)+' min')] = p.count_dictvals_above_thres(list_time_dicts[time].values())
    
    #make column of proportions
    num_games_by_time_df['% Games Remaining'] = num_games_by_time_df['Games']/tot_games*100

# %%
num_games_by_time_df
# Out:
#         Games Games with obj events % Games Remaining
# 5 min   20156                     0            100.78
# 10 min  20012                 11542            100.06
# 15 min  18641                 15571            93.205
# 20 min  14060                 12634              70.3
# 25 min   8722                  8340             43.61
# 30 min   4342                  4274             21.71
# 35 min   1474                  1465              7.37
# 40 min    370                   370              1.85
# 45 min     68                    68              0.34
# 50 min     10                    10              0.05
# 55 min      2                     2              0.01

# %% [markdown]
# Since there are only 370 games remaining at the time interval of 40, 35 minutes will be the maximum time interval used for modeling. Minute 5 has also been removed since no neutral objectives are available to take at that time. This is reflected in the table as there are no games with any objective events prior to 5 minutes.
#
# Note: the length of a game increases as elo decreases, so more time intervals will likely have to be examined if analysis were to expanded to lower elos.

# %% [markdown]
# ## Win Distribution
#
# The outcome data feature is a binary feature that currently holds 'red' and 'blue' string values corresponding to the teams. Of the 20,154 games, red won 51.2% and blue won 48.8% of the games.

# %%
df_dropped.Winner.value_counts().values
# Out:
# array([10312,  9842], dtype=int64)

# %%
plt.bar(df_dropped.Winner.value_counts().index, 
        df_dropped.Winner.value_counts().values, 
        color=['red', 'blue'])
plt.xlabel('Winning Team')
plt.ylabel("Number of matches")
plt.title('Barplot of red team vs blue team wins')
plt.show()

# %%
s_win_ratio = df_dropped.Winner.value_counts()
s_win_perc = s_win_ratio/s_win_ratio.sum()*100
s_win_perc
# Out:
# red     51.166022
# blue    48.833978
# Name: Winner, dtype: float64

# %%
plt.bar(s_win_perc.index, 
        s_win_perc.values, 
        color=['red', 'blue'])
plt.xlabel('Winning Team')
plt.ylabel("Number of matches")
plt.title('Barplot of % red team vs blue team wins')
plt.show()

# %%
df_dropped.shape[0] == s_win_ratio.sum()
# Out:
# True

# %%
s_win_ratio.sum()
# Out:
# 20154

# %%
df_times_list = [10, 15, 20, 25, 30, 35]

# %%
df_by_time_dict = {}

# %%
#build a dataframe for the gamestate of remaining games at 5 minute intervals from 10-35min
#store the dataframes within a dict
for time in df_times_list:
    if len(list_time_dicts[time]) > 1000: #arbitary cutoff number of 1000 games was chosen
        gamestate_by_time_dict[time] = pd.DataFrame(list_time_dicts[time]).transpose()

# %%
#build a dataframe for the gamestate of remaining games at 5 minute intervals from 10-35min
#store the dataframes within a dict
for time in df_times_list:
    if len(list_time_dicts[time]) > 1000: #arbitary cutoff number of 1000 games was chosen
        gamestate_by_time_dict[time] = pd.DataFrame(list_time_dicts[time]).transpose()

# %%
var_diff = ['baronKillsdiff','riftHeraldKillsdiff', 
                   'dragonKillsdiff', 'FIRE_DRAGONdiff', 'EARTH_DRAGONdiff', 
                   'AIR_DRAGONdiff', 'ELDER_DRAGONdiff', 'WATER_DRAGONdiff']
var_team = ['firstTower', 'firstInhibitor',
       'firstDragon', 'firstRiftHerald', 'firstBaron', 'FIRE_DRAGONSoul', 
              'EARTH_DRAGONSoul', 'WATER_DRAGONSoul', 'AIR_DRAGONSoul']
var_firsts = ['firstTower', 'firstInhibitor',
       'firstDragon', 'firstRiftHerald', 'firstBaron']
var_dragtypediff = ['FIRE_DRAGONdiff', 'EARTH_DRAGONdiff', 
                   'AIR_DRAGONdiff', 'ELDER_DRAGONdiff', 'WATER_DRAGONdiff']
var_soul = ['FIRE_DRAGONSoul', 
              'EARTH_DRAGONSoul', 'WATER_DRAGONSoul', 'AIR_DRAGONSoul']

# %%
pd.plotting.scatter_matrix(df_clean[var_diff].astype(float), figsize = [15, 15]);

# %% [markdown]
# Unsurprisingly, there's a lot of multicollinearity between the variables which means that estimators that assume feature independence wouldn't work well. One obvious relationship is dragon kills difference compared with water dragon kills difference - it follows that killing more water dragons will correlate with more dragon kills as well.

# %%
gamestate_by_time_dict.keys()
# Out:
# dict_keys([10, 15, 20, 25, 30, 35, 5])

# %%
for col in gamestate_by_time_dict[25]:
    print(gamestate_by_time_dict[25][col].unique())
# Out:
# [nan 'red' 'blue']
# [nan -1 1 0.0 -2 2.0 3 -3.0]
# [nan -1 2 1.0 0.0 -2.0 -3 -4 3]
# [nan -2 1 -1.0 2.0 0.0 3 -3 4]
# [nan 'blue' 'red']
# [nan -1 1.0 -2 2.0 0.0]
# [nan 0 -1.0 1.0 -2.0 2]
# [nan -1.0 1.0 2 -2.0 0.0 3 4 -3 -4]
# [nan 'blue' 'red']
# [nan 'red' 'blue']
# [nan 1 -1]

# %% [markdown]
# ## Encoding and imputing

# %% [markdown]
# #### Encoding team values to integers
# The numerical integer features indicate differences in objectives between the two teams, with positive numbers indicating a surplus difference for the blue side, and negative integers representing the red side. A value of 0 means that neither team has an advantage in that specific feature over the other team, whether each team has 2 barons or if they each have 0 barons.
# The dataframe of post-game stats and all of the time series dataframes needs to be numerically encoded for machine learning.
#
# The "blue" and "red" strings are used to either indicate match winner or a team that received dragon soul. They are converted to integers 1 and -1, respectively. These integer values and range are selected to match with other objective features. All other values in the soul features are to be encoded to 0, to indicate that a team does not have that dragon soul.

# %%
#encoding the post-game df
df_enc = df_dropped.replace({'blue':1, 'red':-1})

# %%
df_enc
# Out:
#             GameDuration  Winner  firstTower  firstInhibitor  firstDragon  \
# 3411673088          1195      -1        -1.0            -1.0         -1.0
# 3435528193          1516       1         1.0            -1.0          NaN
# 3447586821          1964       1        -1.0            -1.0         -1.0
# 3426877449           915      -1        -1.0             NaN         -1.0
# 3419144205          1176      -1        -1.0            -1.0         -1.0
# ...                  ...     ...         ...             ...          ...
# 3444742545          1326      -1        -1.0            -1.0         -1.0
# 3424164242          1915       1         1.0             1.0          1.0
# 3405814162          1208      -1        -1.0            -1.0          1.0
# 3419838867          1305       1         1.0             1.0          1.0
# 3447495054          1658      -1        -1.0            -1.0         -1.0
#
#             firstRiftHerald  baronKillsdiff  riftHeraldKillsdiff  \
# 3411673088              1.0               0                    1
# 3435528193              NaN               0                    0
# 3447586821              NaN               1                    0
# 3426877449             -1.0               0                   -1
# 3419144205              1.0               0                    0
# ...                     ...             ...                  ...
# 3444742545             -1.0              -1                   -1
# 3424164242              1.0               1                    1
# 3405814162              1.0               0                    0
# 3419838867              1.0               0                    2
# 3447495054              1.0               0                    2
#
#             dragonKillsdiff  FIRE_DRAGONdiff  EARTH_DRAGONdiff  firstBaron  \
# 3411673088               -2             -1.0              -1.0         NaN
# 3435528193                0              NaN               NaN         NaN
# 3447586821               -3             -2.0              -1.0         1.0
# 3426877449               -2              NaN              -1.0         NaN
# 3419144205               -2             -1.0               NaN         NaN
# ...                     ...              ...               ...         ...
# 3444742545               -3             -1.0              -1.0        -1.0
# 3424164242                1              NaN               1.0         1.0
# 3405814162               -1              1.0              -1.0         NaN
# 3419838867                3              1.0               1.0         NaN
# 3447495054               -2              NaN              -1.0         NaN
#
#             FIRE_DRAGONSoul  AIR_DRAGONdiff  ELDER_DRAGONdiff  \
# 3411673088              NaN             NaN               NaN
# 3435528193              NaN             NaN               NaN
# 3447586821             -1.0            -1.0               1.0
# 3426877449              NaN             NaN               NaN
# 3419144205              NaN             NaN               NaN
# ...                     ...             ...               ...
# 3444742545              NaN            -1.0               NaN
# 3424164242              NaN             1.0               NaN
# 3405814162              NaN             NaN               NaN
# 3419838867              NaN             NaN               NaN
# 3447495054              NaN             NaN               NaN
#
#             WATER_DRAGONdiff  EARTH_DRAGONSoul  WATER_DRAGONSoul  \
# 3411673088               NaN               NaN               NaN
# 3435528193               NaN               NaN               NaN
# 3447586821               NaN               NaN               NaN
# 3426877449              -1.0               NaN               NaN
# 3419144205              -1.0               NaN               NaN
# ...                      ...               ...               ...
# 3444742545               NaN               NaN               NaN
# 3424164242              -1.0               NaN               NaN
# 3405814162              -1.0               NaN               NaN
# 3419838867               1.0               NaN               NaN
# 3447495054              -1.0               NaN               NaN
#
#             AIR_DRAGONSoul
# 3411673088             NaN
# 3435528193             NaN
# 3447586821             NaN
# 3426877449             NaN
# 3419144205             NaN
# ...                    ...
# 3444742545             NaN
# 3424164242             NaN
# 3405814162             NaN
# 3419838867             NaN
# 3447495054             NaN
#
# [20154 rows x 19 columns]

# %%
for col in gamestate_by_time_dict[10]:
    print(gamestate_by_time_dict[10][col].unique())
# Out:
# [nan -1.  1.]
# [nan -1.  1.]
# [nan -1.  1.]
# [nan  0.]
# [nan -1.  1.]
# [nan -1.  1.]

# %%
gamestate_by_time_dict[10].columns
# Out:
# Index(['AIR_DRAGONdiff', 'WATER_DRAGONdiff', 'RIFTHERALDdiff',
#        'BARON_NASHORdiff', 'FIRE_DRAGONdiff', 'EARTH_DRAGONdiff'],
#       dtype='object')

# %%
gamestate_by_time_dict[10].iloc[:,0]
# Out:
# 3411673088    NaN
# 3435528193    NaN
# 3447586821   -1.0
# 3426877449    NaN
# 3419144205    NaN
#              ...
# 3444742545    NaN
# 3424164242    NaN
# 3405814162    NaN
# 3419838867    NaN
# 3447495054    NaN
# Name: AIR_DRAGONdiff, Length: 20012, dtype: float64

# %%
#convert blue and red team to boolean ints

enc_gamestate_by_time_dict = {}

for time in gamestate_by_time_dict.keys():
    if gamestate_by_time_dict[time].dtypes.any() == 'object':
        enc_gamestate_by_time_dict[time] = gamestate_by_time_dict[time].replace({'blue': 1, 'red': -1})
    else:
        enc_gamestate_by_time_dict[time] = gamestate_by_time_dict[time]

# %%
enc_gamestate_by_time_dict.keys()
# Out:
# dict_keys([10, 15, 20, 25, 30, 35, 5])

# %%
for col in enc_gamestate_by_time_dict[25]:
    print(enc_gamestate_by_time_dict[25][col].unique())
# Out:
# [nan -1.  1.]
# [nan -1.  1.  0. -2.  2.  3. -3.]
# [nan -1.  2.  1.  0. -2. -3. -4.  3.]
# [nan -2.  1. -1.  2.  0.  3. -3.  4.]
# [nan  1. -1.]
# [nan -1.  1. -2.  2.  0.]
# [nan  0. -1.  1. -2.  2.]
# [nan -1.  1.  2. -2.  0.  3.  4. -3. -4.]
# [nan  1. -1.]
# [nan -1.  1.]
# [nan  1. -1.]

# %% [markdown]
# #### Imputing with means
# For this dataset, the NaN values aren't true missing values; they're placeholders for 0. The game data only records when a team captures an objective, otherwise the absence of a value means that a team has not captured that objective. However, imputing the mean seems most prudent in order to distinguish between 0 values resulting from the sum of non-zero values and 0 values where both teams have not obtained the objective.

# %%
#if I wanted to fill with 0:
#df_enc.fillna(0)

df_filled = df_enc.fillna(df_enc.mean())

# %%
filled_gamestate_by_time_dict = {}
#convert blue and red team to boolean ints
for time in enc_gamestate_by_time_dict.keys():
    filled_gamestate_by_time_dict[time] = enc_gamestate_by_time_dict[time].fillna(enc_gamestate_by_time_dict[time].mean())

# %%
filled_gamestate_by_time_dict[10]
# Out:
#             AIR_DRAGONdiff  WATER_DRAGONdiff  RIFTHERALDdiff  \
# 3411673088       -0.078523         -0.037923        0.080762
# 3435528193       -0.078523         -0.037923        0.080762
# 3447586821       -1.000000         -0.037923        0.080762
# 3426877449       -0.078523         -1.000000       -1.000000
# 3419144205       -0.078523         -0.037923        0.080762
# ...                    ...               ...             ...
# 3444742545       -0.078523         -0.037923        0.080762
# 3424164242       -0.078523         -0.037923        0.080762
# 3405814162       -0.078523         -0.037923        0.080762
# 3419838867       -0.078523         -0.037923        0.080762
# 3447495054       -0.078523         -0.037923        1.000000
#
#             BARON_NASHORdiff  FIRE_DRAGONdiff  EARTH_DRAGONdiff
# 3411673088               0.0        -0.047194         -0.022106
# 3435528193               0.0        -0.047194         -0.022106
# 3447586821               0.0        -0.047194         -0.022106
# 3426877449               0.0        -0.047194         -0.022106
# 3419144205               0.0        -1.000000         -0.022106
# ...                      ...              ...               ...
# 3444742545               0.0        -1.000000         -0.022106
# 3424164242               0.0        -0.047194          1.000000
# 3405814162               0.0         1.000000         -0.022106
# 3419838867               0.0        -0.047194          1.000000
# 3447495054               0.0        -0.047194         -0.022106
#
# [20012 rows x 6 columns]

# %%
enc_corr_heatmap = sns.heatmap(df_enc.corr(), cmap = 'inferno')
enc_corr_heatmap.set_title('Imputed Data Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
filled_corr_heatmap = sns.heatmap(df_filled.corr(), cmap = 'inferno')
filled_corr_heatmap.set_title('Imputed Data Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
enc_gamestate_by_time_dict[10]['Winner']
# Out:
# 3411673088   -1
# 3435528193    1
# 3447586821    1
# 3426877449   -1
# 3419144205   -1
#              ..
# 3444742545   -1
# 3424164242    1
# 3405814162   -1
# 3419838867    1
# 3447495054   -1
# Name: Winner, Length: 20012, dtype: int64

# %%
df_ini_timecorr = pd.DataFrame()
for time in enc_gamestate_by_time_dict.keys():
    s_corr = pd.Series(enc_gamestate_by_time_dict[time].corrwith(enc_gamestate_by_time_dict[time]['Winner']).drop('Winner'), name=time)
    df_ini_timecorr = pd.concat((df_ini_timecorr, s_corr), axis=1)

# %%
df_ini_timecorr
# Out:
#                             10        15        20        25        30  \
# AIR_DRAGONdiff        0.191492  0.243416  0.264763  0.233516  0.185378
# WATER_DRAGONdiff      0.316650  0.321824  0.325857  0.290281  0.234705
# RIFTHERALDdiff        0.189807  0.231883  0.286865  0.208725  0.107054
# BARON_NASHORdiff           NaN  0.062523  0.051695  0.350548  0.340814
# FIRE_DRAGONdiff       0.278077  0.286979  0.291128  0.279099  0.215613
# EARTH_DRAGONdiff      0.260551  0.300264  0.319744  0.280518  0.247665
# FIRE_DRAGONSoulteam        NaN  1.000000  0.651711  0.725939  0.665715
# AIR_DRAGONSoulteam         NaN  0.577350  0.874957  0.767002  0.673871
# WATER_DRAGONSoulteam       NaN       NaN  0.700551  0.755725  0.717088
# EARTH_DRAGONSoulteam       NaN       NaN  0.594028  0.849271  0.693035
# ELDER_DRAGONdiff           NaN       NaN       NaN -0.200446  0.621034
#
#                             35
# AIR_DRAGONdiff        0.134505
# WATER_DRAGONdiff      0.178456
# RIFTHERALDdiff        0.022551
# BARON_NASHORdiff      0.224869
# FIRE_DRAGONdiff       0.181457
# EARTH_DRAGONdiff      0.201333
# FIRE_DRAGONSoulteam   0.540347
# AIR_DRAGONSoulteam    0.440671
# WATER_DRAGONSoulteam  0.488462
# EARTH_DRAGONSoulteam  0.605013
# ELDER_DRAGONdiff      0.274710

# %%
ax = sns.heatmap(df_ini_timecorr, cmap = 'inferno')
ax.set_xlabel('Match time (min)')
# Out:
# Text(0.5, 15.0, 'Match time (min)')

# %% [markdown]
# Heatmap of correlation of the features with the match winner, for each time interval. Very interesting how high the correlations are for dragon souls with the winner. Infernal soul actually has a correlation coefficient of 1 at 15 minutes. The souls' association with the winning team decreases past 30 minutes, but is still fairly strongly associated with winning with coefficients between 0.44 and 0.61.

# %%
df['firstDragon'].value_counts()
# Out:
# red     8675
# blue    7705
# Name: firstDragon, dtype: int64

# %%
df_dropped['firstDragon'].value_counts()
# Out:
# red     8803
# blue    7804
# Name: firstDragon, dtype: int64

# %%
df_dropped
# Out:
#             GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088          1195    red        red            red         red
# 3435528193          1516   blue       blue            red         NaN
# 3447586821          1964   blue        red            red         red
# 3426877449           915    red        red            NaN         red
# 3419144205          1176    red        red            red         red
# ...                  ...    ...        ...            ...         ...
# 3444742545          1326    red        red            red         red
# 3424164242          1915   blue       blue           blue        blue
# 3405814162          1208    red        red            red        blue
# 3419838867          1305   blue       blue           blue        blue
# 3447495054          1658    red        red            red         red
#
#            firstRiftHerald  baronKillsdiff  riftHeraldKillsdiff  \
# 3411673088            blue               0                    1
# 3435528193             NaN               0                    0
# 3447586821             NaN               1                    0
# 3426877449             red               0                   -1
# 3419144205            blue               0                    0
# ...                    ...             ...                  ...
# 3444742545             red              -1                   -1
# 3424164242            blue               1                    1
# 3405814162            blue               0                    0
# 3419838867            blue               0                    2
# 3447495054            blue               0                    2
#
#             dragonKillsdiff  FIRE_DRAGONdiff  EARTH_DRAGONdiff firstBaron  \
# 3411673088               -2             -1.0              -1.0        NaN
# 3435528193                0              NaN               NaN        NaN
# 3447586821               -3             -2.0              -1.0       blue
# 3426877449               -2              NaN              -1.0        NaN
# 3419144205               -2             -1.0               NaN        NaN
# ...                     ...              ...               ...        ...
# 3444742545               -3             -1.0              -1.0        red
# 3424164242                1              NaN               1.0       blue
# 3405814162               -1              1.0              -1.0        NaN
# 3419838867                3              1.0               1.0        NaN
# 3447495054               -2              NaN              -1.0        NaN
#
#            FIRE_DRAGONSoul  AIR_DRAGONdiff  ELDER_DRAGONdiff  \
# 3411673088             NaN             NaN               NaN
# 3435528193             NaN             NaN               NaN
# 3447586821             red            -1.0               1.0
# 3426877449             NaN             NaN               NaN
# 3419144205             NaN             NaN               NaN
# ...                    ...             ...               ...
# 3444742545             NaN            -1.0               NaN
# 3424164242             NaN             1.0               NaN
# 3405814162             NaN             NaN               NaN
# 3419838867             NaN             NaN               NaN
# 3447495054             NaN             NaN               NaN
#
#             WATER_DRAGONdiff EARTH_DRAGONSoul WATER_DRAGONSoul AIR_DRAGONSoul
# 3411673088               NaN              NaN              NaN            NaN
# 3435528193               NaN              NaN              NaN            NaN
# 3447586821               NaN              NaN              NaN            NaN
# 3426877449              -1.0              NaN              NaN            NaN
# 3419144205              -1.0              NaN              NaN            NaN
# ...                      ...              ...              ...            ...
# 3444742545               NaN              NaN              NaN            NaN
# 3424164242              -1.0              NaN              NaN            NaN
# 3405814162              -1.0              NaN              NaN            NaN
# 3419838867               1.0              NaN              NaN            NaN
# 3447495054              -1.0              NaN              NaN            NaN
#
# [20154 rows x 19 columns]

# %% [markdown]
# <a id = 'model'> </a>
# # Revised Model

# %% [markdown]
# My original data had separate sets of features for each team and time features for each objective in an attempt to preserve features. As I found no significant difference in maintaining separate team features, I chose to combine the separate team features for ease of results interpretation. For the revised data and model. I combined the teams' metrics by subtracting the red team from the blue team.
#
# Original model can be found in later sections of this notebook.

# %%
X = df_filled.drop('Winner', axis=1)

# %%
y = df_filled['Winner']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Model selection
#
# Why ensemble learning classifiers:
# - works quickly and efficiently for large datasets
# - high accuracy for complex datasets
# - however, overfitting happens easily
#
# Model of choice, Gradient Boosting Classifier, uses a loss function and weak learner decision trees. The weak learners are added to each other

# %%
# %%time
# prepare configuration for cross validation test harness
seed = 42
# prepare models
models = []
models.append(('ADA', AdaBoostClassifier()))
models.append(('BAG', BaggingClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('GBC', GradientBoostingClassifier()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = KFold(n_splits=10, random_state=seed)
	cv_results = cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# ADA: 0.891745 (0.006074)
# BAG: 0.874975 (0.005032)
# RFC: 0.884452 (0.004338)
# GBC: 0.899385 (0.004823)
# Wall time: 32.4 s

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Just like with the initial model, GradientBoostingClassifier performed the best amongst the classifers with an accuracy score of 90% and F-score of 0.899.

# %% [markdown]
# #### Model tuning
#
# First tried GridSearchCV with small number of parameters, which did not optimize model (and in fact worsened performance slightly). Subsequently used more parameters with RandomSearchCV which produced a slightly improved model.
#
# |                	| Initial Model 	| Optimised Model 	|
# |----------------	|---------------	|-----------------	|
# | Accuracy Score 	|     0.9044    	| 0.9051          	|
# | F-score        	| 0.8994        	| 0.9007          	|

# %%
# %%time
# Initialize the classifier
clf_GB = GradientBoostingClassifier(random_state = 42)

# Create the parameters list to tune
#parameters = {'n_estimators':[10, 20, 60, 100], 'learning_rate': [0.05, 0.1, 0.2, 1]}

parameters = {
    "n_estimators":[5,50,250,500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,10,100]
}

# TODO: Make an fbeta_score scoring object using make_scorer()
scorer = make_scorer(fbeta_score, beta = 0.5)

# TODO: Perform grid search on the classifier using 'scorer' as the scoring method using GridSearchCV()
grid_obj = GridSearchCV(estimator = clf_GB, param_grid = parameters, scoring = scorer, cv = 5)

# TODO: Fit the grid search object to the training data and find the optimal parameters using fit()
grid_fit = grid_obj.fit(X_train, y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

# Make predictions using the unoptimized and model
predictions = (clf_GB.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Unoptimized model
# ------
# Accuracy score on testing data: 0.9044
# F-score on testing data: 0.8994
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 0.8857
# Final F-score on the testing data: 0.9031

# %%
# %%time
clf = GradientBoostingClassifier()

# TODO: Make an fbeta_score scoring object using make_scorer()
scorer = make_scorer(fbeta_score, beta = 0.5)

params = {"max_depth": [3, None],
              "max_features": range(1, 9),
              "min_samples_leaf": range(1, 9),
              "criterion": ["gini", "friedman_mse"],
                'n_estimators':[10, 20, 60, 100], 
                'learning_rate': [0.05, 0.01, 0.1, 0.2, 1],
                'max_depth': [None, 1, 3, 5, 10]}

'''
#Another set of parameters to use
params = {
    "n_estimators":[5,50,250,500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,10,100]
'''
random_search = RandomizedSearchCV(clf, param_distributions=params,n_iter=4, scoring=scorer)
random_search.fit(X_train, y_train)


#store optimized clf
best_clf = random_search.best_estimator_

predictions = clf.fit(X_train, y_train).predict(X_test)
best_predictions = best_clf.predict(X_test)
print("Unoptimized model\n------")
print(classification_report(y_test, predictions))
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print(classification_report(y_test, best_predictions))
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Unoptimized model
# ------
#               precision    recall  f1-score   support
#
#           -1       0.91      0.90      0.91      3109
#            1       0.90      0.91      0.90      2938
#
#     accuracy                           0.90      6047
#    macro avg       0.90      0.90      0.90      6047
# weighted avg       0.90      0.90      0.90      6047
#
# Accuracy score on testing data: 0.9044
# F-score on testing data: 0.8994
#
# Optimized Model
# ------
#               precision    recall  f1-score   support
#
#           -1       0.91      0.90      0.91      3109
#            1       0.90      0.91      0.90      2938
#
#     accuracy                           0.91      6047
#    macro avg       0.90      0.91      0.91      6047
# weighted avg       0.91      0.91      0.91      6047
#
# Final accuracy score on the testing data: 0.9051
# Final F-score on the testing data: 0.9007
# Wall time: 10.8 s

# %%
def train_time_series():
    '''
    Trains estimator to predict match winner based on data of captured neutral objectives up to set time intervals.
    Outputs performance metrics,Fbeta_score and accuracy score, and feature importances.
    
    '''
    feat_imp_by_time_df = pd.DataFrame()
    scores_by_time_df = pd.DataFrame(index=[x for x in filled_gamestate_by_time_dict.keys()], 
                                     columns=['F-score', 'Accuracy'])
    for time in list(filled_gamestate_by_time_dict.keys()):
        X = filled_gamestate_by_time_dict[time].drop('Winner', axis=1)
        y = filled_gamestate_by_time_dict[time]['Winner']
        X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)
        best_clf.fit(X_train, y_train)
        y_preds = best_clf.predict(X_test)
        
        s_feat_imp = pd.Series(best_clf.feature_importances_, index=X.columns.values, name=time).sort_values(ascending=False)
        feat_imp_by_time_df = pd.concat((feat_imp_by_time_df, s_feat_imp), axis=1)
        
        scores_by_time_df['F-score'][time] = fbeta_score(y_test, y_preds, beta = 0.5)
        scores_by_time_df['Accuracy'][time] = accuracy_score(y_test, y_preds)

    return feat_imp_by_time_df, scores_by_time_df.astype(float)

# %%
# %%time
feat_imp_by_time_df, scores_by_time_df = train_time_series()
# Out:
# Wall time: 3.76 s

# %%
feat_imp_by_time_df
# Out:
#                             10        15        20        25        30  \
# WATER_DRAGONdiff      0.299001  0.203074  0.211798  0.140192  0.116853
# FIRE_DRAGONdiff       0.274889  0.189322  0.162145  0.149741  0.143867
# EARTH_DRAGONdiff      0.217706  0.201837  0.203155  0.161219  0.129570
# AIR_DRAGONdiff        0.130932  0.135262  0.130543  0.107321  0.115742
# RIFTHERALDdiff        0.077472  0.221196  0.252760  0.134774  0.118129
# BARON_NASHORdiff      0.000000  0.047827  0.031107  0.283870  0.300873
# AIR_DRAGONSoulteam         NaN  0.000860  0.002792  0.006717  0.019206
# FIRE_DRAGONSoulteam        NaN  0.000621  0.002530  0.005143  0.012605
# ELDER_DRAGONdiff           NaN  0.000000  0.000000  0.001764  0.011231
# EARTH_DRAGONSoulteam       NaN  0.000000  0.001565  0.004658  0.012433
# WATER_DRAGONSoulteam       NaN  0.000000  0.001605  0.004603  0.019491
#
#                             35
# WATER_DRAGONdiff      0.097120
# FIRE_DRAGONdiff       0.099195
# EARTH_DRAGONdiff      0.135436
# AIR_DRAGONdiff        0.111016
# RIFTHERALDdiff        0.143125
# BARON_NASHORdiff      0.214265
# AIR_DRAGONSoulteam    0.025089
# FIRE_DRAGONSoulteam   0.053519
# ELDER_DRAGONdiff      0.042576
# EARTH_DRAGONSoulteam  0.032578
# WATER_DRAGONSoulteam  0.046080

# %%
scores_by_time_df
# Out:
#      F-score  Accuracy
# 10  0.532248  0.580446
# 15  0.613754  0.630252
# 20  0.679688  0.675913
# 25  0.710488  0.705388
# 30  0.696319  0.698388
# 35  0.705394  0.665914

# %%
ax = sns.lineplot(data=scores_by_time_df, palette="husl")

ax.set_ylabel("Performance Metric")
ax.set_xlabel("Game Time (min)")
plt.title('Predicting wins based on cumulative objectives discrepancies at different time intervals')
#plt.tight_layout(h_pad=2)
# Out:
# Text(0.5, 1.0, 'Predicting wins based on cumulative objectives discrepancies at different time intervals')

# %% [markdown]
# As to be expected, prediction accuracy is little better than random during early game when very few objectives are available to be taken, and thus less data available to base predictions upon. As teams capture more objectives throughout the game, the accuracy increases to a maximum of 70.5% at 25 mins and declines thereafter. The decline is also expected since the advantages granted by neutral objectives slowly evens out: the disadvantaged team can use the time in a stalled game to catch up in resources (gold), while gold differences matters less and less as players max out their resource slots.

# %%
clf_preset = GradientBoostingClassifier()
saved_params = {'ccp_alpha': 0.0,
 'criterion': 'friedman_mse',
 'init': None,
 'learning_rate': 0.2,
 'loss': 'deviance',
 'max_depth': 5,
 'max_features': 4,
 'max_leaf_nodes': None,
 'min_impurity_decrease': 0.0,
 'min_impurity_split': None,
 'min_samples_leaf': 6,
 'min_samples_split': 2,
 'min_weight_fraction_leaf': 0.0,
 'n_estimators': 60,
 'n_iter_no_change': None,
 'presort': 'deprecated',
 'random_state': None,
 'subsample': 1.0,
 'tol': 0.0001,
 'validation_fraction': 0.1,
 'verbose': 0,
 'warm_start': False}

# %%
clf_preset.set_params(**saved_params)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.2, loss='deviance', max_depth=5,
#                            max_features=4, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=6, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=60,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
best_clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.2,
#  'loss': 'deviance',
#  'max_depth': 5,
#  'max_features': 4,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 6,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 60,
#  'n_iter_no_change': None,
#  'presort': 'deprecated',
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Feature importances

# %%
var_diff = ['baronKillsdiff','riftHeraldKillsdiff', 
                   'dragonKillsdiff', 'FIRE_DRAGONdiff', 'EARTH_DRAGONdiff', 
                   'AIR_DRAGONdiff', 'ELDER_DRAGONdiff', 'WATER_DRAGONdiff']
var_team = ['firstTower', 'firstInhibitor',
       'firstDragon', 'firstRiftHerald', 'firstBaron', 'FIRE_DRAGONSoul', 
              'EARTH_DRAGONSoul', 'WATER_DRAGONSoul', 'AIR_DRAGONSoul']
var_firsts = ['firstTower', 'firstInhibitor',
       'firstDragon', 'firstRiftHerald', 'firstBaron']
var_dragtypediff = ['FIRE_DRAGONdiff', 'EARTH_DRAGONdiff', 
                   'AIR_DRAGONdiff', 'ELDER_DRAGONdiff', 'WATER_DRAGONdiff']
var_soul = ['FIRE_DRAGONSoul', 
              'EARTH_DRAGONSoul', 'WATER_DRAGONSoul', 'AIR_DRAGONSoul']

# %%
feat_importances = pd.Series(best_clf.feature_importances_, index=X_test.columns.values).sort_values(ascending=False)

# %%
feat_importances
# Out:
# firstInhibitor         0.428574
# dragonKillsdiff        0.194438
# GameDuration           0.100819
# baronKillsdiff         0.082527
# firstBaron             0.035316
# firstTower             0.035183
# riftHeraldKillsdiff    0.018968
# FIRE_DRAGONdiff        0.016897
# firstDragon            0.015536
# EARTH_DRAGONdiff       0.014207
# AIR_DRAGONdiff         0.013353
# WATER_DRAGONdiff       0.013240
# firstRiftHerald        0.012784
# ELDER_DRAGONdiff       0.007782
# FIRE_DRAGONSoul        0.002904
# AIR_DRAGONSoul         0.002528
# EARTH_DRAGONSoul       0.002499
# WATER_DRAGONSoul       0.002447
# dtype: float64

# %%
def plot_barh(s_to_plot, title = '', xlabel = '', ylabel = '',
color_palette = 'YlGnBu', pre_unit = '', suff_unit = '', round_place = 4,
              xllim_set = 0, xulim_set = 1, size=(12, 8)):

    y_labels = s_to_plot.index

    # Plot the figure.
    plt.figure(figsize=size)
    ax = s_to_plot.plot(kind='barh')
    plt.barh(s_to_plot.index, s_to_plot,
            color = sns.color_palette(color_palette, len(s_to_plot.index)))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_yticklabels(y_labels)
    #x_llim, x_ulim = ax.get_xlim()
    #x_ulim = xulim_set
    ax.set_xlim(xllim_set, xulim_set) # expand xlim to make labels easier to read
    plt.tight_layout()
    rects = ax.patches

    # For each bar: Place a label
    for rect in rects:
        # Get X and Y placement of label from rect.
        x_value = rect.get_width()
        y_value = rect.get_y() + rect.get_height() / 2

        # Number of points between bar and label. Change to your liking.
        space = 5
        # Vertical alignment for positive values
        ha = 'left'

        # If value of bar is negative: Place label left of bar
        if x_value < 0:
            # Invert space to place label to the left
            space *= -1
            # Horizontally align label at right
            ha = 'right'

        label_string = "{:."+str(round_place)+"f}"
        # Use X value as label and format number with a defined number of decimal places
        #label = "{:.1f}".format(x_value)
        label = label_string.format(x_value)

        # Create annotation
        plt.annotate(
            pre_unit+label+suff_unit,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(space, 0),          # Horizontally shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            va='center',                # Vertically center label
            ha=ha)                      # Horizontally align label differently for
                                        # positive and negative values.

# %% [markdown]
# <a id = 'results'></a>
#
# # Results

# %%
v.plot_barh(feat_importances.sort_values(ascending=True), xulim_set=0.48, round_place=4)

# %%
sns.heatmap(feat_imp_by_time_df, cmap = 'inferno')

# %% [markdown]
# # Results Summary

# %% [markdown]
# Although this project is unable to establish causal relationships, it identified interesting relationships between different types of neutral objectives, game time, and the winning team:
# - among the "firsts" in objectives, first inhibitor is most predictive of the winner followed by first baron and first tower very closely together.
#
# The top 5 most post-game predictive features are:
# 1. team that takes first inhibitor
# 2. elemental dragons difference
# 3. game duration
# 4. baron kill difference
# 5. team that takes first baron / team that takes first tower
#
#
#
#
#
#
# ### Early objectives
#
# Of all the early objectives available (inhibitor, tower, dragon, baron, rift herald), the order of their importances are.
#
# #### First inhibitor > First baron > First tower > First dragon > First rift herald
#
# Of course, the associations here must be taken with a grain of salt before tranlating them to causation - other than First Inhibitor, the differences in weights between the objectives are not big. Having early game pressure will translate to more objective control. However, it is very telling that first dragon has more weight than first herald, when both of these objectives are usually captured around the same time and are often "traded" for each other (if one team takes one, the other team will take the other).

# %% [markdown]
# Different types of objectives seem to be the most valuable (associated with winning) at different points in the game:
# - 10 mins: **elemental dragon differences**, in order of Ocean > Infernal > Mountain > Cloud.
#     - While this may suggest that the order is related to the degree of advantage the dragon bestows on a team, it's just as possible that the order reflects prioritization of the dragon types. For example, the ocean dragons are regarded as beneficial for early laning phases, so advantaged team may expend more effort securing the dragon than for a cloud dragon.
#     - considering the priority that teams place on dragons right now as a stepping stone to obtaining dragon soul, the weakness of the individual dragons, and the fact that the soul drake element is not reveal until after the 2nd dragon is killed, it seems likely that the weight differences here stem from the degree of advantages conferred by different types of dragons.
# - 15-20 mins: **rift herald difference** - if the rift herald is captured early enough, it will spawn a second time as a stronger buff. The rift herald will despawn at 20 minutes if not killed, so the window of most significance during 15 and 20 minutes reflects this nicely. The 20 minute association is stronger than the 15 minute one in accordance with the rift herald's strength.
# - 25-35 mins: **Baron nashor difference** at 35 mins, soul dragons and elder dragons become more significant, but their effects are still overshadowed by literally every other objective.
#
# ### Elemental Dragons
# It seems that elemental dragon advantages - those found in early game - are much more significantly associated with wins than souls. Certainly part of the reason for the association may be the translation of early game advantages, obtained from outside of neutral objectives (e.g. lane dominance, successful skirmishes), into capturing neutral objectives. There is still the logical possibility of a causal relationship.
#
# Individiual elemental dragons might be weak (and they are far weaker than in previous seasons), but they are far more significantly related to wins than the objectively stronger elder dragons and dragon souls. The small advantages conferred by individual drakes in the early game might help teams dominate over the enemy team and snowball further advantages.
# To better establish a causal relationship, Assessing how teams prioritize between the different objectives would be useful to establish a causal relationship. The relatively small importances that souls have towards wins compared to the initial direct correlation might be that by the time these late-game objectives are available, wins are already decided by early game snowballing.

# %% [markdown]
# # Future work/directions:
# - adding predictions based on different points of time in the game
# - adding lane positions to assess their impact on objective control
# - try fitting a XGBoost Classifier model, a variation of the Gradient Boosting Classifier used for the project
# - add other relevant match variables: team gold, kills, wards, champion picks, etc.
# - expand number of matches in dataset - due to time practicality limitations, only 20,000 matches were extracted of over 60,000 match IDs obtained
# - expand data to servers in other geographical regions - e.g. EU, China, Korean
# - expand data to lower elos, since masters+ is a very small proportion of the playerbase and may not reflect what the predictors are in lower elo (e.g. Bronze, Silver, Gold)
# - evaluate competitive play, which plays out differently than solo queue, and where objective decisions matter more than anywhere else

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# take out all time vars

# %%
match_stats_dict
# Out:
# {3411673088: {'GameDuration': 1195,
#   'Winner': 'red',
#   'FIRE_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1,
#   'RIFTHERALDdiff': 1,
#   'BARON_NASHORdiff': 0},
#  3435528193: {'GameDuration': 1516, 'Winner': 'blue'},
#  3447586821: {'GameDuration': 1964,
#   'Winner': 'blue',
#   'FIRE_DRAGONSoulteam': 'red',
#   'AIR_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1,
#   'FIRE_DRAGONdiff': -2,
#   'ELDER_DRAGONdiff': 1,
#   'RIFTHERALDdiff': 0,
#   'BARON_NASHORdiff': 1},
#  3426877449: {'GameDuration': 915,
#   'Winner': 'red',
#   'WATER_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': 0},
#  3419144205: {'GameDuration': 1176,
#   'Winner': 'red',
#   'FIRE_DRAGONdiff': -1,
#   'WATER_DRAGONdiff': -1,
#   'RIFTHERALDdiff': 0,
#   'BARON_NASHORdiff': 0},
#  3428843533: {'GameDuration': 758,
#   'Winner': 'red',
#   'WATER_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1},
#  3433824271: {'GameDuration': 1154,
#   'Winner': 'blue',
#   'FIRE_DRAGONdiff': 1,
#   'WATER_DRAGONdiff': -1,
#   'AIR_DRAGONdiff': 0,
#   'RIFTHERALDdiff': 0,
#   'BARON_NASHORdiff': 1},
#  3445751824: {'GameDuration': 1954,
#   'Winner': 'blue',
#   'EARTH_DRAGONSoulteam': 'blue',
#   'FIRE_DRAGONdiff': 1,
#   'AIR_DRAGONdiff': 1,
#   'EARTH_DRAGONdiff': 2,
#   'ELDER_DRAGONdiff': 1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': 1},
#  3442737172: {'GameDuration': 1716,
#   'Winner': 'blue',
#   'FIRE_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1,
#   'AIR_DRAGONdiff': 1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': 1},
#  3397648407: {'GameDuration': 1511,
#   'Winner': 'red',
#   'AIR_DRAGONdiff': 1,
#   'WATER_DRAGONdiff': -1,
#   'FIRE_DRAGONdiff': -1,
#   'RIFTHERALDdiff': 1,
#   'BARON_NASHORdiff': -1},
#  3422683163: {'GameDuration': 1436,
#   'Winner': 'blue',
#   'WATER_DRAGONSoulteam': 'blue',
#   'FIRE_DRAGONdiff': 1,
#   'EARTH_DRAGONdiff': 1,
#   'WATER_DRAGONdiff': 2,
#   'RIFTHERALDdiff': 0,
#   'BARON_NASHORdiff': 1},
#  3383099420: {'GameDuration': 621,
#   'Winner': 'red',
#   'AIR_DRAGONdiff': -1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': 0},
#  3442868254: {'GameDuration': 1519,
#   'Winner': 'red',
#   'FIRE_DRAGONSoulteam': 'red',
#   'WATER_DRAGONdiff': -1,
#   'AIR_DRAGONdiff': -1,
#   'FIRE_DRAGONdiff': -2,
#   'RIFTHERALDdiff': -2,
#   'BARON_NASHORdiff': -1},
#  3421372448: {'GameDuration': 942,
#   'Winner': 'red',
#   'AIR_DRAGONdiff': -1,
#   'WATER_DRAGONdiff': -1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': 0},
#  3441557537: {'GameDuration': 1941,
#   'Winner': 'blue',
#   'AIR_DRAGONSoulteam': 'blue',
#   'FIRE_DRAGONdiff': 1,
#   'EARTH_DRAGONdiff': 1,
#   'AIR_DRAGONdiff': 1,
#   'RIFTHERALDdiff': 2,
#   'BARON_NASHORdiff': -1},
#  3431858209: {'GameDuration': 1747,
#   'Winner': 'blue',
#   'AIR_DRAGONdiff': -1,
#   'FIRE_DRAGONdiff': 1,
#   'EARTH_DRAGONdiff': 2,
#   'RIFTHERALDdiff': 1,
#   'BARON_NASHORdiff': 1},
#  3433168932: {'GameDuration': 2054,
#   'Winner': 'red',
#   'AIR_DRAGONSoulteam': 'red',
#   'FIRE_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': -1,
#   'AIR_DRAGONdiff': -1,
#   'RIFTHERALDdiff': -1,
#   'BARON_NASHORdiff': -1},
#  3439329317: {'GameDuration': 1763,
#   'Winner': 'red',
#   'WATER_DRAGONdiff': -1,
#   'EARTH_DRAGONdiff': 1,
#   'AIR_DRAGONdiff': -2,
#   'RIFTHERALDdiff': 2,
#   'BARON_NASHORdiff': 1},
#  3445358630: {'GameDuration': 1639, 'Winner': 'red'},
#  3435135015: {'GameDuration': 1420,
#   'Winner': 'red',
#   'AIR_DRAGONSoulteam': 'red',
#   'EARTH_DRAGONdiff': -1,
#   'FIRE_DRAGONdiff': -1,
#   'AIR_DRAGONdiff': -2,
#   'RIFTHERALDdiff': -2,
#   'BARON_NASHORdiff': 0}}

# %%
match_timeline_dict[gameId].keys()
# Out:
# dict_keys(['frames', 'frameInterval'])

# %%
#convert dict into df with one game per row
df = pd.DataFrame(match_stats_dict3).transpose()

# %%
var_soul = ['FIRE_DRAGONSoulteam', 'FIRE_DRAGONSoultime',
            'WATER_DRAGONSoulteam', 'WATER_DRAGONSoultime',
           'AIR_DRAGONSoulteam', 'AIR_DRAGONSoultime',
           'EARTH_DRAGONSoulteam', 'EARTH_DRAGONSoultime']
var_soul_team = ['FIRE_DRAGONSoulteam', 
            'WATER_DRAGONSoulteam', 
           'AIR_DRAGONSoulteam', 
           'EARTH_DRAGONSoulteam']
var_soul_time = ['FIRE_DRAGONSoultime',
'WATER_DRAGONSoultime',
'AIR_DRAGONSoultime',
'EARTH_DRAGONSoultime']

# %%
for var in var_soul_team:
    print (df[var].value_counts())
# Out:
# red     518
# blue    433
# Name: FIRE_DRAGONSoulteam, dtype: int64
# red     539
# blue    468
# Name: WATER_DRAGONSoulteam, dtype: int64
# red     521
# blue    423
# Name: AIR_DRAGONSoulteam, dtype: int64
# red     541
# blue    461
# Name: EARTH_DRAGONSoulteam, dtype: int64

# %%
df[var_soul_team]
# Out:
#            FIRE_DRAGONSoulteam WATER_DRAGONSoulteam AIR_DRAGONSoulteam  \
# 3411673088                 NaN                  NaN                NaN
# 3435528193                 NaN                  NaN                NaN
# 3447586821                 red                  NaN                NaN
# 3426877449                 NaN                  NaN                NaN
# 3419144205                 NaN                  NaN                NaN
# ...                        ...                  ...                ...
# 3436877728                 NaN                  NaN                NaN
# 3422984098                 NaN                  NaN                NaN
# 3342243749                 NaN                  NaN                NaN
# 3448805286                 NaN                  NaN                NaN
# 3427833767                 NaN                  NaN                NaN
#
#            EARTH_DRAGONSoulteam
# 3411673088                  NaN
# 3435528193                  NaN
# 3447586821                  NaN
# 3426877449                  NaN
# 3419144205                  NaN
# ...                         ...
# 3436877728                  NaN
# 3422984098                  NaN
# 3342243749                  NaN
# 3448805286                  NaN
# 3427833767                  NaN
#
# [20000 rows x 4 columns]

# %%
#create new var of which team obtained dragon soul
s = df[var_soul_team[0]]
for var in var_soul_team[1:]:
    s = s.replace(np.nan, '').astype(str).add(df[var].replace(np.nan, '').astype(str))

# %%
df['soul_team'] = s.replace({'':np.nan})

# %%
df['GameDuration'].max()
# Out:
# 3507

# %%
df
# Out:
#            GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088         1195    red        red            red         red
# 3435528193         1516   blue       blue            red         NaN
# 3447586821         1964   blue        red            red         red
# 3426877449          915    red        red            NaN         red
# 3419144205         1176    red        red            red         red
# ...                 ...    ...        ...            ...         ...
# 3436877728         2184    red        red            red         red
# 3422984098         1112   blue       blue           blue         red
# 3342243749         1880    red       blue            red        blue
# 3448805286         1105    red        red            NaN         red
# 3427833767          896   blue       blue           blue        blue
#
#            firstRiftHerald bluebaronKills redbaronKills blueriftHeraldKills  \
# 3411673088            blue              0             0                   1
# 3435528193             NaN              0             0                   0
# 3447586821             NaN              1             0                   0
# 3426877449             red              0             0                   0
# 3419144205            blue              0             0                   1
# ...                    ...            ...           ...                 ...
# 3436877728             red              0             2                   0
# 3422984098            blue              0             0                   1
# 3342243749            blue              0             1                   1
# 3448805286            blue              0             0                   1
# 3427833767             NaN              0             0                   0
#
#            redriftHeraldKills  ... 2ELDER_DRAGONtime 7AIR_DRAGONteam  \
# 3411673088                  0  ...               NaN             NaN
# 3435528193                  0  ...               NaN             NaN
# 3447586821                  0  ...               NaN             NaN
# 3426877449                  1  ...               NaN             NaN
# 3419144205                  1  ...               NaN             NaN
# ...                       ...  ...               ...             ...
# 3436877728                  1  ...               NaN             NaN
# 3422984098                  0  ...               NaN             NaN
# 3342243749                  1  ...               NaN             NaN
# 3448805286                  0  ...               NaN             NaN
# 3427833767                  0  ...               NaN             NaN
#
#            7AIR_DRAGONtime 7WATER_DRAGONteam 7WATER_DRAGONtime  \
# 3411673088             NaN               NaN               NaN
# 3435528193             NaN               NaN               NaN
# 3447586821             NaN               NaN               NaN
# 3426877449             NaN               NaN               NaN
# 3419144205             NaN               NaN               NaN
# ...                    ...               ...               ...
# 3436877728             NaN               NaN               NaN
# 3422984098             NaN               NaN               NaN
# 3342243749             NaN               NaN               NaN
# 3448805286             NaN               NaN               NaN
# 3427833767             NaN               NaN               NaN
#
#            3ELDER_DRAGONteam 3ELDER_DRAGONtime BARON_NASHOR5team  \
# 3411673088               NaN               NaN               NaN
# 3435528193               NaN               NaN               NaN
# 3447586821               NaN               NaN               NaN
# 3426877449               NaN               NaN               NaN
# 3419144205               NaN               NaN               NaN
# ...                      ...               ...               ...
# 3436877728               NaN               NaN               NaN
# 3422984098               NaN               NaN               NaN
# 3342243749               NaN               NaN               NaN
# 3448805286               NaN               NaN               NaN
# 3427833767               NaN               NaN               NaN
#
#            BARON_NASHOR5time soul_team
# 3411673088               NaN       NaN
# 3435528193               NaN       NaN
# 3447586821               NaN       red
# 3426877449               NaN       NaN
# 3419144205               NaN       NaN
# ...                      ...       ...
# 3436877728               NaN       NaN
# 3422984098               NaN       NaN
# 3342243749               NaN       NaN
# 3448805286               NaN       NaN
# 3427833767               NaN       NaN
#
# [20000 rows x 108 columns]

# %%
match_stats = {}

# %%
df_clean = df[df['GameDuration'] > 300]

# %%
df_dropped
# Out:
#            GameDuration Winner firstTower firstInhibitor firstDragon  \
# 3411673088         1195    red        red            red         red
# 3435528193         1516   blue       blue            red         NaN
# 3447586821         1964   blue        red            red         red
# 3426877449          915    red        red            NaN         red
# 3419144205         1176    red        red            red         red
# ...                 ...    ...        ...            ...         ...
# 3436877728         2184    red        red            red         red
# 3422984098         1112   blue       blue           blue         red
# 3342243749         1880    red       blue            red        blue
# 3448805286         1105    red        red            NaN         red
# 3427833767          896   blue       blue           blue        blue
#
#            firstRiftHerald bluebaronKills redbaronKills blueriftHeraldKills  \
# 3411673088            blue              0             0                   1
# 3435528193             NaN              0             0                   0
# 3447586821             NaN              1             0                   0
# 3426877449             red              0             0                   0
# 3419144205            blue              0             0                   1
# ...                    ...            ...           ...                 ...
# 3436877728             red              0             2                   0
# 3422984098            blue              0             0                   1
# 3342243749            blue              0             1                   1
# 3448805286            blue              0             0                   1
# 3427833767             NaN              0             0                   0
#
#            redriftHeraldKills  ... 2ELDER_DRAGONteam 2ELDER_DRAGONtime  \
# 3411673088                  0  ...               NaN               NaN
# 3435528193                  0  ...               NaN               NaN
# 3447586821                  0  ...               NaN               NaN
# 3426877449                  1  ...               NaN               NaN
# 3419144205                  1  ...               NaN               NaN
# ...                       ...  ...               ...               ...
# 3436877728                  1  ...               NaN               NaN
# 3422984098                  0  ...               NaN               NaN
# 3342243749                  1  ...               NaN               NaN
# 3448805286                  0  ...               NaN               NaN
# 3427833767                  0  ...               NaN               NaN
#
#            7AIR_DRAGONteam 7AIR_DRAGONtime 7WATER_DRAGONteam  \
# 3411673088             NaN             NaN               NaN
# 3435528193             NaN             NaN               NaN
# 3447586821             NaN             NaN               NaN
# 3426877449             NaN             NaN               NaN
# 3419144205             NaN             NaN               NaN
# ...                    ...             ...               ...
# 3436877728             NaN             NaN               NaN
# 3422984098             NaN             NaN               NaN
# 3342243749             NaN             NaN               NaN
# 3448805286             NaN             NaN               NaN
# 3427833767             NaN             NaN               NaN
#
#            7WATER_DRAGONtime 3ELDER_DRAGONteam 3ELDER_DRAGONtime  \
# 3411673088               NaN               NaN               NaN
# 3435528193               NaN               NaN               NaN
# 3447586821               NaN               NaN               NaN
# 3426877449               NaN               NaN               NaN
# 3419144205               NaN               NaN               NaN
# ...                      ...               ...               ...
# 3436877728               NaN               NaN               NaN
# 3422984098               NaN               NaN               NaN
# 3342243749               NaN               NaN               NaN
# 3448805286               NaN               NaN               NaN
# 3427833767               NaN               NaN               NaN
#
#            BARON_NASHOR5team BARON_NASHOR5time
# 3411673088               NaN               NaN
# 3435528193               NaN               NaN
# 3447586821               NaN               NaN
# 3426877449               NaN               NaN
# 3419144205               NaN               NaN
# ...                      ...               ...
# 3436877728               NaN               NaN
# 3422984098               NaN               NaN
# 3342243749               NaN               NaN
# 3448805286               NaN               NaN
# 3427833767               NaN               NaN
#
# [19882 rows x 107 columns]

# %%
#drop games below 3min in length - not relevant since they would be remakes
df_clean = df[df['GameDuration'] > 300].replace({'blue':0, 'red':1})

# %%
df_clean
# Out:
#             GameDuration  Winner  firstTower  firstInhibitor  firstDragon  \
# 3411673088          1195       1         1.0             1.0          1.0
# 3435528193          1516       0         0.0             1.0          NaN
# 3447586821          1964       0         1.0             1.0          1.0
# 3426877449           915       1         1.0             NaN          1.0
# 3419144205          1176       1         1.0             1.0          1.0
# ...                  ...     ...         ...             ...          ...
# 3436877728          2184       1         1.0             1.0          1.0
# 3422984098          1112       0         0.0             0.0          1.0
# 3342243749          1880       1         0.0             1.0          0.0
# 3448805286          1105       1         1.0             NaN          1.0
# 3427833767           896       0         0.0             0.0          0.0
#
#             firstRiftHerald  bluebaronKills  redbaronKills  \
# 3411673088              0.0               0              0
# 3435528193              NaN               0              0
# 3447586821              NaN               1              0
# 3426877449              1.0               0              0
# 3419144205              0.0               0              0
# ...                     ...             ...            ...
# 3436877728              1.0               0              2
# 3422984098              0.0               0              0
# 3342243749              0.0               0              1
# 3448805286              0.0               0              0
# 3427833767              NaN               0              0
#
#             blueriftHeraldKills  redriftHeraldKills  ...  2ELDER_DRAGONtime  \
# 3411673088                    1                   0  ...                NaN
# 3435528193                    0                   0  ...                NaN
# 3447586821                    0                   0  ...                NaN
# 3426877449                    0                   1  ...                NaN
# 3419144205                    1                   1  ...                NaN
# ...                         ...                 ...  ...                ...
# 3436877728                    0                   1  ...                NaN
# 3422984098                    1                   0  ...                NaN
# 3342243749                    1                   1  ...                NaN
# 3448805286                    1                   0  ...                NaN
# 3427833767                    0                   0  ...                NaN
#
#             7AIR_DRAGONteam  7AIR_DRAGONtime  7WATER_DRAGONteam  \
# 3411673088              NaN              NaN                NaN
# 3435528193              NaN              NaN                NaN
# 3447586821              NaN              NaN                NaN
# 3426877449              NaN              NaN                NaN
# 3419144205              NaN              NaN                NaN
# ...                     ...              ...                ...
# 3436877728              NaN              NaN                NaN
# 3422984098              NaN              NaN                NaN
# 3342243749              NaN              NaN                NaN
# 3448805286              NaN              NaN                NaN
# 3427833767              NaN              NaN                NaN
#
#             7WATER_DRAGONtime  3ELDER_DRAGONteam  3ELDER_DRAGONtime  \
# 3411673088                NaN                NaN                NaN
# 3435528193                NaN                NaN                NaN
# 3447586821                NaN                NaN                NaN
# 3426877449                NaN                NaN                NaN
# 3419144205                NaN                NaN                NaN
# ...                       ...                ...                ...
# 3436877728                NaN                NaN                NaN
# 3422984098                NaN                NaN                NaN
# 3342243749                NaN                NaN                NaN
# 3448805286                NaN                NaN                NaN
# 3427833767                NaN                NaN                NaN
#
#             BARON_NASHOR5team  BARON_NASHOR5time  soul_team
# 3411673088                NaN                NaN        NaN
# 3435528193                NaN                NaN        NaN
# 3447586821                NaN                NaN        1.0
# 3426877449                NaN                NaN        NaN
# 3419144205                NaN                NaN        NaN
# ...                       ...                ...        ...
# 3436877728                NaN                NaN        NaN
# 3422984098                NaN                NaN        NaN
# 3342243749                NaN                NaN        NaN
# 3448805286                NaN                NaN        NaN
# 3427833767                NaN                NaN        NaN
#
# [19882 rows x 108 columns]

# %%
df_filled = df_clean.fillna(df_clean.mean())

# %% [markdown]
# <a id='machine'></a>
# ### Model Selection

# %%
X = df_filled.drop('Winner', axis=1)

# %%
y = df_filled['Winner']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# %%time
# prepare configuration for cross validation test harness
seed = 42
# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# LR: 0.510411 (0.008647)
# LDA: 0.893824 (0.004370)
# KNN: 0.531184 (0.008935)
# CART: 0.858566 (0.005077)
# NB: 0.490544 (0.005773)
# SVM: 0.511719 (0.005898)

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Since ensemble method classifers seem promising from the results with DecisionTreeClassifier, train and compare ensemble method classifiers.

# %%
# %%time
# prepare configuration for cross validation test harness
seed = 42
# prepare models
models = []
models.append(('ADA', AdaBoostClassifier()))
models.append(('BAG', BaggingClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('GBC', GradientBoostingClassifier()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# ADA: 0.886380 (0.006614)
# BAG: 0.876622 (0.004677)
# RFC: 0.888895 (0.004026)
# GBC: 0.900564 (0.005460)
# Wall time: 2min 16s

# %%
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# <a id='tuning'></a>
# ### Model Tuning

# %% [markdown]
# GradientBoostingClassifier was selected for having the highest precision and f1-score amongst the fitted classifers. GridSearchCCV was used to fine-tune the model parameters.

# %%
clf_GB.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'deviance',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'presort': 'deprecated',
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Import 'GridSearchCV', 'make_scorer', and any other necessary libraries
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import make_scorer

# Initialize the classifier
clf_GB = GradientBoostingClassifier(random_state = 42)

# Create the parameters list to tune
parameters = {'n_estimators':[10, 20, 60, 100], 'learning_rate': [0.05, 0.1, 0.2, 1]}

# TODO: Make an fbeta_score scoring object using make_scorer()
scorer = make_scorer(fbeta_score, beta = 0.5)

# TODO: Perform grid search on the classifier using 'scorer' as the scoring method using GridSearchCV()
grid_obj = GridSearchCV(estimator = clf_GB, param_grid = parameters, scoring = scorer, cv = 5)

# TODO: Fit the grid search object to the training data and find the optimal parameters using fit()
grid_fit = grid_obj.fit(X_train, y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

# Make predictions using the unoptimized and model
predictions = (clf_GB.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Unoptimized model
# ------
# Accuracy score on testing data: 0.9065
# F-score on testing data: 0.9102
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 0.9076
# Final F-score on the testing data: 0.9118

# %% [markdown]
# ### Feature Importance Extraction

# %%
feat_importances = pd.Series(clf_GB.feature_importances_, index=X_test.columns.values).sort_values(ascending=False)

# %%
def plot_barh(s_to_plot, title = '', xlabel = '', ylabel = '',
color_palette = 'YlGnBu', pre_unit = '', suff_unit = '', round_place = '',):
    '''
    Plot horizontal bar graph
    '''
    y_labels = s_to_plot.index

    # Plot the figure.
    plt.figure(figsize=(12, 20))
    ax = s_to_plot.plot(kind='barh')
    plt.barh(s_to_plot.index, s_to_plot,
            color = sns.color_palette(color_palette, len(s_to_plot.index)))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_yticklabels(y_labels)
    x_llim, x_ulim = ax.get_xlim()
    #x_ulim = xulim_set
    #ax.set_xlim(x_llim, xulim_set) # expand xlim to make labels easier to read
    plt.tight_layout()
    rects = ax.patches

# %%
plot_barh(feat_importances[feat_importances > 0].sort_values())

# %%
pd.DataFrame(feat_importances[feat_importances > 0])
# Out:
#                               0
# firstInhibitor     6.489103e-01
# redElemDragNum     7.295672e-02
# blueElemDragNum    6.624017e-02
# redbaronKills      3.830563e-02
# firstTower         3.491930e-02
# ...                         ...
# blueFIRE_DRAGON    1.690759e-05
# 4AIR_DRAGONteam    2.279306e-06
# 2EARTH_DRAGONteam  1.420384e-06
# BARON_NASHOR4time  1.109049e-06
# 2ELDER_DRAGONtime  9.713221e-07
#
# [79 rows x 1 columns]

# %%
feat_importances[var_soul].sort_values(ascending=False)
# Out:
# WATER_DRAGONSoultime    0.000300
# FIRE_DRAGONSoulteam     0.000099
# FIRE_DRAGONSoultime     0.000098
# AIR_DRAGONSoultime      0.000041
# EARTH_DRAGONSoultime    0.000000
# EARTH_DRAGONSoulteam    0.000000
# AIR_DRAGONSoulteam      0.000000
# WATER_DRAGONSoulteam    0.000000
# dtype: float64

# %%
def feature_plot(importances, X_train, y_train):
    
    # Display the five most important features
    indices = np.argsort(importances)[::-1]
    columns = X_train.columns.values[indices[:10]]
    values = importances[indices][:10]

    # Creat the plot
    fig = plt.figure(figsize = (9,5))
    plt.title("Normalized Weights for First Five Most Predictive Features", fontsize = 16)
    plt.bar(np.arange(10), values, width = 0.2, align="center", color = '#00A000', \
          label = "Feature Weight")
    plt.bar(np.arange(10) - 0.3, np.cumsum(values), width = 0.2, align = "center", color = '#00A0A0', \
          label = "Cumulative Feature Weight")
    plt.xticks(np.arange(10), columns)
    plt.xlim((-0.5, 4.5))
    plt.ylabel("Weight", fontsize = 12)
    plt.xlabel("Feature", fontsize = 12)
    
    plt.legend(loc = 'upper center')
    plt.tight_layout()
    plt.show()

# %%
feat_importances[:30]
# Out:
# firstInhibitor         0.648910
# redElemDragNum         0.072957
# blueElemDragNum        0.066240
# redbaronKills          0.038306
# firstTower             0.034919
# bluebaronKills         0.034776
# reddragonKills         0.025468
# bluedragonKills        0.016608
# BARON_NASHOR2team      0.015860
# GameDuration           0.012358
# BARON_NASHOR3team      0.004313
# 1ELDER_DRAGONteam      0.003248
# firstDragon            0.002674
# 2ELDER_DRAGONteam      0.002267
# blueriftHeraldKills    0.001990
# redriftHeraldKills     0.001301
# 6FIRE_DRAGONtime       0.000944
# 4EARTH_DRAGONteam      0.000799
# BARON_NASHOR2time      0.000766
# 5AIR_DRAGONtime        0.000759
# 5WATER_DRAGONteam      0.000759
# 5AIR_DRAGONteam        0.000632
# 4FIRE_DRAGONtime       0.000627
# 5FIRE_DRAGONteam       0.000594
# 2EARTH_DRAGONtime      0.000560
# BARON_NASHOR1time      0.000545
# 1FIRE_DRAGONtime       0.000491
# 3FIRE_DRAGONteam       0.000465
# 1ELDER_DRAGONtime      0.000429
# 1WATER_DRAGONtime      0.000426
# dtype: float64

# %%
feature_plot(clf_GB.feature_importances_, X_train, y_train)

# %% [markdown]
# ### Results of initial model

# %% [markdown]
# #### Dragon Soul
#
# The data does seem to reflect what people think of the relative power levels of dragon souls - ocean is the most powerful IF you get it early. Cloud soul also contributes towards wins if it's obtained earlier in the game. This makes sense since ocean and cloud drake both grant advantages early and mid-game, but these advantages decrease as the game goes on. Come late game, the players' stats will have scaled enough and the game's pace will change to even out these dragon soul advantages.
#
# Ocean soul grants extra health and mana regeneration out of combat, which will help one team stay healthy throughout midgames during skirmishes, extended seiges and teamfights. Since it boosts regeneration, ocean soul is only useful if at least some players on a team stay alive after combat. Turrets still do significant damage to players midgame, so even if not everyone on a is alive, ocean soul helps the alive players stay healthy to defend with the safety of  structures. As the game goes on, player damage will have also increased to the point that players are more likely to die and the death timers are longer. Additionally, structural defenses, turrets, do less meaningful damage to players while players can destroy them more easily. As deaths become more impactful, any player who remain alive on a team while some of their teammates are dead find that ocean soul becomes less helpful in defense.
#
# Cloud soul increases movement speed and cooldown reduction on spells, granting one team a tempo advantage in moving around the map and having increased access to useful ultimate spells. Player will have more CDR items and have decreased cooldowns with higher level spells, so players will be more likely to have equal access to their ultimate spells later in the game.
#
# Infernal soul, on the other hand, remains powerful regardless of when the team obtains it. The infernal soul grants percent-based permanent damage bonuses to a team, so that advantage remains throughout the course of a game.

# %% [markdown]
# The top 5 most predictive features are:
# 1. team that takes first inhibitor
# 2. number of elemental dragons taken by red team
# 3. number of elemental dragons taken by blue team
# 4. number of baron kills taken by the red team
# 5. team that takes first tower
#
# Which team kills the first inhibitor seems to be the best predictor of who will win the game. This makes sense since killing an inhibitor is the most direct path towards killing the enemy nexus. The first inhibitor kill accounts for 60% of the weights for predicting the game winner.
#
# The total number of elemental drakes taken by a team is the next best predictor, with red team dragon kills being slightly more predictive than blue team's. Without doing further analysis it's hard to say whether this difference is statistically significant. We can speculate that perhaps the red team's larger relative distance from the dragon pit compared to the blue team means that red team naturally has less control over the dragon; therefore, if the red team is successful at capturing dragon objectives, red likely has a strong control over the game carrying over to wins.
#
# The order of importance of neutral objectives to the game result seems to be:
# #### elemental dragons > baron > elder dragon > rift herald
#
# ### Early objectives
#
# Of all the early objectives available (inhibitor, tower, dragon, baron, rift herald), it seems that the non-neutral objectives, inhibitors and towers, are the most predictive, followed by dragon and baron. First rift herald seem to have no predictive weight on the winner at all.
#
# Of course, the associations here must be taken with a grain of salt before tranlating them to causation. Having early game pressure will translate to more objective control. However, it is very telling that first dragon has more weight than first herald, when both of these objectives are usually captured around the same time and are often "traded" for each other (if one team takes one, the other team will take the other).

# %%
bool_params = ['firstTower', 'firstInhibitor', 'firstBaron', 'firstDragon', 
               'firstRiftHerald']
num_params = ['baronKills', 'riftHeraldKills', 'dragonKills']

# %%
feat_importances[bool_params].sort_values(ascending=False)
# Out:
# firstInhibitor     0.648910
# firstTower         0.034919
# firstDragon        0.002674
# firstBaron         0.000188
# firstRiftHerald    0.000000
# dtype: float64

# %%
plt.bar(feat_importances[bool_params].index, feat_importances[bool_params])
# Out:
# <BarContainer object of 5 artists>
